# %% [markdown]
# # Fresh Prompt
# - [freshllms/freshqa](https://github.com/freshllms/freshqa)

# %% [markdown]
# ## セットアップ

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv(verbose=True)

openai_client = OpenAI(
  api_key=os.environ["OPENAI_API_KEY"],
)

# %%
import pytz
import datetime

current_date = datetime.datetime.now(
    # pytz.timezone('Asia/Tokyo')
    pytz.timezone("America/Los_Angeles")
).strftime("%B %d, %Y")
print(current_date)
# Out:
# November 14, 2023

# %%
temperature = 0.0
max_tokens = 256

def chat_completions(prompt):
    response = openai_client.chat.completions.create(
        model="gpt-4-1106-preview",
        temperature=0.0,
        max_tokens=256,
        messages=[
            {
                "role": "system",
                "content": (
                    "You are a helpful assistant. Answer as concisely as"
                    f" possible. Knowledge cutoff: {current_date}."
                ),
            },
            {"role": "user", "content": "What's today's date?"},
            {
                "role": "assistant",
                "content": f"Today is {current_date} in Pacific Standard Time.",
            },
            {"role": "user", "content": prompt},
        ],
    )
    return response.choices[0].message.content

# %%
from serpapi import GoogleSearch

def call_search_engine(query):
  params = {
    "q": query,
    # "location": "California, United States",
    "hl": "en",
    "gl": "us",
    "google_domain": "google.com",
    "api_key": os.environ["SERPAPI_API_KEY"],
  }

  search = GoogleSearch(params)
  return search.get_dict()

# %%
import dateutil
import re

def is_date(string, fuzzy=False):
  # Parse a string into a date and check its validity
  try:
      dateutil.parser.parse(string, fuzzy=fuzzy)
      return True
  except ValueError:
      return False


def format_date(d):
  # Standardize the date format for each search result
  date = dateutil.parser.parse(current_date, fuzzy=True).strftime("%b %d, %Y")
  if d is None:
    return None

  for t in ["second", "minute", "hour"]:
    if f"{t} ago" in d or f"{t}s ago" in d:
      return date

  t = "day"
  if f"{t} ago" in d or f"{t}s ago" in d:
    n_days = int(re.search("(\d+) days? ago", d).group(1))
    return (
        datetime.datetime.strptime(date, "%b %d, %Y")
        - datetime.timedelta(days=n_days)
    ).strftime("%b %d, %Y")

  try:
    return dateutil.parser.parse(d, fuzzy=True).strftime("%b %d, %Y")
  except ValueError:
    for x in d.split():
      if is_date(x):
        return dateutil.parser.parse(x, fuzzy=True).strftime("%b %d, %Y")


def extract_source_webpage(link):
  # Extract source webpage
  return (
      link.strip()
      .replace("https://www.", "")
      .replace("http://www.", "")
      .replace("https://", "")
      .replace("http://", "")
      .split("/")[0]
  )


def simplify_displayed_link(displayed_link):
  # Simplify displayed link
  if displayed_link is None:
    return None
  return extract_source_webpage(displayed_link.split(' › ')[0])

# %%
def format_search_results(search_data, title_field=None, highlight_field=None):
  # Standardize search results as shown in Figure 3 (left) in the paper
  field = 'snippet_highlighted_words'
  if field in search_data and isinstance(search_data[field], list):
    search_data[field] = ' | '.join(search_data[field])

  field = 'displayed_link'
  if field in search_data:
    search_data[field] = simplify_displayed_link(search_data[field])

  # edge case 1
  if search_data.get('type') == 'local_time':
    source = search_data.get('displayed_link')
    date = format_date(search_data.get('date'))
    title = search_data.get('title')

    snippet = search_data.get('snippet')
    if snippet is None and 'result' in search_data:
      if 'extensions' in search_data and isinstance(
          search_data['extensions'], list
      ):
        snippet = '\n\t'.join(
            [search_data['result']] + search_data['extensions']
        )
      else:
        snippet = search_data['result']

    highlight = search_data.get('snippet_highlighted_words')
    if highlight is None and 'result' in search_data:
      highlight = search_data['result']

  # edge case 2
  elif 'type' in search_data and search_data['type'] == 'population_result':
    source = search_data.get('displayed_link')
    if source is None and 'sources' in search_data:
      if (
          isinstance(search_data['sources'], list)
          and 'link' in search_data['sources'][0]
      ):
        source = extract_source_webpage(search_data['sources'][0]['link'])

    date = format_date(search_data.get('date'))
    if date is None and 'year' in search_data:
      date = format_date(search_data['year'])

    title = search_data.get('title')

    snippet = search_data.get('snippet')
    if snippet is None and 'population' in search_data:
      if 'place' in search_data:
        snippet = '\n\t'.join(
            [
                f"{search_data['place']} / Population",
            ]
            + [
                search_data['population'],
            ]
        )
      else:
        snippet = search_data['population']

    highlight = search_data.get('snippet_highlighted_words')
    if highlight is None and 'population' in search_data:
      highlight = search_data['population']

  else:
    source = search_data.get('displayed_link')
    date = format_date(search_data.get('date'))
    title = (
        search_data.get('title')
        if title_field is None
        else search_data.get(title_field)
    )
    highlight = (
        search_data.get('snippet_highlighted_words')
        if highlight_field is None
        else search_data.get(highlight_field)
    )
    snippet = search_data.get('snippet', '')

    if 'rich_snippet' in search_data:
      for key in ['top', 'bottom']:
        if (
            key in search_data['rich_snippet']
            and 'extensions' in search_data['rich_snippet'][key]
        ):
          snippet = '\n\t'.join(
              [snippet] + search_data['rich_snippet'][key]['extensions']
          )

    if 'list' in search_data:
      assert isinstance(search_data['list'], list)
      snippet = '\n\t'.join([snippet] + search_data['list'])

    if 'contents' in search_data and 'table' in search_data['contents']:
      tbl = search_data['contents']['table']
      assert isinstance(tbl, list)
      snippet += '\n'
      for row in tbl:
        snippet += f'\n{",".join(row)}'

    if snippet is not None and snippet.strip() == '':
      snippet = None

  return {
      'source': source,
      'date': date,
      'title': title,
      'snippet': snippet,
      'highlight': highlight,
  }

# %%
def format_knowledge_graph(search_data):
  # Standardize knowledge graphs as shown in Figure 3 (left) in the paper
  source = None
  if "source" in search_data and "link" in search_data["source"]:
    source = extract_source_webpage(search_data["source"]["link"])

  date = None

  title = None
  if "title" in search_data:
    title = search_data["title"]
    if "type" in search_data:
      title += f"\n\t{search_data['type']}"

  snippet = ""
  for field in search_data:
    if (
        (field not in ["title", "type", "kgmid"])
        and ("_link" not in field)
        and ("_stick" not in field)
        and isinstance(search_data[field], str)
        and not search_data[field].startswith("http")
    ):
      snippet += f"\n\t{field}: {search_data[field]}"

  if snippet.strip() == "":
    snippet = None
  else:
    snippet = snippet.strip()

  highlight = None

  return {
      "source": source,
      "date": date,
      "title": title,
      "snippet": snippet,
      "highlight": highlight,
  }


def format_questions_and_answers(search_data):
  # Standardize questions and answers as shown in Figure 3 (left) in the paper
  source = None
  if "link" in search_data:
    source = extract_source_webpage(search_data["link"])

  date = None

  title = None
  if "question" in search_data:
    title = search_data["question"]

  snippet = None
  if "answer" in search_data:
    snippet = search_data["answer"]

  highlight = None

  return {
      "source": source,
      "date": date,
      "title": title,
      "snippet": snippet,
      "highlight": highlight,
  }

# %% [markdown]
# ## Demo Prompts

# %%
# read from file
with open("./data/freshprompt_demo.txt", "r") as f:
    freshprompt_demo = f.read()

print(freshprompt_demo)
# Out:
# query: What year is considered Albert Einstein's annus mirabilis?
#
# source: philsci-archive.pitt.edu
# date: None
# title: The Turning Point for Einstein's Annus Mirabilis
# snippet: The year 1905 has been called Einstein's annus mirabilis in virtue of three ground-breaking works completed over the span of a few months — the light.
# highlight: 1905
#
# source: cantorsparadise.com
# date: None
# title: Einstein's Miraculous Year: A Summary of the 1905 Annus ...
# snippet: These are the four papers that Albert Einstein published in 1905, which are considered to be the foundation of modern physics.
# highlight: 1905
#
# source: quora.com
# date: None
# title: Why is 1905 Einstein's miracle year?
# snippet: Thus, 1905 is called Einstein's annus mirabilis, or miracle year, and these papers are called his annus mirabilis papers .
# highlight: 1905
#
# source: en.wikipedia.org
# date: None
# title: Annus mirabilis papers
# snippet: The annus mirabilis papers are the four papers that Albert Einstein published in Annalen der Physik (Annals of Physics), a scientific journal, in 1905.
# highlight: 1905
#
# source: americanscientist.org
# date: None
# title: Which year is known as annus mirabilis year?
# snippet: The Cambridge Dictionary defines annus mirabilis as “a year of extremely good events.” When otherwise unqualified, the term is usually understood to refer to “the miraculous year” of 1666, during which the Great Plague continued and the Great Fire of London raged for four days.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: When was the annus mirabilis of Albert Einstein?
# snippet: Because Einstein published these remarkable papers in a single year, 1905 is called his annus mirabilis (miracle year in English or Wunderjahr in German). , and was the only specific discovery mentioned in the citation awarding Einstein the Nobel Prize in Physics.
# highlight: None
#
# source: iopscience.iop.org
# date: None
# title: 1905
# snippet: Abstract. It is no exaggeration to say that almost every physicist knows about Albert Einstein's annus mirabilis 1905.
# highlight: 1905
#
# source: npr.org
# date: Mar 17, 2005
# title: Albert Einstein's Year of Miracles: Light Theory
# snippet: Scientists call 1905 Albert Einstein's annus mirabilis — his year of miracles. ... considered here [the March paper]" that represented a sharp ...
# highlight: 1905
#
# source: npr.org
# date: Mar 17, 2005
# title: What year is Einstein's biggest year?
# snippet: Web Resources. Scientists call 1905 Albert Einstein's annus mirabilis — his year of miracles. Within a few months, Einstein wrote a series of papers that would transform the way we see the universe.
# highlight: None
#
# source: scihi.org
# date: Jun 30, 2018
# title: The Annus Mirabilis in Physics – Albert Einstein and the Year ...
# snippet: 1905 was this Annus Mirabilis, this year of wonders or extraordinary year. History considers 1905 as the year with the most outstanding and ...
# highlight: 1905
#
# source: guides.loc.gov
# date: Nov 06, 2019
# title: Introduction - Annus Mirabilis of Albert Einstein
# snippet: He published hundreds of scientific papers during the course of his life, but in 1905, the year he turned 26, he published the four ...
# highlight: 1905
#
# source: guides.loc.gov
# date: Nov 04, 2023
# title: The 1905 Papers - Annus Mirabilis of Albert Einstein
# snippet: English translations of the four papers, from The Collected Papers of Albert Einstein, vol. 2: The Swiss Years: Writings 1900-1909, Princeton ...
# highlight: Albert
#
# question: What year is considered Albert Einstein's annus mirabilis?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. 1905 is considered Albert Einstein's annus mirabilis, his miraculous year.
#
#
# query: Which photographer took the most expensive photograph in the world?
#
# source: phototraces.com
# date: None
# title: Top 10 Most Expensive Photographs Ever Sold
# snippet: 10 Most Expensive Photographs Ever Sold · #1 Peter Lik, Phantom – (?) · #2 Andreas Gursky, Rhein II $4,338,500 · #3 Richard Prince, Spiritual America $3,973,000 · # ...
# highlight: Peter Lik, Phantom
#
# source: expertphotography.com
# date: None
# title: The 10 Most Expensive Photographs Ever Sold (by 2023)
# snippet: These are most expensive photographs ever sold, for millions at auction. You can decide for yourself if these famous photographers work is worth the price!
# highlight: most expensive photographs ever | photographers
#
# source: academic-accelerator.com
# date: None
# title: This is some fact about the cell membrane.
# snippet: cell membrane
# highlight: None
#
# source: reddit.com
# date: None
# title: Who is The Most Expensive Wedding Photographer in the world? and what is their portfolio like?
# snippet: surely Jose Villa would cost a bomb.
# highlight: None
#
# source: quora.com
# date: None
# title: What is the most expensive photograph ever shot?
# snippet: Probably the photo of the Earth taken from the Moon. Each moon landing of the Apollo program averages out to $18 billion dollars out of the $109 billion dollar program (based in 2011 dollars). http://www.thespacereview.com/article/1579/1 Hard to imaging that any other photo can come close.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: List
# snippet:
#
# Rank,Artist,Date
# 1,Man Ray,May 14, 2022
# 2,Edward Steichen,Nov 10, 2022
# 3,Andreas Gursky,November 8, 2011
# 4,Atsuko Satō,June 11, 2021
# highlight: None
#
# source: pentaxforums.com
# date: Oct 23, 2012
# title: WHo took the world's most expensive photograph?
# snippet: WHo took the world's most expensive photograph? ... Gursky sells high resolution photographs of huge dimensions often taken from very high angles.
# highlight: Gursky
#
# source: quora.com
# date: Mar 12, 2015
# title: What is the most expensive photograph ever shot?
# snippet: Shot by Kevin Abosch, in 2010 was auctioned for a whopping 1 Million Euros in 2015.
# highlight: Kevin Abosch
#
# source: digitalphotographycourses.co.za
# date: Nov 21, 2018
# title: What photograph sold for 4.3 million?
# snippet: Andreas Gursky's, Rhein II was sold at Christie's, New York for a whopping 4.3 Million USD on November 8, 2011.
# highlight: None
#
# source: all-about-photo.com
# date: Dec 22, 2019
# title: Most expensive photographs ever sold | Photo Article
# snippet: The most expensive photo in history as of December 2014 is $6.5 million! The work of Australian landscape photographer Peter Lik, Phantom is a ...
# highlight: Australian landscape photographer Peter Lik, Phantom
#
# source: pocket-lint.com
# date: Jul 22, 2021
# title: The 24 most expensive photos that sold for millions
# snippet: Australian photographer Peter Lik claims to hold the record for the most expensive photograph ever sold: a staggering $6.5 million for his photo ...
# highlight: Australian photographer Peter Lik
#
# source: cnn.com
# date: May 15, 2022
# title: What is the world's most expensive photograph?
# snippet: Man Ray's 'Le Violon d'Ingres' photograph sells for record $12.4 million. Editor's Note: This story was updated with the final sale price and other details following the auction.
# highlight: None
#
# source: news.artnet.com
# date: May 16, 2022
# title: What is the most expensive print ever sold?
# snippet: Man Ray, Le Violon d'Ingres (1924). Courtesy of Christie's. This weekend, an iconic Man Ray print sold for $12.4 million at Christie's, nearly tripling the record for the most expensive photograph ever sold at auction.
# highlight: None
#
# source: barnebys.com
# date: May 14, 2023
# title: The 11 Most Expensive Photographers
# snippet: It became the world's most expensive photograph when it sold at Christie's in 2022 for $12.4 million. Find more features on Barnebys Magazine.
# highlight: Christie's
#
# source: artincontext.org
# date: Aug 10, 2023
# title: Most Expensive Photographs - 15 Extravagant Photographs
# snippet: Le Violon D'Ingre (1924) by Man Ray takes first place at an astonishing $12.4 million! Some of the other most expensive photos ever sold include ...
# highlight: Le Violon D'Ingre (1924) by Man Ray
#
# question: Which photographer took the most expensive photograph in the world?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The most expensive photograph in the world is "Le Violon d'Ingres". The photograph was created by Man Ray.
#
#
# query: How many days are left until the 2023 Grammy Awards?
#
# source: en.wikipedia.org
# date: None
# title: 65th Annual Grammy Awards
# snippet: The 65th Annual Grammy Awards ceremony was held at the Crypto.com Arena in Los Angeles on February 5, 2023. It recognized the best recordings, compositions, ...
# highlight: Grammy Awards | in | 2023
#
# source: grammy.com
# date: None
# title: Everything You Need To Know About The 2023 GRAMMYs ...
# snippet: The eligibility period for the 65th GRAMMY Awards is Friday, Oct. 1, 2021 – Friday, Sept. 30, 2022. All eligible awards entries must be released within this ...
# highlight: for | GRAMMY Awards
#
# source: recordingacademy.com
# date: None
# title: 2023 GRAMMYs: Everything You Need To Know About ...
# snippet: There are only two days left to participate in first-round voting for the 2023 GRAMMYs; final-round voting will commence Dec. 14. If you're a Recording ...
# highlight: two days
#
# source: grammy.com
# date: None
# title: Air Date For 2023 GRAMMYs Announced
# snippet: This year's GRAMMY nominees will be announced on Tuesday, Nov. 15, with the 2023 GRAMMYs airing live Sunday, Feb. 5, from the Crypto.com Arena in Los Angeles.
# highlight: GRAMMY | 2023 GRAMMYs | in
#
# source: recordingacademy.com
# date: None
# title: How long until the next Grammy Awards?
# snippet: THE 66TH ANNUAL GRAMMY AWARDS® SET TO TAKE PLACE SUN, FEB. 4, 2024 | RECORDINGACADEMY.com.
# highlight: None
#
# source: grammy.com
# date: None
# title: What time is GRAMMYs 2023 over?
# snippet: The 2023 GRAMMYs will air live on Sunday, Feb. 5, at 8-11:30 p.m. ET/5-8:30 p.m. PT from the Crypto.com Arena in Los Angeles.
# highlight: None
#
# source: variety.com
# date: Jul 14, 2022
# title: Grammy Awards Announce Key Dates for 2023 Race
# snippet: Nominees will be announced this year on Nov. 15, with the first round of voting set from Oct. 13 to Oct. 23 and a final round on Dec. 14 to Jan.
# highlight: None
#
# source: billboard.com
# date: Jul 14, 2022
# title: Here's the Date & Location of the 2023 Grammy Awards
# snippet: Nominations will be announced on Tuesday, Nov. 15 -- eight days earlier than they were last year.
# highlight: eight days
#
# source: en.as.com
# date: Feb 01, 2023
# title: 2023 Grammy Awards: Who's attending, skipping, and ...
# snippet: With only a few days left until the 65th annual Grammy Awards, and the full performer lineup yet to be announced, here is how the show is ...
# highlight: only a few days
#
# source: howmanydaysuntil.center
# date: Feb 04, 2023
# title: When ar The Grammy Awards - How Many Days Until
# snippet: The Grammy Awards will be celebrated this year on is on February 4th. Find out more about The Grammy Awards.
# highlight: February 4th
#
# source: cnn.com
# date: Feb 05, 2023
# title: How to watch the Grammys: Time, channels and more
# snippet: How to watch the 2023 Grammy Awards: Time, channels and more · Day and time. The Grammy Awards air Sunday, February 5, at 8 p.m. ET/5 p.m. PT.
# highlight: 2023 Grammy Awards | Day | Grammy Awards
#
# source: nytimes.com
# date: Feb 06, 2023
# title: How to Watch the 2023 Grammys
# snippet: The ceremony will air live on Sunday, at 8 p.m. Eastern time (5 p.m. Pacific time) on CBS and stream live on Paramount+. Before the prime-time ...
# highlight: Before the
#
# source: billboard.com
# date: Nov 10, 2023
# title: What is the deadline for Grammy nominations 2023?
# snippet: This year's eligibility period ran from Oct. 1, 2022, through Sept. 15, 2023. The final round of Grammy voting, which will determine the winners, will take place Dec. 14 through Jan. 4, 2024.
# highlight: None
#
# question: How many days are left until the 2023 Grammy Awards?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The 2023 Grammy Awards ceremony was held on February 5, 2023. Thus, the ceremony has already taken place.
#
#
# query: How many years ago did the Boxing Day Tsunami happen?
#
# source: knowledge.aidr.org.au
# date: None
# title: The Boxing Day Tsunami in numbers Stats and facts
# snippet: The Tangshan Earthquake in China killed at least 255,000 in 1976. Flooding in Bangladesh in 2004 destroyed over 1 million homes, displaced over 4 million ...
# 	2 pages
# highlight: Earthquake | 2004
#
# source: knowledge.aidr.org.au
# date: None
# title: Indian Ocean tsunami, 2004 | Australian Disasters
# snippet: In December 2004, a massive earthquake struck off the west coast of Sumatra. The resulting Indian Ocean tsunami caused widespread destruction. Learn more.
# highlight: December 2004
#
# source: britannica.com
# date: None
# title: Indian Ocean tsunami of 2004 | Facts & Death Toll
# snippet: Indian Ocean tsunami of 2004, deadly tsunami that hit the coasts of several countries of South and Southeast Asia and caused immense destruction.
# highlight: 2004
#
# source: britannica.com
# date: None
# title: How long did the 2004 tsunami last?
# snippet: How long did the Indian Ocean tsunami of 2004 last? The Indian Ocean tsunami of 2004 lasted for seven hours and reached out across the Indian Ocean, devastating coastal areas of Indonesia, Sri Lanka, India, Maldives, and Thailand, and as far away as East Africa.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: 2004 Indian Ocean earthquake and tsunami - Wikipedia
# snippet: On 26 December 2004, at 07:58:53 local time (UTC+7), a major earthquake with a magnitude of 9.1–9.3 Mw struck with an epicentre off the west coast of northern Sumatra, Indonesia.
# highlight: None
#
# source: history.com
# date: Oct 02, 2018
# title: The 2004 Tsunami Wiped Away Towns With 'Mind- ...
# snippet: The Boxing Day tsunami would be the deadliest in recorded history, taking a staggering 230,000 lives in a matter of hours. The city of Banda ...
# highlight: 230,000
#
# source: reuters.com
# date: Dec 18, 2019
# title: 15 years on, a look back at the Boxing Day tsunami
# snippet: December 26 marks 15 years since a 9.1 magnitude quake off the coast of Indonesia's Aceh province triggered a tsunami that killed more than ...
# highlight: 15 years
#
# source: preventionweb.net
# date: Jun 26, 2021
# title: Indian Ocean tsunami: What was learned about recovery
# snippet: We've been following victims of the Boxing Day tsunami for 16 years – this is what we've learned about recovering from disaster. Source(s): ...
# highlight: 16 years
#
# source: materchristi.libguides.com
# date: May 11, 2023
# title: 2004 Indian Ocean Tsunami - Natural disasters of the Asia ...
# snippet: The Boxing Day tsunami in 2004 is believed to be the deadliest tsunami in history, killing more than 230,000 people across 14 countries.
# highlight: 2004
#
# source: noaa.gov
# date: Jun 12, 2023
# title: JetStream Max: 2004 Indian Ocean Tsunami
# snippet: On December 26, 2004, an extremely powerful earthquake off the coast of the Indonesian island of Sumatra in the Indian Ocean generated a ...
# highlight: December 26, 2004
#
# source: noaa.gov
# date: Jun 12, 2023
# title: When did the Boxing Day tsunami occur?
# snippet: On December 26, 2004, an extremely powerful earthquake off the coast of the Indonesian island of Sumatra in the Indian Ocean generated a devastating tsunami.
# highlight: None
#
# source: worldvision.org
# date: Sep 25, 2023
# title: 2004 Indian Ocean Earthquake and Tsunami
# snippet: Discover the 2004 Indian Ocean tsunami's historic impact and World Vision's multi-country humanitarian efforts that lasted over a decade.
# highlight: 2004
#
# source: worldvision.org
# date: Sep 25, 2023
# title: What was the worst tsunami in 2004?
# snippet: Approximately 230,000 people died in the 2004 Indian Ocean earthquake and tsunami, making it one of the deadliest disasters in modern history. The Sumatra-Andaman earthquake, which caused the tsunami, is estimated to have released energy equivalent to 23,000 Hiroshima-type atomic bombs.
# highlight: None
#
# question: How many years ago did the Boxing Day Tsunami happen?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The disaster occurred on December 26, 2004. Thus, it happened 18 years ago.
#
#
# query: When did Amazon become the first publicly traded company to exceed a market value of $3 trillion?
#
# source: en.wikipedia.org
# date: None
# title: List of public corporations by market capitalization
# snippet: The table below lists all companies which have, at any point, had a market capitalization in excess of $1 trillion, the date on which their market cap first ...
# highlight: companies | market capitalization | excess | trillion | market cap first
#
# source: cbsnews.com
# date: Sep 04, 2018
# title: Amazon becomes second trillion-dollar company in US
# snippet: Amazon hits $1 trillion and becomes the second U.S. company worth one trillion dollars after stock price surged Tuesday - CBS News.
# highlight: after stock price surged Tuesday
#
# source: cnbc.com
# date: Jan 03, 2022
# title: Apple becomes first U.S. company to reach $3 trillion ...
# snippet: Apple became the first publicly traded U.S. company to hit a $1 trillion market cap during intraday trading on Aug. 2, 2018. It hit a $2 ...
# highlight: Aug. 2, 2018
#
# source: fortune.com
# date: Nov 02, 2022
# title: As Amazon's value drops below $1 trillion, this chart shows ...
# snippet: On November 1, Amazon reached a bleak milestone when its value dropped below $1 trillion for the first time since first crossing that ...
# highlight: On November 1
#
# source: financialpost.com
# date: Nov 09, 2022
# title: Amazon becomes first public company to lose $1 trillion ...
# snippet: Amazon.com Inc. is the world's first public company to lose a trillion dollars in market value as a combination of rising inflation ...
# highlight: Amazon | is the | first public company | trillion | market value
#
# source: bloomberg.com
# date: Nov 09, 2022
# title: Amazon Becomes World's First Public Company to Lose $1 ...
# snippet: Amazon.com Inc. is the world's first public company to lose a trillion dollars in market value as a combination of rising inflation, ...
# highlight: Amazon | is the | first public company | trillion | market value
#
# source: fortune.com
# date: Jun 30, 2023
# title: Apple becomes first $3 trillion market value company
# snippet: Apple first became the world's most valuable stock in 2011, when its market cap was under $340 billion and it comprised about 3.3% of the S&P ...
# highlight: 2011
#
# source: qz.com
# date: Jun 30, 2023
# title: Apple is officially the world's first-ever $3 trillion company
# snippet: Apple became the first company in the world with a $3 trillion valuation on Friday (June 30). The company's stock closed at $193.97 per share— ...
# highlight: Friday (June 30
#
# source: zeebiz.com
# date: Jun 30, 2023
# title: What company has reached the market cap of 3 trillion?
# snippet: Apple is once again worth $3 trillion, the only company ever to reach the milestone, a media report said. Its shares rose 1 per cent on Friday to hit a record $191.34. With 15.7 billion shares outstanding, the stock price pushed Apple to its historic market value, CNN reported.
# highlight: None
#
# source: nbcnews.com
# date: Jun 30, 2023
# title: Is Apple the first US company to reach $3 trillion market cap?
# snippet: The news shows investors remain bullish on the stock and Apple's portfolio of products and services, despite the company's warning in May that its current quarter revenue is expected to fall about 3%.
# highlight: None
#
# source: fortune.com
# date: Jun 30, 2023
# title: What is the first $3 trillion dollar company?
# snippet: Apple just made history by becoming the first company with a $3 trillion market value—'and its lock on the consumer is only getting stronger' Apple CEO Tim Cook.
# highlight: None
#
# source: cityindex.com
# date: Aug 24, 2023
# title: A guide to trillion-dollar companies
# snippet: Apple did become the world's first $3 trillion company in June 2023 but hasn't retained that market capitalisation in the subsequent months.
# highlight: June 2023
#
# source: money.usnews.com
# date: Oct 24, 2023
# title: The 10 Most Valuable Companies in the World by Market ...
# snippet: (ticker: AAPL) was the first company to reach a market capitalization of $1 trillion in 2018. ... Overall, Amazon has become the largest online ...
# highlight: 2018
#
# question: When did Amazon become the first publicly traded company to exceed a market value of $3 trillion?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. Amazon's market capitalization has never exceeded $3 trillion.

# %% [markdown]
# ## freshprompt_format method

# %%
question = "Who won the latest Nobel Prize in Physics?"

# %%
# modelにgpt-4を利用する場合
num_organic_results = 15
num_related_questions = 3
num_questions_and_answers = 3
num_retrieved_evidences = 15

# %%
import pandas as pd

df = pd.DataFrame(columns=['source', 'date', 'title', 'snippet', 'highlight'])

# %%
search_data = call_search_engine(question)

# %%
search_data
# Out:
# {'search_metadata': {'id': '65536ab495bf92860dee7a18',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/15cabbac73034b35/65536ab495bf92860dee7a18.json',
#   'created_at': '2023-11-14 12:40:20 UTC',
#   'processed_at': '2023-11-14 12:40:20 UTC',
#   'google_url': 'https://www.google.com/search?q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&oq=Who+won+the+latest+Nobel+Prize+in+Physics%3F&hl=en&gl=us&sourceid=chrome&ie=UTF-8',
#   'raw_html_file': 'https://serpapi.com/searches/15cabbac73034b35/65536ab495bf92860dee7a18.html',
#   'total_time_taken': 5.67},
#  'search_parameters': {'engine': 'google',
#   'q': 'Who won the latest Nobel Prize in Physics?',
#   'google_domain': 'google.com',
#   'hl': 'en',
#   'gl': 'us',
#   'device': 'desktop'},
#  'search_information': {'query_displayed': 'Who won the latest Nobel Prize in Physics?',
#   'total_results': 140000000,
#   'time_taken_displayed': 0.4,
#   'menu_items': [{'position': 1,
#     'title': '2023',
#     'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Who+won+the+latest+nobel+prize+in+physics+2023&uds=H4sIAAAAAAAA_-NK4WIxMjAyFtIKz8hXKM_PUyjJSFXISSxJLS5R8MtPSs1RCCjKrEpVyMxTCMioLM5MLrY3ECrSw6I6D6y6AKa6AKJaAWS6EQmmAwBVooJJkgAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQxKsJegQIDBAB&ictx=0',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+nobel+prize+in+physics+2023'},
#    {'position': 2,
#     'title': 'News',
#     'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&tbm=nws&source=lnms&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ0pQJegQICxAB',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&tbm=nws'},
#    {'position': 3,
#     'title': 'Images',
#     'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&uds=H4sIAAAAAAAA_-PK5WLzzE1MTy0W0grPyFcoz89TKMlIVchJLEktLlHwy09KzVEIKMqsSlXIzFMIyKgszkwutjdgs2KTYuFi4mAqIkHXDkZGIxKUAwBLbQdumwAAAA&udm=2&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQtKgLegQIChAB',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F'},
#    {'position': 4,
#     'title': 'Today',
#     'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Who+won+the+latest+nobel+prize+in+physics+today&uds=H4sIAAAAAAAA_-NK42INyU9JrBTSCs_IVyjPz1MoyUhVyEksSS0uUfDLT0rNUQgoyqxKVcjMUwjIqCzOTC62NxAq0seiOg-sugCmugCiWqEEZLwRCcYDABsRnyyUAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQxKsJegQICRAB&ictx=0',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+nobel+prize+in+physics+today'},
#    {'position': 5,
#     'title': 'Videos',
#     'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&tbm=vid&source=lnms&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ0pQJegQIUBAB',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_videos&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F'},
#    {'position': 6,
#     'title': 'Shopping',
#     'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&tbm=shop&source=lnms&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ0pQJegQIUxAB',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F'},
#    {'position': 7,
#     'title': 'Books',
#     'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&tbm=bks&source=lnms&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ0pQJegQIVBAB'},
#    {'position': 8,
#     'title': 'Maps',
#     'link': 'https://maps.google.com/maps?sca_esv=582259872&hl=en&gl=us&output=search&q=Who+won+the+latest+Nobel+Prize+in+Physics?&source=lnms&entry=mc&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ0pQJegQIUhAB'},
#    {'position': 9,
#     'title': 'Flights',
#     'link': 'https://www.google.com/travel/flights?sca_esv=582259872&hl=en&gl=us&output=search&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&source=lnms&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ0pQJegQIURAB'}],
#   'organic_results_state': 'Results for exact spelling'},
#  'inline_videos': [{'position': 1,
#    'title': 'Announcement of the 2023 Nobel Prize in Physics',
#    'link': 'https://www.google.com#',
#    'thumbnail': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/0e1094030f07419d1dc04ce95df85e6675b55a0721541dd687e7f207958d5990.jpeg',
#    'platform': 'YouTube',
#    'key_moments': [{'time': '03:28',
#      'title': 'Summary',
#      'link': 'https://www.youtube.com/watch?v=guNJjFRKQ9k&t=208'},
#     {'time': '03:34',
#      'title': 'Atto Second Physics',
#      'link': 'https://www.youtube.com/watch?v=guNJjFRKQ9k&t=214'},
#     {'time': '13:45',
#      'title': 'Applications',
#      'link': 'https://www.youtube.com/watch?v=guNJjFRKQ9k&t=825'},
#     {'time': '14:56',
#      'title': 'Molecular Fingerprinting Applied to Biological Samples',
#      'link': 'https://www.youtube.com/watch?v=guNJjFRKQ9k&t=896'},
#     {'time': '29:00',
#      'title': 'Questions to the Committee',
#      'link': 'https://www.youtube.com/watch?v=guNJjFRKQ9k&t=1740'},
#     {'time': '41:49',
#      'title': 'How Will this New Research Affect Our Lives',
#      'link': 'https://www.youtube.com/watch?v=guNJjFRKQ9k&t=2509'},
#     {'time': '42:26',
#      'title': 'Molecular Fingerprinting',
#      'link': 'https://www.youtube.com/watch?v=guNJjFRKQ9k&t=2546'}]},
#   {'position': 2,
#    'title': 'This Discovery Just Won the Nobel Prize in Physics',
#    'link': 'https://www.google.com#',
#    'thumbnail': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/0e1094030f07419d82824b5d5e84e304b08c6ff87a95daecb8961cd9e1222086.jpeg',
#    'platform': 'YouTube'},
#   {'position': 3,
#    'title': 'Nobel Prize in Physics 2023. First reactions from Nobel ...',
#    'link': 'https://www.google.com#',
#    'thumbnail': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/0e1094030f07419d878bb7cc75bd573ba4ef69a787551f7d2160c5e2a8bded36.jpeg',
#    'platform': 'YouTube'}],
#  'inline_people_also_search_for': [{'title': 'Nobel Prize categories',
#    'items': [{'name': 'Nobel Prize in Physics',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQAKL1uFrs-ynjlHTY6rX7Dma5gNRZAwvrm83hcTv7hj3EDb1EeORVI&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Prize+in+Physics&stick=H4sIAAAAAAAAAOOQUeLQz9U3SCkxtjQSy8tPSs1RKCjKrEpVSE4sSU3PL8pMLY7SDM_IVyjPz1MoyUhVyAGKF5co-IGVBoCVZuYpBGRUFmcmF59ihJsGZ5rAmSkpMKZpWm4lnGlceIqRE8Q0NCw3NfnFKIZsNsIZDSyMi1jFsNt7i02S4cCVzCVbhM8t1-Mv-5C2zeCt2fvs9lNPvk4DAPinKPXjAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAB6BAhDEAI',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Prize+in+Physics&stick=H4sIAAAAAAAAAOOQUeLQz9U3SCkxtjQSy8tPSs1RKCjKrEpVSE4sSU3PL8pMLY7SDM_IVyjPz1MoyUhVyAGKF5co-IGVBoCVZuYpBGRUFmcmF59ihJsGZ5rAmSkpMKZpWm4lnGlceIqRE8Q0NCw3NfnFKIZsNsIZDSyMi1jFsNt7i02S4cCVzCVbhM8t1-Mv-5C2zeCt2fvs9lNPvk4DAPinKPXjAAAA'},
#     {'name': 'Nobel Prize in Physiology or Medicine',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQAKL1uFrs-ynjlHTY6rX7Dma5gNRZAwvrm83hcTv7hj3EDb1EeORVI&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Prize+in+Physiology+or+Medicine&stick=H4sIAAAAAAAAAOOQUeLQz9U3SCkxsTQSy8tPSs1RKCjKrEpVSE4sSU3PL8pMLY7SDM_IVyjPz1MoyUhVyAGKF5co-IGVBoCVZuYpBGRUFmcmF59ihJpmbAlnmsCZKSkwpmlabiWcaVx4ipETxDQ0LDc1-cUohmw2whkNLIyLWFWx2Zufk59eqZBfpOCbmpKZnJmXeotNkuHAlcwlW4TPLdfjL_uQts3grdn77PZTT75OAwAx37NU8gAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAF6BAhDEAM',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Prize+in+Physiology+or+Medicine&stick=H4sIAAAAAAAAAOOQUeLQz9U3SCkxsTQSy8tPSs1RKCjKrEpVSE4sSU3PL8pMLY7SDM_IVyjPz1MoyUhVyAGKF5co-IGVBoCVZuYpBGRUFmcmF59ihJpmbAlnmsCZKSkwpmlabiWcaVx4ipETxDQ0LDc1-cUohmw2whkNLIyLWFWx2Zufk59eqZBfpOCbmpKZnJmXeotNkuHAlcwlW4TPLdfjL_uQts3grdn77PZTT75OAwAx37NU8gAAAA'},
#     {'name': 'Nobel Prize in Literature',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSREhD8XWH_pUnDoZLqXCKyOAFiOE7WDuB1m2kM&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Prize+in+Literature&stick=H4sIAAAAAAAAAOOQUeLQz9U3SElJsTQSy8tPSs1RKCjKrEpVSE4sSU3PL8pMLY7SDM_IVyjPz1MoyUhVyAGKF5co-IGVBoCVZuYpBGRUFmcmF59ihJhWYmwJZ5rAmUA7oEzTtNxKONO48BQjJ4hpaFhuavKLUQzZbIQzGlgYF7FKotnrk1mSWpRYUlqUeotNkuHAlcwlW4TPLdfjL_uQts3grdn77PZTT75OAwAVpaeW5gAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAJ6BAhDEAQ',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Prize+in+Literature&stick=H4sIAAAAAAAAAOOQUeLQz9U3SElJsTQSy8tPSs1RKCjKrEpVSE4sSU3PL8pMLY7SDM_IVyjPz1MoyUhVyAGKF5co-IGVBoCVZuYpBGRUFmcmF59ihJhWYmwJZ5rAmUA7oEzTtNxKONO48BQjJ4hpaFhuavKLUQzZbIQzGlgYF7FKotnrk1mSWpRYUlqUeotNkuHAlcwlW4TPLdfjL_uQts3grdn77PZTT75OAwAVpaeW5gAAAA'},
#     {'name': 'Nobel Prize in Chemistry',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQAKL1uFrs-ynjlHTY6rX7Dma5gNRZAwvrm83hcTv7hj3EDb1EeORVI&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Prize+in+Chemistry&stick=H4sIAAAAAAAAAOOQUeLQz9U3ME3LrTQSy8tPSs1RKCjKrEpVSE4sSU3PL8pMLY7SDM_IVyjPz1MoyUhVyAGKF5co-IGVBoCVZuYpBGRUFmcmF59iBJuWUmJsCWeawJkpKTAmyDo407jwFCMniGloWG5q8otRDNlshDMaWBgXsUqg2euckZqbWVxSVHmLTZLhwJXMJVuEzy3X4y_7kLbN4K3Z--z2U0--TgMA1_oCZeUAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAN6BAhDEAU',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Prize+in+Chemistry&stick=H4sIAAAAAAAAAOOQUeLQz9U3ME3LrTQSy8tPSs1RKCjKrEpVSE4sSU3PL8pMLY7SDM_IVyjPz1MoyUhVyAGKF5co-IGVBoCVZuYpBGRUFmcmF59iBJuWUmJsCWeawJkpKTAmyDo407jwFCMniGloWG5q8otRDNlshDMaWBgXsUqg2euckZqbWVxSVHmLTZLhwJXMJVuEzy3X4y_7kLbN4K3Z--z2U0--TgMA1_oCZeUAAAA'},
#     {'name': 'Nobel Peace Prize',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQb7LnV4_nbMCYLpveZU3hKCiH8vvqD342hDp85&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Peace+Prize&stick=H4sIAAAAAAAAAOOQUeLQz9U3ME0zLjQSy8tPSs1RKCjKrEpVSE4sSU3PL8pMLY7SDM_IVyjPz1MoyUhVyAGKF5co-IGVBoCVZuYpBGRUFmcmF59iBJuWUmJsCWeawJkpKTCmaVpuJZxpXHiKkRPENDQsNzX5xSiGbDbCGQ0sjItYBaFyqYnJqRAVt9gkGQ5cyVyyRfjccj3-sg9p2wzemr3Pbj_15Os0AJ1hRYveAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAR6BAhDEAY',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Peace+Prize&stick=H4sIAAAAAAAAAOOQUeLQz9U3ME0zLjQSy8tPSs1RKCjKrEpVSE4sSU3PL8pMLY7SDM_IVyjPz1MoyUhVyAGKF5co-IGVBoCVZuYpBGRUFmcmF59iBJuWUmJsCWeawJkpKTCmaVpuJZxpXHiKkRPENDQsNzX5xSiGbDbCGQ0sjItYBaFyqYnJqRAVt9gkGQ5cyVyyRfjccj3-sg9p2wzemr3Pbj_15Os0AJ1hRYveAAAA'},
#     {'name': 'Nobel Memorial Prize in Eco...',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSFx98eTP15fb83TNEjlojpXkBikCN2uMLfHgS_930xsY4l5jv4i1bf&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Memorial+Prize+in+Economic+Sciences&stick=H4sIAAAAAAAAAOOQUeLUz9U3MDQsNzUxEsvLT0rNUSgoyqxKVUhOLElNzy_KTC2O0gzPyFcoz89TKMlIVcgBiheXKPiBlQaAlWbmKQRkVBZnJhefYuQAGZdSYmwJZ5rAmSkpMKZpWm4lnGlceIoR4YpfjGLIZiOc0cDCuIhVEyLnm5oLFEtEcoBrcn5efm5mskJwcmZqXnJq8S02SYYDVzKXbBE-t1yPv-xD2jaDt2bvs9tPPfk6DQD2P5ne9wAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAV6BAhDEAc',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Memorial+Prize+in+Economic+Sciences&stick=H4sIAAAAAAAAAOOQUeLUz9U3MDQsNzUxEsvLT0rNUSgoyqxKVUhOLElNzy_KTC2O0gzPyFcoz89TKMlIVcgBiheXKPiBlQaAlWbmKQRkVBZnJhefYuQAGZdSYmwJZ5rAmSkpMKZpWm4lnGlceIoR4YpfjGLIZiOc0cDCuIhVEyLnm5oLFEtEcoBrcn5efm5mskJwcmZqXnJq8S02SYYDVzKXbBE-t1yPv-xD2jaDt2bvs9tPPfk6DQD2P5ne9wAAAA'}],
#    'see_more_link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Prize+categories&stick=H4sIAAAAAAAAAOOQMRLLy09KzVEoKMqsSlVITixJTc8vykwtjtIMz8hXKM_PUyjJSFXIAYoXlyj4gZUGgJVm5ikEZFQWZyYXn2Lk0M_VN0gpMbaEM03gzJQUGNM0LbcSzjQuPMXICWIaGpabmvxiFEM2G-GMBhbGRaw45G6xSTIcuJK5ZIvwueV6_GUf0rYZvDV7n91-6snXaQCG8qZz2QAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ4qYDegQIQxAI',
#    'see_more_serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Prize+categories&stick=H4sIAAAAAAAAAOOQMRLLy09KzVEoKMqsSlVITixJTc8vykwtjtIMz8hXKM_PUyjJSFXIAYoXlyj4gZUGgJVm5ikEZFQWZyYXn2Lk0M_VN0gpMbaEM03gzJQUGNM0LbcSzjQuPMXICWIaGpabmvxiFEM2G-GMBhbGRaw45G6xSTIcuJK5ZIvwueV6_GUf0rYZvDV7n91-6snXaQCG8qZz2QAAAA'},
#   {'title': '2022 Nobel Prize winners',
#    'items': [{'name': 'Alain Aspect',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcQtCnyHrWKpQUAfrXY2WUjhourBkoePVCHAGwsy5EsOUJuTUi4n69YO5R5nnCQAXLlnb10g659f&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Alain+Aspect&stick=H4sIAAAAAAAAAOOQUeLUz9U3MCkqSCkwkjAyMDJSyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xYgw8BQjF4htZFaSnl5xipEDxMnKLa-EiicbVxiap0A1GBeUmVdA2UZFJmbppxh59dP1DQ1LTIvLTXOz8qByScZpOekwdSZVSWm_GCHORnYO1NkNLIyLWHkccxKBznMsLkhNLrnFJslw4ErmkkqnbUxGgT-fOR2SmGBd5bj58mOXGwCHwTINDAEAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAB6BAhGEAI',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Alain+Aspect&stick=H4sIAAAAAAAAAOOQUeLUz9U3MCkqSCkwkjAyMDJSyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xYgw8BQjF4htZFaSnl5xipEDxMnKLa-EiicbVxiap0A1GBeUmVdA2UZFJmbppxh59dP1DQ1LTIvLTXOz8qByScZpOekwdSZVSWm_GCHORnYO1NkNLIyLWHkccxKBznMsLkhNLrnFJslw4ErmkkqnbUxGgT-fOR2SmGBd5bj58mOXGwCHwTINDAEAAA'},
#     {'name': 'Carolyn R. Bertozzi',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcSGAxtKjcpTokviNi1soUP8UusEVC3vToNPCQUyr4ah7YsFcb2KciKc8mqZe6iPJXG5m2w-Bmk&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Carolyn+Bertozzi&stick=H4sIAAAAAAAAAOOQUeLSz9U3MDIrSU-vMJIwMjAyUsjLT0rNUSgoyqxKVSjPzMtLLSqO0gzPyFcoz89TKMlIVchJLEktLlHwA6sLAKvLzFMIyKgszkwuPsXICTLRpKggpeAUI5Lppxg5QJys3PJKqHiycYWheQpUg3FBmXkFlG1UZGKWfoqRVz9d39CwxLS43DQ3Kw8ql2SclpMOU2dSlZT2ixHibGTnQJ3dwMK4iFXAObEoP6cyT8Eptagkv6oq8xabJMOBK5lLKp22MRkF_nzmdEhignWV4-bLj11uAAAS3Jy9EQEAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAF6BAhGEAM',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Carolyn+Bertozzi&stick=H4sIAAAAAAAAAOOQUeLSz9U3MDIrSU-vMJIwMjAyUsjLT0rNUSgoyqxKVSjPzMtLLSqO0gzPyFcoz89TKMlIVchJLEktLlHwA6sLAKvLzFMIyKgszkwuPsXICTLRpKggpeAUI5Lppxg5QJys3PJKqHiycYWheQpUg3FBmXkFlG1UZGKWfoqRVz9d39CwxLS43DQ3Kw8ql2SclpMOU2dSlZT2ixHibGTnQJ3dwMK4iFXAObEoP6cyT8Eptagkv6oq8xabJMOBK5lLKp22MRkF_nzmdEhignWV4-bLj11uAAAS3Jy9EQEAAA'},
#     {'name': 'Svante Pääbo',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcThJdquSmvYHl8o-R1NRgyDaYktxXBI3KdCMaVbZbhmkIoarJkcqNsU&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Svante+P%C3%A4%C3%A4bo&stick=H4sIAAAAAAAAAOOQUeLQz9U3yMotrzSSMDIwMlLIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FyAkyz6SoIKXgFCMXiG1kVpKeXnGKEW4RVDzZuMLQPAWqwbigzLwCyjYqMjFLP8XIq5-ub2hYYlpcbpqblQeVSzJOy0mHqTOpSkr7xQhxNrJzoM5uYGFcxMoXXJaYV5KqEHB4yeElSfm32CQZDlzJXFLptI3JKPDnM6dDEhOsqxw3X37scgMAJNg_tw0BAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAJ6BAhGEAQ',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Svante+P%C3%A4%C3%A4bo&stick=H4sIAAAAAAAAAOOQUeLQz9U3yMotrzSSMDIwMlLIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FyAkyz6SoIKXgFCMXiG1kVpKeXnGKEW4RVDzZuMLQPAWqwbigzLwCyjYqMjFLP8XIq5-ub2hYYlpcbpqblQeVSzJOy0mHqTOpSkr7xQhxNrJzoM5uYGFcxMoXXJaYV5KqEHB4yeElSfm32CQZDlzJXFLptI3JKPDnM6dDEhOsqxw3X37scgMAJNg_tw0BAAA'},
#     {'name': 'John Clauser',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcSFTNtE7eLlK4D9tKjkD6lrOgxjGD8tqrKtT3Tmf0PX3qzirLcoV1MQdcFeom3iqDyTeRrrzcA&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=John+Clauser&stick=H4sIAAAAAAAAAOOQUeLSz9U3SDauMDRPMZIwMjAyUsjLT0rNUSgoyqxKVSjPzMtLLSqO0gzPyFcoz89TKMlIVchJLEktLlHwA6sLAKvLzFMIyKgszkwuPsXICTLRpKggpeAUI9h0I7OS9PSKU4wcIE5WbnklVBxiK1SDcUGZeQWUbVRkYpZ-ipFXP13f0LDEtLjcNDcrDyqXZJyWkw5TZ1KVlPaLEeJsZOdAnd3AwriIlccrPyNPwTknsbQ4tegWmyTDgSuZSyqdtjEZBf585nRIYoJ1lePmy49dbgAA-wRYVg0BAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAN6BAhGEAU',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=John+Clauser&stick=H4sIAAAAAAAAAOOQUeLSz9U3SDauMDRPMZIwMjAyUsjLT0rNUSgoyqxKVSjPzMtLLSqO0gzPyFcoz89TKMlIVchJLEktLlHwA6sLAKvLzFMIyKgszkwuPsXICTLRpKggpeAUI9h0I7OS9PSKU4wcIE5WbnklVBxiK1SDcUGZeQWUbVRkYpZ-ipFXP13f0LDEtLjcNDcrDyqXZJyWkw5TZ1KVlPaLEeJsZOdAnd3AwriIlccrPyNPwTknsbQ4tegWmyTDgSuZSyqdtjEZBf585nRIYoJ1lePmy49dbgAA-wRYVg0BAAA'},
#     {'name': 'Anton Zeilinger',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRwiSDCzOGFZz1y4AmhmJ5Ad3_k8wxSSD8XJYXZDSCUl8KX9MyKHGEw&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Anton+Zeilinger&stick=H4sIAAAAAAAAAOOQUeLUz9U3MC4oM68wkjAyMDJSyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xQg20KSoIKXgFCMXiG1kVpKeXnGKkQPEycotr4SKJxtXGJqnQDWAXQBlGxWZmKWfYuTVT9c3NCwxLS43zc3Kg8olGaflpMPUmVQlpf1ihDgb2TlQZzewMC5i5XfMKwE6PCo1MyczLz216BabJMOBK5lLKp22MRkF_nzmdEhignWV4-bLj11uAAA9UGNEDwEAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAR6BAhGEAY',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Anton+Zeilinger&stick=H4sIAAAAAAAAAOOQUeLUz9U3MC4oM68wkjAyMDJSyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xQg20KSoIKXgFCMXiG1kVpKeXnGKkQPEycotr4SKJxtXGJqnQDWAXQBlGxWZmKWfYuTVT9c3NCwxLS43zc3Kg8olGaflpMPUmVQlpf1ihDgb2TlQZzewMC5i5XfMKwE6PCo1MyczLz216BabJMOBK5lLKp22MRkF_nzmdEhignWV4-bLj11uAAA9UGNEDwEAAA'},
#     {'name': 'Memorial',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQi8SogsuE_9PYCeUFiZVY_MrVAmsVEIgGLRy3t&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Memorial+(society)&stick=H4sIAAAAAAAAAOOQUeLUz9U3MCoyMUs3kjAyMDJSyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xQg20KSoIKXgFCMX2HCzkvT0ilOMHCBOVm55JVQ82bjC0DwFqsG4oMy8AsoGu-YUI69-ur6hYYlpcblpblYeVC7JOC0nHabOpCop7RcjxNnIzoE6u4GFcRGrkG9qbn5RZmKOgkZxfnJmakml5i02SYYDVzKXVDptYzIK_PnM6ZDEBOsqx82XH7vcAAD8kIJYEgEAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAV6BAhGEAc',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Memorial+%28society%29&stick=H4sIAAAAAAAAAOOQUeLUz9U3MCoyMUs3kjAyMDJSyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xQg20KSoIKXgFCMX2HCzkvT0ilOMHCBOVm55JVQ82bjC0DwFqsG4oMy8AsoGu-YUI69-ur6hYYlpcblpblYeVC7JOC0nHabOpCop7RcjxNnIzoE6u4GFcRGrkG9qbn5RZmKOgkZxfnJmakml5i02SYYDVzKXVDptYzIK_PnM6ZDEBOsqx82XH7vcAAD8kIJYEgEAAA'}],
#    'see_more_link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=2022+Nobel+Prize+winners&stick=H4sIAAAAAAAAAOOQMZIwMjAyUsjLT0rNUSgoyqxKVSjPzMtLLSqO0gzPyFcoz89TKMlIVchJLEktLlHwA6sLAKvLzFMIyKgszkwuPsXIqZ-rb2BSVJBScIqRC8Q2MitJT684xcgB4mTllldCxZONKwzNU6AajAvKzCugbKMiE7P0U4y8-un6hoYlpsXlprlZeVC5JOO0nHSYOpOqpLRfjBBnIzsH6uwGFsZFrDhlb7FJMhy4krmk0mkbk1Hgz2dOhyQmWFc5br782OUGAGL5ZXoNAQAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ4qYDegQIRhAI',
#    'see_more_serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=2022+Nobel+Prize+winners&stick=H4sIAAAAAAAAAOOQMZIwMjAyUsjLT0rNUSgoyqxKVSjPzMtLLSqO0gzPyFcoz89TKMlIVchJLEktLlHwA6sLAKvLzFMIyKgszkwuPsXIqZ-rb2BSVJBScIqRC8Q2MitJT684xcgB4mTllldCxZONKwzNU6AajAvKzCugbKMiE7P0U4y8-un6hoYlpsXlprlZeVC5JOO0nHSYOpOqpLRfjBBnIzsH6uwGFsZFrDhlb7FJMhy4krmk0mkbk1Hgz2dOhyQmWFc5br782OUGAGL5ZXoNAQAA'},
#   {'title': 'Nobel Peace Prize ceremony',
#    'items': [{'name': '2022 Nobel Peace Prize Ceremony',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ8m5S9QYht8Q44ABIZCjqgur_U-vSRbB0n3KNL&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=2022+Nobel+Peace+Prize&stick=H4sIAAAAAAAAAOOQUeLVT9c3NCyqzEnJMTErMpLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xYhqLIxfklJSWJhXUAXjZ5tUFqaVlBvB-HnFBqaWFQVmMH6GaW52WYaBAYyfllNVZl6YkwvjZ1nkZplmZFjA-Okl8fG5hQbJpxi59HP1DVJy8kqK06CcquL4iniDX4xSUCeDfRiA4sMGFsZFrGJGBkZGChiKbrFJMhy4krnEUidv1ket_T2z1hRVSIfPnXFuRfZxAAZU8axHAQAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAB6BAhEEAI',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=2022+Nobel+Peace+Prize&stick=H4sIAAAAAAAAAOOQUeLVT9c3NCyqzEnJMTErMpLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xYhqLIxfklJSWJhXUAXjZ5tUFqaVlBvB-HnFBqaWFQVmMH6GaW52WYaBAYyfllNVZl6YkwvjZ1nkZplmZFjA-Okl8fG5hQbJpxi59HP1DVJy8kqK06CcquL4iniDX4xSUCeDfRiA4sMGFsZFrGJGBkZGChiKbrFJMhy4krnEUidv1ket_T2z1hRVSIfPnXFuRfZxAAZU8axHAQAA'},
#     {'name': '2022 Nobel Prize in Physiology...',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRkGxAdNxOLWBK88qjKIzrQNH1ohOy4zy5lEkBO&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=2022+Nobel+Prize+in+Physiology+or+Medicine&stick=H4sIAAAAAAAAAOOQUeLVT9c3NCxJKSkszCuoMpLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxodZA-Nnm1QWppWUG8H4ecUGppYVBWYwfoZpbnZZhoEBjJ-WU1VmXpiTC-NnWeRmmWZkWMD46SXx8bmFBsmnGLn0c_UNUnLySorToJyq4viKeINfjFJQJ4N9GIDiwwYWxkWsWkYGRkZY_ZWfk59eqZBfpOCbmpKZnJmXeotNkuHAlcwlljp5sz5q7e-ZtaaoQjp87oxzK7KPAwAd33P8WwEAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAF6BAhEEAM',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=2022+Nobel+Prize+in+Physiology+or+Medicine&stick=H4sIAAAAAAAAAOOQUeLVT9c3NCxJKSkszCuoMpLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxodZA-Nnm1QWppWUG8H4ecUGppYVBWYwfoZpbnZZhoEBjJ-WU1VmXpiTC-NnWeRmmWZkWMD46SXx8bmFBsmnGLn0c_UNUnLySorToJyq4viKeINfjFJQJ4N9GIDiwwYWxkWsWkYGRkZY_ZWfk59eqZBfpOCbmpKZnJmXeotNkuHAlcwlljp5sz5q7e-ZtaaoQjp87oxzK7KPAwAd33P8WwEAAA'},
#     {'name': '2023 Nobel Peace Prize',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT7t4LHgPzBgo43ZXvnNQ4zXhZ7vkOGz3j-iJhq&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=2023+Nobel+Peace+Prize&stick=H4sIAAAAAAAAAOOQUeLVT9c3NMw2qSxMKyk3MpLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvFh1sL4ecUGppYVBWYwfoZpbnZZhoEBjJ-WU1VmXpiTC-NnWeRmmWZkWMD46SXx8bmFBsmnGLn0c_UNUnLySorToJyq4viKeINfjFJQJ4N9GIDiwwYWxkWsYkYGRsYKGIpusUkyHLiSucRSJ2_WR639PbPWFFVIh8-dcW5F9nEAExMcCUcBAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAJ6BAhEEAQ',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=2023+Nobel+Peace+Prize&stick=H4sIAAAAAAAAAOOQUeLVT9c3NMw2qSxMKyk3MpLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvFh1sL4ecUGppYVBWYwfoZpbnZZhoEBjJ-WU1VmXpiTC-NnWeRmmWZkWMD46SXx8bmFBsmnGLn0c_UNUnLySorToJyq4viKeINfjFJQJ4N9GIDiwwYWxkWsYkYGRsYKGIpusUkyHLiSucRSJ2_WR639PbPWFFVIh8-dcW5F9nEAExMcCUcBAAA'},
#     {'name': '2021 Nobel Peace Prize Ceremony',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSCJ-4wWEV6OxpddPCBGkxvkG9qFdCz5CvksmVj&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=2021+Nobel+Peace+Prize&stick=H4sIAAAAAAAAAOOQUeLVT9c3NMwrNjC1rCgwM5LKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvGzTSoL00rKjWB8mDNg_AzT3OyyDAMDGD8tp6rMvDAnF8bPssjNMs3IsIDx00vi43MLDZJPMXLp5-obpOTklRSnQTlVxfEV8Qa_GKWgTgb7MADFhw0sjItYxYwMjAwVMBTdYpNkOHAlc4mlTt6sj1r7e2atKaqQDp8749yK7OMAmGIUTkcBAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAN6BAhEEAU',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=2021+Nobel+Peace+Prize&stick=H4sIAAAAAAAAAOOQUeLVT9c3NMwrNjC1rCgwM5LKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvGzTSoL00rKjWB8mDNg_AzT3OyyDAMDGD8tp6rMvDAnF8bPssjNMs3IsIDx00vi43MLDZJPMXLp5-obpOTklRSnQTlVxfEV8Qa_GKWgTgb7MADFhw0sjItYxYwMjAwVMBTdYpNkOHAlc4mlTt6sj1r7e2atKaqQDp8749yK7OMAmGIUTkcBAAA'},
#     {'name': '2019 Nobel Peace Prize Ceremony',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSAtphVL3YJZmvwpqpBVV6ZqyI1qoB2DqUJyDeK&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=2019+Nobel+Peace+Prize+Ceremony&stick=H4sIAAAAAAAAAOOQUeLVT9c3NMwwzc0uyzAwMJLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvGzTSoL00rKjWD8vGIDU8uKAjMYH-YsGD8tp6rMvDAnF8bPssjNMs3IsIDx00vi43MLDZJPMXLp5-obpOTklRSnQTlVxfEV8Qa_GKWgTgb7MADFhw0sjItY5Y0MDC0VMBU5QxXdYpNkOHAlc4mlTt6sj1r7e2atKaqQDp8749yK7OMAZNRZ9lABAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAR6BAhEEAY',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=2019+Nobel+Peace+Prize+Ceremony&stick=H4sIAAAAAAAAAOOQUeLVT9c3NMwwzc0uyzAwMJLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvGzTSoL00rKjWD8vGIDU8uKAjMYH-YsGD8tp6rMvDAnF8bPssjNMs3IsIDx00vi43MLDZJPMXLp5-obpOTklRSnQTlVxfEV8Qa_GKWgTgb7MADFhw0sjItY5Y0MDC0VMBU5QxXdYpNkOHAlc4mlTt6sj1r7e2atKaqQDp8749yK7OMAZNRZ9lABAAA'},
#     {'name': '2019 Nobel Prize',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSEW5ei0qMEZokIVYMmSwbCWH0TaADGyimP8Hwd&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=2019+Nobel+Prize&stick=H4sIAAAAAAAAAOOQUeLVT9c3NEzLqSozL8zJNZLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvGzTSoL00rKjWD8vGIDU8uKAjMYP8M0N7ssw8AAxoc5E8bPssjNMs3IsIDx00vi43MLDZJPMXLp5-obpOTklRSnQTlVxfEV8Qa_GKWgTgb7MADFhw0sjItYBYwMDC2R_XWLTZLhwJXMJZY6ebM-au3vmbWmqEI6fO6McyuyjwMAz8o1TUEBAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAV6BAhEEAc',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=2019+Nobel+Prize&stick=H4sIAAAAAAAAAOOQUeLVT9c3NEzLqSozL8zJNZLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvGzTSoL00rKjWD8vGIDU8uKAjMYP8M0N7ssw8AAxoc5E8bPssjNMs3IsIDx00vi43MLDZJPMXLp5-obpOTklRSnQTlVxfEV8Qa_GKWgTgb7MADFhw0sjItYBYwMDC2R_XWLTZLhwJXMJZY6ebM-au3vmbWmqEI6fO6McyuyjwMAz8o1TUEBAAA'}],
#    'see_more_link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Peace+Prize+ceremony&stick=H4sIAAAAAAAAAOOQMZLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xcirn65vaFhUmZOSY2JWBOOXpJQUFuYVVMH42SaVhWkl5UYwfl6xgallRYEZjJ9hmptdlmFgAOOn5VSVmRfm5ML4WRa5WaYZGRYwfnpJfHxuoUHyKUYu_Vx9g5ScvJLiNCinqji-It7gF6MU1MlgHwag-LCBhXERKx75W2ySDAeuZC6x1Mmb9VFrf8-sNUUV0uFzZ5xbkX0cAMhJ3NQ8AQAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ4qYDegQIRBAI',
#    'see_more_serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Peace+Prize+ceremony&stick=H4sIAAAAAAAAAOOQMZLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xcirn65vaFhUmZOSY2JWBOOXpJQUFuYVVMH42SaVhWkl5UYwfl6xgallRYEZjJ9hmptdlmFgAOOn5VSVmRfm5ML4WRa5WaYZGRYwfnpJfHxuoUHyKUYu_Vx9g5ScvJLiNCinqji-It7gF6MU1MlgHwag-LCBhXERKx75W2ySDAeuZC6x1Mmb9VFrf8-sNUUV0uFzZ5xbkX0cAMhJ3NQ8AQAA'},
#   {'title': 'Indian Nobel Prize winners',
#    'items': [{'name': 'C. V. Raman',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcTcQjSpOKrYdOzFu_gTHnMaUAkB0xI_OavLnOtKmXTqM_Ejdpke1aFbn2gYR5-A1HojBrrOL-k&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=C.+V.+Raman&stick=H4sIAAAAAAAAAOOQUeLUz9U3MCxIqSw0ksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FiDASyk4xyE3KOsXIAWZnFSZDhY3McjNMTzFygdgmWZY5JYZQjpGZRbGBxS9GKU-Ig5AtgjqogYVxESu3s55CmJ5CUGJuYt4tNkmGA1cyl7gUPvz0hz_h5asmxvZZMpoBjOzPPACaQf6F5wAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAB6BAhHEAI',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=C.+V.+Raman&stick=H4sIAAAAAAAAAOOQUeLUz9U3MCxIqSw0ksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FiDASyk4xyE3KOsXIAWZnFSZDhY3McjNMTzFygdgmWZY5JYZQjpGZRbGBxS9GKU-Ig5AtgjqogYVxESu3s55CmJ5CUGJuYt4tNkmGA1cyl7gUPvz0hz_h5asmxvZZMpoBjOzPPACaQf6F5wAAAA'},
#     {'name': 'Rabindrana... Tagore',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcR6Ovz7oy46JnCip2u4ScQGioDaDbEsnLc9jLdLx2dxadZKLKvxJXvn4HkplnzgWBOETGV-Hf4&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Rabindranath+Tagore&stick=H4sIAAAAAAAAAOOQUeLUz9U3SDHITcoyksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FCDbSsCClshDKBht_ipEDzM4qTIYKG5nlZpieYuQCsU2yLHNKDKEcIzOLYgOLX4xSnhAHIVsEdVADC-MiVuGgxCSgm4sS8xJLMhRCEtPzi1JvsUkyHLiSucSl8OGnP_wJL181MbbPktEMYGR_5gEAgJuICO8AAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAF6BAhHEAM',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Rabindranath+Tagore&stick=H4sIAAAAAAAAAOOQUeLUz9U3SDHITcoyksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FCDbSsCClshDKBht_ipEDzM4qTIYKG5nlZpieYuQCsU2yLHNKDKEcIzOLYgOLX4xSnhAHIVsEdVADC-MiVuGgxCSgm4sS8xJLMhRCEtPzi1JvsUkyHLiSucSl8OGnP_wJL181MbbPktEMYGR_5gEAgJuICO8AAAA'},
#     {'name': 'Amartya Sen',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcQPqc5MWScQarbHSB-1cHscpMvjr-RA_Oe1u4lJRGG50XtbLHnadHnBytS3ODMMcxsPFkZQqsc&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Amartya+Sen&stick=H4sIAAAAAAAAAOOQUeLQz9U3SMkqTDaSysxLyUzMU8jLT0rNUSgoyqxKVSjPzMtLLSqO0gzPyFcoz89TKMlIVchJLEktLlHwA6sLAKvLzFMIyKgszkwuPsXICTLRsCClshDKTjHITco6xQi3CSpsZJabYXqKkQvENsmyzCkxhHKMzCyKDSx-MUp5QhyEbBHUQQ0sjItYuR1zE4tKKhMVglPzbrFJMhy4krnEpfDhpz_8CS9fNTG2z5LRDGBkf-YBAM_b4DbmAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAJ6BAhHEAQ',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Amartya+Sen&stick=H4sIAAAAAAAAAOOQUeLQz9U3SMkqTDaSysxLyUzMU8jLT0rNUSgoyqxKVSjPzMtLLSqO0gzPyFcoz89TKMlIVchJLEktLlHwA6sLAKvLzFMIyKgszkwuPsXICTLRsCClshDKTjHITco6xQi3CSpsZJabYXqKkQvENsmyzCkxhHKMzCyKDSx-MUp5QhyEbBHUQQ0sjItYuR1zE4tKKhMVglPzbrFJMhy4krnEpfDhpz_8CS9fNTG2z5LRDGBkf-YBAM_b4DbmAAAA'},
#     {'name': 'Har Gobind Khorana',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcTNzmDldRAzqSX7_U1ha4y_pqIVJyB_9A30utqPnLtxFByvof-f3o99uyZjLyNDZQ2KSZvT4eE&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Har+Gobind+Khorana&stick=H4sIAAAAAAAAAOOQUeLUz9U3MDLLzTA1ksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FCDbSsCClshDKTjHITco6xcgBZmcVJkOFwbaeYuQCsU2yLHNKDKEcIzOLYgOLX4xSnhAHIVsEdVADC-MiViGPxCIF9_wkoLsVvDPyixLzEm-xSTIcuJK5xKXw4ac__AkvXzUxts-S0QxgZH_mAQC8pWi07gAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAN6BAhHEAU',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Har+Gobind+Khorana&stick=H4sIAAAAAAAAAOOQUeLUz9U3MDLLzTA1ksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FCDbSsCClshDKTjHITco6xcgBZmcVJkOFwbaeYuQCsU2yLHNKDKEcIzOLYgOLX4xSnhAHIVsEdVADC-MiViGPxCIF9_wkoLsVvDPyixLzEm-xSTIcuJK5xKXw4ac__AkvXzUxts-S0QxgZH_mAQC8pWi07gAAAA'},
#     {'name': 'Abhijit Banerjee',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcTN1BGhpiGYPYwyApE3lWGjRzX2-BNj6FrierSdxhdQZMDS_0THL78ECSmGvAP_LTE8AawfXRqG&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Abhijit+Banerjee&stick=H4sIAAAAAAAAAOOQUeLSz9U3MMmyzCkxNJLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcgJMtOwIKWyEMpOMchNyjrFyAFmZxUmQ4WNzHIzTE8xIjkByjEysyg2sPjFKOUJcRCyRVAHNbAwLmIVcEzKyMzKLFFwSgSKZaWm3mKTZDhwJXOJS-HDT3_4E16-amJsnyWjGcDI_swDAI8HWDftAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAR6BAhHEAY',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Abhijit+Banerjee&stick=H4sIAAAAAAAAAOOQUeLSz9U3MMmyzCkxNJLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcgJMtOwIKWyEMpOMchNyjrFyAFmZxUmQ4WNzHIzTE8xIjkByjEysyg2sPjFKOUJcRCyRVAHNbAwLmIVcEzKyMzKLFFwSgSKZaWm3mKTZDhwJXOJS-HDT3_4E16-amJsnyWjGcDI_swDAI8HWDftAAAA'},
#     {'name': 'Kailash Satyarthi',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ37txF6T8wi2_1QrAtc2L2RJLW2Yfn5pRfharpt8yIX9TlUVAwb4F4&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Kailash+Satyarthi&stick=H4sIAAAAAAAAAOOQUeLSz9U3MDKzKDawMJLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcgJMtOwIKWyEMpOMchNyjrFyAFmZxUmQ4WNzHIzTE8xgp1gkmWZU2II5UDc84tRyhPiIGSLoA5qYGFcxCronZiZk1icoRCcWFKZWFSSkXmLTZLhwJXMJS6FDz_94U94-aqJsX2WjGYAI_szDwA-pbRq7gAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAV6BAhHEAc',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Kailash+Satyarthi&stick=H4sIAAAAAAAAAOOQUeLSz9U3MDKzKDawMJLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcgJMtOwIKWyEMpOMchNyjrFyAFmZxUmQ4WNzHIzTE8xgp1gkmWZU2II5UDc84tRyhPiIGSLoA5qYGFcxCronZiZk1icoRCcWFKZWFSSkXmLTZLhwJXMJS6FDz_94U94-aqJsX2WjGYAI_szDwA-pbRq7gAAAA'}],
#    'see_more_link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Indian+Nobel+Prize+winners&stick=H4sIAAAAAAAAAOOQMZLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcipn6tvYFiQUlkIZacY5CZlnWLkALOzCpOhwkZmuRmmpxi5QGyTLMucEkMox8jMotjA4hejlCfEQcgWQR3UwMK4iBWP_C02SYYDVzKXuBQ-_PSHP-HlqybG9lkymgGM7M88AAjgshPrAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ4qYDegQIRxAI',
#    'see_more_serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Indian+Nobel+Prize+winners&stick=H4sIAAAAAAAAAOOQMZLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcipn6tvYFiQUlkIZacY5CZlnWLkALOzCpOhwkZmuRmmpxi5QGyTLMucEkMox8jMotjA4hejlCfEQcgWQR3UwMK4iBWP_C02SYYDVzKXuBQ-_PSHP-HlqybG9lkymgGM7M88AAjgshPrAAAA'}],
#  'related_questions': [{'question': 'Who won Nobel Prize 2023 in Physics?',
#    'snippet': "The 2023 Nobel Prize in Physics has been awarded to Pierre Agostini, Ferenc Krausz, and Anne L'Huillier “for experimental methods that generate attosecond pulses of light for the study of electro dynamics in matter”, The Royal Swedish Academy of Science announced on October 3, 2023.",
#    'title': 'Nobel Prize in Physics 2023: Three scientists win for research ...',
#    'date': 'Oct 3, 2023',
#    'link': 'https://www.thehindu.com/sci-tech/science/nobel-prize-physics-winner-2023-pierre-agostini-ferenc-krausz-anne-lhuillier/article67374928.ece',
#    'displayed_link': 'https://www.thehindu.com › Sci-Tech › Science',
#    'thumbnail': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/2917fabe161e0d3c58f2e4fee682b86bf2ec80c5e9f89982cd9c137d10300fa9.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D%3D'},
#   {'question': 'Who won the last Nobel Prize Physics?',
#    'snippet': "Nobel Prize in Physics Awarded to 3 Scientists for Illuminating How Electrons Move. Techniques resulting from the work of Pierre Agostini, Ferenc Krausz and Anne L'Huillier let scientists capture the motions of subatomic particles moving at impossible speeds.",
#    'title': 'Nobel Prize in Physics Awarded to 3 Scientists for Illuminating ...',
#    'date': 'Oct 3, 2023',
#    'link': 'https://www.nytimes.com/2023/10/03/science/nobel-prize-physics.html',
#    'displayed_link': 'https://www.nytimes.com › 2023/10/03 › science › nobel...',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT4RKdHYIV_IEd1H1dcaFM9FeBEYLh5f0VJfkNxcJiR&s',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%'},
#   {'question': 'Who won the Nobel Prize in Physics 2023 attosecond?',
#    'snippet': "The 2023 Nobel Prize in Physics has been awarded to three researchers for their contributions to attosecond science. The prize honors Pierre Agostini of the Ohio State University, Ferenc Krausz of the Max Planck Institute of Quantum Optics, and Anne L'Huillier of Lund University.",
#    'title': 'Nobel Prize in Physics awarded to 3 for achievements in attosecond ...',
#    'date': 'Oct 9, 2023',
#    'link': 'https://pubs.acs.org/doi/10.1021/cen-10133-scicon2',
#    'displayed_link': 'https://pubs.acs.org › doi › cen-10133-scicon2',
#    'thumbnail': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/2917fabe161e0d3c58f2e4fee682b86b01ba8fe3b37f936ca1cf43e0ecf80445.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D%3D'},
#   {'question': 'Who won the Nobel Prize for Physics 20222?',
#    'snippet': 'The Royal Swedish Academy of Sciences has decided to award the Nobel Prize in Physics 2022 to. and École Polytechnique, Palaiseau, France. Born 1942 in Pasadena, CA, USA.',
#    'title': 'The Nobel Prize in Physics 2022 - Popular science background',
#    'link': 'https://www.nobelprize.org/prizes/physics/2022/popular-information/',
#    'displayed_link': 'https://www.nobelprize.org › prizes › popular-information',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcThOeWCZVb3hmAX842bCLhx8ePqx8-s4dq3akQMtyisrw&s',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D'}],
#  'answer_box': {'type': 'organic_result',
#   'title': 'The Nobel Prize in Physics 2023 - NobelPrize.org',
#   'link': 'https://www.nobelprize.org/prizes/physics/2023/summary/',
#   'displayed_link': 'https://www.nobelprize.org › prizes › physics › summary',
#   'date': 'Oct 3, 2023',
#   'snippet': 'The Nobel Prize in Physics 2023',
#   'snippet_highlighted_words': ['The Nobel Prize in Physics 2023'],
#   'list': ['Niklas Elmehed © Nobel Prize Outreach. Pierre Agostini. Prize share: 1/3.',
#    'Niklas Elmehed © Nobel Prize Outreach. Ferenc Krausz. Prize share: 1/3.',
#    "Niklas Elmehed © Nobel Prize Outreach. Anne L'Huillier. Prize share: 1/3."],
#   'favicon': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/6b9ac23c08437f9eb15fad54af13cc6505d7b6be295f612a.png',
#   'source': 'Nobel Prize',
#   'about_this_result': {}},
#  'organic_results': [{'position': 1,
#    'title': 'Nobel Prize in Physics Laureates',
#    'link': 'https://www.nobelprize.org/prizes/physics/',
#    'displayed_link': 'https://www.nobelprize.org › prizes › physics',
#    'favicon': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/4e5d582d767d9d9ff0e6e326fb7dbc81808756a8f2720d10a81c698d828cc35a.png',
#    'snippet': 'The three Nobel Prize laureates in physics 2023 are being recognised for ... Read what caused the Royal Swedish Academy of Sciences to exclaim, “Here, at last!',
#    'snippet_highlighted_words': ['Nobel Prize laureates in physics', 'last'],
#    'sitelinks': {'inline': [{'title': 'All Nobel Prizes in Physics',
#       'link': 'https://www.nobelprize.org/prizes/lists/all-nobel-prizes-in-physics/'},
#      {'title': '2022',
#       'link': 'https://www.nobelprize.org/prizes/physics/2022/summary/'},
#      {'title': 'Press release',
#       'link': 'https://www.nobelprize.org/prizes/physics/2023/press-release/'},
#      {'title': 'The Nobel Prize in Physics 2023',
#       'link': 'https://www.nobelprize.org/prizes/physics/2023/summary/'}]},
#    'about_page_link': 'https://www.google.com/search?q=About+https://www.nobelprize.org/prizes/physics/&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fwww.nobelprize.org%2Fprizes%2Fphysics%2F',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:b9Q1qbTvxJUJ:https://www.nobelprize.org/prizes/physics/&hl=en&gl=us',
#    'source': 'Nobel Prize'},
#   {'position': 2,
#    'title': 'All Nobel Prizes in Physics',
#    'link': 'https://www.nobelprize.org/prizes/lists/all-nobel-prizes-in-physics/',
#    'displayed_link': 'https://www.nobelprize.org › prizes › lists › all-nobel-...',
#    'favicon': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/4e5d582d767d9d9ff0e6e326fb7dbc812adb51b635cd805e2ca0b03fb406f7b3.png',
#    'snippet': 'The Nobel Prize in Physics has been awarded 117 times to 225 Nobel Prize laureates between 1901 and 2023. John Bardeen is the only laureate who has been ...',
#    'snippet_highlighted_words': ['Nobel Prize in Physics',
#     'been awarded',
#     'laureates',
#     'laureate',
#     'been'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://www.nobelprize.org/prizes/lists/all-nobel-prizes-in-physics/&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fwww.nobelprize.org%2Fprizes%2Flists%2Fall-nobel-prizes-in-physics%2F',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:SKmMaHQT4AcJ:https://www.nobelprize.org/prizes/lists/all-nobel-prizes-in-physics/&hl=en&gl=us',
#    'source': 'Nobel Prize'},
#   {'position': 3,
#    'title': 'The official website of the Nobel Prize - NobelPrize.org',
#    'link': 'https://www.nobelprize.org/',
#    'displayed_link': 'https://www.nobelprize.org',
#    'favicon': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/4e5d582d767d9d9ff0e6e326fb7dbc811164c4aba4deb1c429033e90b50385f7.png',
#    'snippet': "The Nobel Prize in Physics 2023 was awarded to Pierre Agostini, Ferenc ... Last year's laureates. 14 laureates were awarded Nobel Prizes in 2022. See a short ...",
#    'snippet_highlighted_words': ['Nobel Prize in Physics',
#     'was awarded',
#     'Last',
#     'laureates',
#     'laureates',
#     'awarded'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://www.nobelprize.org/&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fwww.nobelprize.org%2F',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:lkkS60DsvfQJ:https://www.nobelprize.org/&hl=en&gl=us',
#    'source': 'Nobel Prize'},
#   {'position': 4,
#    'title': 'The Nobel Prize in Physics 2022 - NobelPrize.org',
#    'link': 'https://www.nobelprize.org/prizes/physics/2022/summary/',
#    'displayed_link': 'https://www.nobelprize.org › physics › summary',
#    'favicon': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/4e5d582d767d9d9ff0e6e326fb7dbc814c66f345369abecf4dab05c178caeded.png',
#    'date': 'Oct 4, 2022',
#    'snippet': 'The Nobel Prize in Physics 2022 was awarded jointly to Alain Aspect, John F. Clauser and Anton Zeilinger "for experiments with entangled ...',
#    'snippet_highlighted_words': ['Nobel Prize in Physics', 'was awarded'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://www.nobelprize.org/prizes/physics/2022/summary/&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fwww.nobelprize.org%2Fprizes%2Fphysics%2F2022%2Fsummary%2F',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:NngHcueNRXIJ:https://www.nobelprize.org/prizes/physics/2022/summary/&hl=en&gl=us',
#    'source': 'Nobel Prize'},
#   {'position': 5,
#    'title': 'All Nobel Prizes',
#    'link': 'https://www.nobelprize.org/prizes/lists/all-nobel-prizes/',
#    'displayed_link': 'https://www.nobelprize.org › prizes › lists › all-nobel-...',
#    'favicon': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/4e5d582d767d9d9ff0e6e326fb7dbc8123c51003f30077502e933a062e1e9f4b.png',
#    'snippet': 'Below, you can view the full list of Nobel Prizes and Nobel Prize laureates. Find all prizes in | physics | chemistry | physiology or medicine | literature | ...',
#    'snippet_highlighted_words': ['Nobel Prizes',
#     'Nobel Prize laureates',
#     'prizes',
#     'physics'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://www.nobelprize.org/prizes/lists/all-nobel-prizes/&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fwww.nobelprize.org%2Fprizes%2Flists%2Fall-nobel-prizes%2F',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:0NgdAuHkgFgJ:https://www.nobelprize.org/prizes/lists/all-nobel-prizes/&hl=en&gl=us',
#    'source': 'Nobel Prize'},
#   {'position': 6,
#    'title': 'Trio wins Nobel Prize in physics for split-second glimpse of ...',
#    'link': 'https://apnews.com/article/physics-nobel-prize-stockholm-73b17b0f2c417a51f9d71964b170a395',
#    'displayed_link': 'https://apnews.com › article › physics-nobel-prize-stoc...',
#    'favicon': 'https://serpapi.com/searches/65536ab495bf92860dee7a18/images/4e5d582d767d9d9ff0e6e326fb7dbc815c62fcaa7ba2b3cc452405ee6bc4dfa3.png',
#    'date': 'Oct 3, 2023',
#    'snippet': 'Three scientists won the Nobel Prize in physics for their work on how electrons zip around the atom during the tiniest fractions of seconds.',
#    'snippet_highlighted_words': ['won', 'Nobel Prize in physics'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://apnews.com/article/physics-nobel-prize-stockholm-73b17b0f2c417a51f9d71964b170a395&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fapnews.com%2Farticle%2Fphysics-nobel-prize-stockholm-73b17b0f2c417a51f9d71964b170a395',
# ...
#     {'name': '2019 Nobel Peace Prize Ceremony',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSAtphVL3YJZmvwpqpBVV6ZqyI1qoB2DqUJyDeK&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=2019+Nobel+Peace+Prize+Ceremony&stick=H4sIAAAAAAAAAOOQUeLVT9c3NMwwzc0uyzAwMJLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvGzTSoL00rKjWD8vGIDU8uKAjMYH-YsGD8tp6rMvDAnF8bPssjNMs3IsIDx00vi43MLDZJPMXLp5-obpOTklRSnQTlVxfEV8Qa_GKWgTgb7MADFhw0sjItY5Y0MDC0VMBU5QxXdYpNkOHAlc4mlTt6sj1r7e2atKaqQDp8749yK7OMAZNRZ9lABAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAR6BAhEEAY',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=2019+Nobel+Peace+Prize+Ceremony&stick=H4sIAAAAAAAAAOOQUeLVT9c3NMwwzc0uyzAwMJLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvGzTSoL00rKjWD8vGIDU8uKAjMYH-YsGD8tp6rMvDAnF8bPssjNMs3IsIDx00vi43MLDZJPMXLp5-obpOTklRSnQTlVxfEV8Qa_GKWgTgb7MADFhw0sjItY5Y0MDC0VMBU5QxXdYpNkOHAlc4mlTt6sj1r7e2atKaqQDp8749yK7OMAZNRZ9lABAAA'},
#     {'name': '2019 Nobel Prize',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSEW5ei0qMEZokIVYMmSwbCWH0TaADGyimP8Hwd&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=2019+Nobel+Prize&stick=H4sIAAAAAAAAAOOQUeLVT9c3NEzLqSozL8zJNZLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvGzTSoL00rKjWD8vGIDU8uKAjMYP8M0N7ssw8AAxoc5E8bPssjNMs3IsIDx00vi43MLDZJPMXLp5-obpOTklRSnQTlVxfEV8Qa_GKWgTgb7MADFhw0sjItYBYwMDC2R_XWLTZLhwJXMJZY6ebM-au3vmbWmqEI6fO6McyuyjwMAz8o1TUEBAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAV6BAhEEAc',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=2019+Nobel+Prize&stick=H4sIAAAAAAAAAOOQUeLVT9c3NEzLqSozL8zJNZLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xQgxtqgyJyXHxKwIxi9JKSkszCuogvGzTSoL00rKjWD8vGIDU8uKAjMYP8M0N7ssw8AAxoc5E8bPssjNMs3IsIDx00vi43MLDZJPMXLp5-obpOTklRSnQTlVxfEV8Qa_GKWgTgb7MADFhw0sjItYBYwMDC2R_XWLTZLhwJXMJZY6ebM-au3vmbWmqEI6fO6McyuyjwMAz8o1TUEBAAA'}],
#    'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Peace+Prize+ceremony&stick=H4sIAAAAAAAAAOOQMZLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xcirn65vaFhUmZOSY2JWBOOXpJQUFuYVVMH42SaVhWkl5UYwfl6xgallRYEZjJ9hmptdlmFgAOOn5VSVmRfm5ML4WRa5WaYZGRYwfnpJfHxuoUHyKUYu_Vx9g5ScvJLiNCinqji-It7gF6MU1MlgHwag-LCBhXERKx75W2ySDAeuZC6x1Mmb9VFrf8-sNUUV0uFzZ5xbkX0cAMhJ3NQ8AQAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ4qYDegQIRBAI',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Peace+Prize+ceremony&stick=H4sIAAAAAAAAAOOQMZLKy09KzVEoSE1MTlUoKMqsSlVITi1Kzc3Pq4zSDM_IVyjPz1MoyUhVyEksSS0uUfADKw8AK8zMUwjIqCzOTC4-xcirn65vaFhUmZOSY2JWBOOXpJQUFuYVVMH42SaVhWkl5UYwfl6xgallRYEZjJ9hmptdlmFgAOOn5VSVmRfm5ML4WRa5WaYZGRYwfnpJfHxuoUHyKUYu_Vx9g5ScvJLiNCinqji-It7gF6MU1MlgHwag-LCBhXERKx75W2ySDAeuZC6x1Mmb9VFrf8-sNUUV0uFzZ5xbkX0cAMhJ3NQ8AQAA'},
#   {'block_position': 1,
#    'query': 'Indian Nobel Prize winners',
#    'items': [{'name': 'C. V. Raman',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcTcQjSpOKrYdOzFu_gTHnMaUAkB0xI_OavLnOtKmXTqM_Ejdpke1aFbn2gYR5-A1HojBrrOL-k&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=C.+V.+Raman&stick=H4sIAAAAAAAAAOOQUeLUz9U3MCxIqSw0ksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FiDASyk4xyE3KOsXIAWZnFSZDhY3McjNMTzFygdgmWZY5JYZQjpGZRbGBxS9GKU-Ig5AtgjqogYVxESu3s55CmJ5CUGJuYt4tNkmGA1cyl7gUPvz0hz_h5asmxvZZMpoBjOzPPACaQf6F5wAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAB6BAhHEAI',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=C.+V.+Raman&stick=H4sIAAAAAAAAAOOQUeLUz9U3MCxIqSw0ksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FiDASyk4xyE3KOsXIAWZnFSZDhY3McjNMTzFygdgmWZY5JYZQjpGZRbGBxS9GKU-Ig5AtgjqogYVxESu3s55CmJ5CUGJuYt4tNkmGA1cyl7gUPvz0hz_h5asmxvZZMpoBjOzPPACaQf6F5wAAAA'},
#     {'name': 'Rabindrana... Tagore',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcR6Ovz7oy46JnCip2u4ScQGioDaDbEsnLc9jLdLx2dxadZKLKvxJXvn4HkplnzgWBOETGV-Hf4&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Rabindranath+Tagore&stick=H4sIAAAAAAAAAOOQUeLUz9U3SDHITcoyksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FCDbSsCClshDKBht_ipEDzM4qTIYKG5nlZpieYuQCsU2yLHNKDKEcIzOLYgOLX4xSnhAHIVsEdVADC-MiVuGgxCSgm4sS8xJLMhRCEtPzi1JvsUkyHLiSucSl8OGnP_wJL181MbbPktEMYGR_5gEAgJuICO8AAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAF6BAhHEAM',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Rabindranath+Tagore&stick=H4sIAAAAAAAAAOOQUeLUz9U3SDHITcoyksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FCDbSsCClshDKBht_ipEDzM4qTIYKG5nlZpieYuQCsU2yLHNKDKEcIzOLYgOLX4xSnhAHIVsEdVADC-MiVuGgxCSgm4sS8xJLMhRCEtPzi1JvsUkyHLiSucSl8OGnP_wJL181MbbPktEMYGR_5gEAgJuICO8AAAA'},
#     {'name': 'Amartya Sen',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcQPqc5MWScQarbHSB-1cHscpMvjr-RA_Oe1u4lJRGG50XtbLHnadHnBytS3ODMMcxsPFkZQqsc&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Amartya+Sen&stick=H4sIAAAAAAAAAOOQUeLQz9U3SMkqTDaSysxLyUzMU8jLT0rNUSgoyqxKVSjPzMtLLSqO0gzPyFcoz89TKMlIVchJLEktLlHwA6sLAKvLzFMIyKgszkwuPsXICTLRsCClshDKTjHITco6xQi3CSpsZJabYXqKkQvENsmyzCkxhHKMzCyKDSx-MUp5QhyEbBHUQQ0sjItYuR1zE4tKKhMVglPzbrFJMhy4krnEpfDhpz_8CS9fNTG2z5LRDGBkf-YBAM_b4DbmAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAJ6BAhHEAQ',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Amartya+Sen&stick=H4sIAAAAAAAAAOOQUeLQz9U3SMkqTDaSysxLyUzMU8jLT0rNUSgoyqxKVSjPzMtLLSqO0gzPyFcoz89TKMlIVchJLEktLlHwA6sLAKvLzFMIyKgszkwuPsXICTLRsCClshDKTjHITco6xQi3CSpsZJabYXqKkQvENsmyzCkxhHKMzCyKDSx-MUp5QhyEbBHUQQ0sjItYuR1zE4tKKhMVglPzbrFJMhy4krnEpfDhpz_8CS9fNTG2z5LRDGBkf-YBAM_b4DbmAAAA'},
#     {'name': 'Har Gobind Khorana',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcTNzmDldRAzqSX7_U1ha4y_pqIVJyB_9A30utqPnLtxFByvof-f3o99uyZjLyNDZQ2KSZvT4eE&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Har+Gobind+Khorana&stick=H4sIAAAAAAAAAOOQUeLUz9U3MDLLzTA1ksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FCDbSsCClshDKTjHITco6xcgBZmcVJkOFwbaeYuQCsU2yLHNKDKEcIzOLYgOLX4xSnhAHIVsEdVADC-MiViGPxCIF9_wkoLsVvDPyixLzEm-xSTIcuJK5xKXw4ac__AkvXzUxts-S0QxgZH_mAQC8pWi07gAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAN6BAhHEAU',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Har+Gobind+Khorana&stick=H4sIAAAAAAAAAOOQUeLUz9U3MDLLzTA1ksrMS8lMzFPIy09KzVEoKMqsSlUoz8zLSy0qjtIMz8hXKM_PUyjJSFXISSxJLS5R8AOrCwCry8xTCMioLM5MLj7FCDbSsCClshDKTjHITco6xcgBZmcVJkOFwbaeYuQCsU2yLHNKDKEcIzOLYgOLX4xSnhAHIVsEdVADC-MiViGPxCIF9_wkoLsVvDPyixLzEm-xSTIcuJK5xKXw4ac__AkvXzUxts-S0QxgZH_mAQC8pWi07gAAAA'},
#     {'name': 'Abhijit Banerjee',
#      'image': 'https://encrypted-tbn0.gstatic.com/licensed-image?q=tbn:ANd9GcTN1BGhpiGYPYwyApE3lWGjRzX2-BNj6FrierSdxhdQZMDS_0THL78ECSmGvAP_LTE8AawfXRqG&s=19',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Abhijit+Banerjee&stick=H4sIAAAAAAAAAOOQUeLSz9U3MMmyzCkxNJLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcgJMtOwIKWyEMpOMchNyjrFyAFmZxUmQ4WNzHIzTE8xIjkByjEysyg2sPjFKOUJcRCyRVAHNbAwLmIVcEzKyMzKLFFwSgSKZaWm3mKTZDhwJXOJS-HDT3_4E16-amJsnyWjGcDI_swDAI8HWDftAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAR6BAhHEAY',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Abhijit+Banerjee&stick=H4sIAAAAAAAAAOOQUeLSz9U3MMmyzCkxNJLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcgJMtOwIKWyEMpOMchNyjrFyAFmZxUmQ4WNzHIzTE8xIjkByjEysyg2sPjFKOUJcRCyRVAHNbAwLmIVcEzKyMzKLFFwSgSKZaWm3mKTZDhwJXOJS-HDT3_4E16-amJsnyWjGcDI_swDAI8HWDftAAAA'},
#     {'name': 'Kailash Satyarthi',
#      'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ37txF6T8wi2_1QrAtc2L2RJLW2Yfn5pRfharpt8yIX9TlUVAwb4F4&s=0',
#      'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Kailash+Satyarthi&stick=H4sIAAAAAAAAAOOQUeLSz9U3MDKzKDawMJLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcgJMtOwIKWyEMpOMchNyjrFyAFmZxUmQ4WNzHIzTE8xgp1gkmWZU2II5UDc84tRyhPiIGSLoA5qYGFcxCronZiZk1icoRCcWFKZWFSSkXmLTZLhwJXMJS6FDz_94U94-aqJsX2WjGYAI_szDwA-pbRq7gAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQs9oBKAV6BAhHEAc',
#      'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Kailash+Satyarthi&stick=H4sIAAAAAAAAAOOQUeLSz9U3MDKzKDawMJLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcgJMtOwIKWyEMpOMchNyjrFyAFmZxUmQ4WNzHIzTE8xgp1gkmWZU2II5UDc84tRyhPiIGSLoA5qYGFcxCronZiZk1icoRCcWFKZWFSSkXmLTZLhwJXMJS6FDz_94U94-aqJsX2WjGYAI_szDwA-pbRq7gAAAA'}],
#    'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Indian+Nobel+Prize+winners&stick=H4sIAAAAAAAAAOOQMZLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcipn6tvYFiQUlkIZacY5CZlnWLkALOzCpOhwkZmuRmmpxi5QGyTLMucEkMox8jMotjA4hejlCfEQcgWQR3UwMK4iBWP_C02SYYDVzKXuBQ-_PSHP-HlqybG9lkymgGM7M88AAjgshPrAAAA&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ4qYDegQIRxAI',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Indian+Nobel+Prize+winners&stick=H4sIAAAAAAAAAOOQMZLKzEvJTMxTyMtPSs1RKCjKrEpVKM_My0stKo7SDM_IVyjPz1MoyUhVyEksSS0uUfADqwsAq8vMUwjIqCzOTC4-xcipn6tvYFiQUlkIZacY5CZlnWLkALOzCpOhwkZmuRmmpxi5QGyTLMucEkMox8jMotjA4hejlCfEQcgWQR3UwMK4iBWP_C02SYYDVzKXuBQ-_PSHP-HlqybG9lkymgGM7M88AAjgshPrAAAA'},
#   {'block_position': 1,
#    'query': 'Who won the latest nobel prize in physics today',
#    'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Who+won+the+latest+nobel+prize+in+physics+today&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ1QJ6BAhLEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+nobel+prize+in+physics+today'},
#   {'block_position': 1,
#    'query': 'Who won the latest nobel prize in physics 2023',
#    'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Who+won+the+latest+nobel+prize+in+physics+2023&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ1QJ6BAhKEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+nobel+prize+in+physics+2023'},
#   {'block_position': 1,
#    'query': 'nobel prize in physics 2023',
#    'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Prize+in+Physics+2023&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ1QJ6BAhJEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Prize+in+Physics+2023'},
#   {'block_position': 1,
#    'query': 'nobel prize in physics list',
#    'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Prize+in+Physics+List&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ1QJ6BAhIEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Prize+in+Physics+List'},
#   {'block_position': 1,
#    'query': 'nobel prize winners 2023',
#    'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Prize+winners+2023&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ1QJ6BAhPEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Prize+winners+2023'},
#   {'block_position': 1,
#    'query': 'nobel prize physics nominees 2023',
#    'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Prize+Physics+nominees+2023&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ1QJ6BAhOEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Prize+Physics+nominees+2023'},
#   {'block_position': 1,
#    'query': 'nobel prize physics 2023 explained',
#    'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=Nobel+Prize+Physics+2023+explained&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ1QJ6BAhNEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Nobel+Prize+Physics+2023+explained'},
#   {'block_position': 1,
#    'query': 'first nobel prize in physics',
#    'link': 'https://www.google.com/search?sca_esv=582259872&hl=en&gl=us&q=First+Nobel+Prize+in+Physics&sa=X&ved=2ahUKEwj3sd65wcOCAxU2g4kEHWO-BtgQ1QJ6BAhMEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=First+Nobel+Prize+in+Physics'}],
#  'pagination': {'current': 1,
#   'next': 'https://www.google.com/search?q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&oq=Who+won+the+latest+Nobel+Prize+in+Physics%3F&hl=en&gl=us&start=10&sourceid=chrome&ie=UTF-8',
#   'other_pages': {'2': 'https://www.google.com/search?q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&oq=Who+won+the+latest+Nobel+Prize+in+Physics%3F&hl=en&gl=us&start=10&sourceid=chrome&ie=UTF-8',
#    '3': 'https://www.google.com/search?q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&oq=Who+won+the+latest+Nobel+Prize+in+Physics%3F&hl=en&gl=us&start=20&sourceid=chrome&ie=UTF-8',
#    '4': 'https://www.google.com/search?q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&oq=Who+won+the+latest+Nobel+Prize+in+Physics%3F&hl=en&gl=us&start=30&sourceid=chrome&ie=UTF-8',
#    '5': 'https://www.google.com/search?q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&oq=Who+won+the+latest+Nobel+Prize+in+Physics%3F&hl=en&gl=us&start=40&sourceid=chrome&ie=UTF-8'}},
#  'serpapi_pagination': {'current': 1,
#   'next_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&start=10',
#   'next': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&start=10',
#   'other_pages': {'2': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&start=10',
#    '3': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&start=20',
#    '4': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&start=30',
#    '5': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&q=Who+won+the+latest+Nobel+Prize+in+Physics%3F&start=40'}}}

# %%
# Organic results
organic_results = [None] * num_organic_results
for k in range(num_organic_results):
    if (
        'organic_results' in search_data
        and len(search_data['organic_results']) > k
    ):
      organic_results[k] = format_search_results(
          search_data['organic_results'][k]
      )
    else:
      organic_results[k] = format_search_results({})

for d in organic_results[::-1]:
   df = pd.concat([df, pd.DataFrame([d])], ignore_index=True)

# %%
print(len(organic_results))
organic_results
# Out:
# 15
# [{'source': 'nobelprize.org',
#   'date': None,
#   'title': 'Nobel Prize in Physics Laureates',
#   'snippet': 'The three Nobel Prize laureates in physics 2023 are being recognised for ... Read what caused the Royal Swedish Academy of Sciences to exclaim, “Here, at last!',
#   'highlight': 'Nobel Prize laureates in physics | last'},
#  {'source': 'nobelprize.org',
#   'date': None,
#   'title': 'All Nobel Prizes in Physics',
#   'snippet': 'The Nobel Prize in Physics has been awarded 117 times to 225 Nobel Prize laureates between 1901 and 2023. John Bardeen is the only laureate who has been ...',
#   'highlight': 'Nobel Prize in Physics | been awarded | laureates | laureate | been'},
#  {'source': 'nobelprize.org',
#   'date': None,
#   'title': 'The official website of the Nobel Prize - NobelPrize.org',
#   'snippet': "The Nobel Prize in Physics 2023 was awarded to Pierre Agostini, Ferenc ... Last year's laureates. 14 laureates were awarded Nobel Prizes in 2022. See a short ...",
#   'highlight': 'Nobel Prize in Physics | was awarded | Last | laureates | laureates | awarded'},
#  {'source': 'nobelprize.org',
#   'date': 'Oct 04, 2022',
#   'title': 'The Nobel Prize in Physics 2022 - NobelPrize.org',
#   'snippet': 'The Nobel Prize in Physics 2022 was awarded jointly to Alain Aspect, John F. Clauser and Anton Zeilinger "for experiments with entangled ...',
#   'highlight': 'Nobel Prize in Physics | was awarded'},
#  {'source': 'nobelprize.org',
#   'date': None,
#   'title': 'All Nobel Prizes',
#   'snippet': 'Below, you can view the full list of Nobel Prizes and Nobel Prize laureates. Find all prizes in | physics | chemistry | physiology or medicine | literature | ...',
#   'highlight': 'Nobel Prizes | Nobel Prize laureates | prizes | physics'},
#  {'source': 'apnews.com',
#   'date': 'Oct 03, 2023',
#   'title': 'Trio wins Nobel Prize in physics for split-second glimpse of ...',
#   'snippet': 'Three scientists won the Nobel Prize in physics for their work on how electrons zip around the atom during the tiniest fractions of seconds.',
#   'highlight': 'won | Nobel Prize in physics'},
#  {'source': 'quantamagazine.org',
#   'date': 'Oct 04, 2022',
#   'title': 'Pioneering Quantum Physicists Win Nobel Prize in Physics',
#   'snippet': 'Alain Aspect, John Clauser and Anton Zeilinger have won the 2022 Nobel Prize in Physics for groundbreaking experiments with entangled ...',
#   'highlight': 'won | Nobel Prize in Physics'},
#  {'source': 'thehindu.com',
#   'date': 'Oct 03, 2023',
#   'title': 'Nobel Prize in Physics 2023: Three scientists win for ...',
#   'snippet': "The 2023 Nobel Prize for Physics has been awarded to to Pierre Agostini, Ferenc Krausz, Anne L'Huillier for research onelectrons in flashes ...",
#   'highlight': 'Nobel Prize | Physics | been awarded'},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None}]

# %%
 # Related questions
related_questions = [None] * num_related_questions
for k in range(num_related_questions):
  if (
      'related_questions' in search_data
      and len(search_data['related_questions']) > k
  ):
    related_questions[k] = format_search_results(
        search_data['related_questions'][k], title_field='question'
    )
  else:
    related_questions[k] = format_search_results({})

for d in related_questions[::-1]:
  df = pd.concat([df, pd.DataFrame([d])], ignore_index=True)

# %%
print(len(related_questions))
related_questions
# Out:
# 3
# [{'source': 'thehindu.com',
#   'date': 'Oct 03, 2023',
#   'title': 'Who won Nobel Prize 2023 in Physics?',
#   'snippet': "The 2023 Nobel Prize in Physics has been awarded to Pierre Agostini, Ferenc Krausz, and Anne L'Huillier “for experimental methods that generate attosecond pulses of light for the study of electro dynamics in matter”, The Royal Swedish Academy of Science announced on October 3, 2023.",
#   'highlight': None},
#  {'source': 'nytimes.com',
#   'date': 'Oct 03, 2023',
#   'title': 'Who won the last Nobel Prize Physics?',
#   'snippet': "Nobel Prize in Physics Awarded to 3 Scientists for Illuminating How Electrons Move. Techniques resulting from the work of Pierre Agostini, Ferenc Krausz and Anne L'Huillier let scientists capture the motions of subatomic particles moving at impossible speeds.",
#   'highlight': None},
#  {'source': 'pubs.acs.org',
#   'date': 'Oct 09, 2023',
#   'title': 'Who won the Nobel Prize in Physics 2023 attosecond?',
#   'snippet': "The 2023 Nobel Prize in Physics has been awarded to three researchers for their contributions to attosecond science. The prize honors Pierre Agostini of the Ohio State University, Ferenc Krausz of the Max Planck Institute of Quantum Optics, and Anne L'Huillier of Lund University.",
#   'highlight': None}]

# %%
# Knowledge graph
knowledge_graph = None
if 'knowledge_graph' in search_data:
  knowledge_graph = format_knowledge_graph(search_data['knowledge_graph'])
else:
  knowledge_graph = format_knowledge_graph({})
df = pd.concat([df, pd.DataFrame([knowledge_graph])], ignore_index=True)

# %%
knowledge_graph
# Out:
# {'source': None,
#  'date': None,
#  'title': None,
#  'snippet': None,
#  'highlight': None}

# %%
# Answer box
answer_box = None
if 'answer_box' in search_data:
  answer_box = format_search_results(
      search_data['answer_box'], highlight_field='answer'
  )
else:
  answer_box = format_search_results({})
df = pd.concat([df, pd.DataFrame([answer_box])], ignore_index=True)

# %%
answer_box
# Out:
# {'source': 'nobelprize.org',
#  'date': 'Oct 03, 2023',
#  'title': 'The Nobel Prize in Physics 2023 - NobelPrize.org',
#  'snippet': "The Nobel Prize in Physics 2023\n\tNiklas Elmehed © Nobel Prize Outreach. Pierre Agostini. Prize share: 1/3.\n\tNiklas Elmehed © Nobel Prize Outreach. Ferenc Krausz. Prize share: 1/3.\n\tNiklas Elmehed © Nobel Prize Outreach. Anne L'Huillier. Prize share: 1/3.",
#  'highlight': None}

# %%
# Sort by date
df['date'] = df['date'].apply(lambda x: format_date(x))
df['datetime'] = pd.to_datetime(df['date'], errors='coerce')
df = df.sort_values(by='datetime', na_position='first')
df.replace({pd.NaT: None}, inplace=True)
df = df.dropna(how='all')

# %%
df.head()
# Out:
#                 source          date  \
# 10      nobelprize.org          None
# 12      nobelprize.org          None
# 13      nobelprize.org          None
# 14      nobelprize.org          None
# 8   quantamagazine.org  Oct 04, 2022
#
#                                                 title  \
# 10                                   All Nobel Prizes
# 12  The official website of the Nobel Prize - Nobe...
# 13                        All Nobel Prizes in Physics
# 14                   Nobel Prize in Physics Laureates
# 8   Pioneering Quantum Physicists Win Nobel Prize ...
#
#                                               snippet  \
# 10  Below, you can view the full list of Nobel Pri...
# 12  The Nobel Prize in Physics 2023 was awarded to...
# 13  The Nobel Prize in Physics has been awarded 11...
# 14  The three Nobel Prize laureates in physics 202...
# 8   Alain Aspect, John Clauser and Anton Zeilinger...
#
#                                             highlight             datetime
# 10  Nobel Prizes | Nobel Prize laureates | prizes ...                 None
# 12  Nobel Prize in Physics | was awarded | Last | ...                 None
# 13  Nobel Prize in Physics | been awarded | laurea...                 None
# 14            Nobel Prize laureates in physics | last                 None
# 8                        won | Nobel Prize in Physics  2022-10-04 00:00:00

# %%
reasoning_and_answer = (
    "\nPlease check if the question contains a valid premise before"
    " answering.\nanswer: "
)

# Select top_k supporting evidences overall
evidences = []

for _, row in df.tail(num_retrieved_evidences).iterrows():
  evidences.append(
      f"""\n\nsource: {row['source']}\ndate: {row['date']}\ntitle: {row['title']}\nsnippet: {row['snippet']}\nhighlight: {row['highlight']}"""
  )

format_fresh_prompt = ''.join(
        [
            f'\n\n\nquery: {question}',
        ]
        + evidences
    ) + f'\n\nquestion: {question}{reasoning_and_answer}'

# %%
print(format_fresh_prompt)
# Out:
# query: Who won the latest Nobel Prize in Physics?
#
# source: nobelprize.org
# date: None
# title: All Nobel Prizes
# snippet: Below, you can view the full list of Nobel Prizes and Nobel Prize laureates. Find all prizes in | physics | chemistry | physiology or medicine | literature | ...
# highlight: Nobel Prizes | Nobel Prize laureates | prizes | physics
#
# source: nobelprize.org
# date: None
# title: The official website of the Nobel Prize - NobelPrize.org
# snippet: The Nobel Prize in Physics 2023 was awarded to Pierre Agostini, Ferenc ... Last year's laureates. 14 laureates were awarded Nobel Prizes in 2022. See a short ...
# highlight: Nobel Prize in Physics | was awarded | Last | laureates | laureates | awarded
#
# source: nobelprize.org
# date: None
# title: All Nobel Prizes in Physics
# snippet: The Nobel Prize in Physics has been awarded 117 times to 225 Nobel Prize laureates between 1901 and 2023. John Bardeen is the only laureate who has been ...
# highlight: Nobel Prize in Physics | been awarded | laureates | laureate | been
#
# source: nobelprize.org
# date: None
# title: Nobel Prize in Physics Laureates
# snippet: The three Nobel Prize laureates in physics 2023 are being recognised for ... Read what caused the Royal Swedish Academy of Sciences to exclaim, “Here, at last!
# highlight: Nobel Prize laureates in physics | last
#
# source: quantamagazine.org
# date: Oct 04, 2022
# title: Pioneering Quantum Physicists Win Nobel Prize in Physics
# snippet: Alain Aspect, John Clauser and Anton Zeilinger have won the 2022 Nobel Prize in Physics for groundbreaking experiments with entangled ...
# highlight: won | Nobel Prize in Physics
#
# source: nobelprize.org
# date: Oct 04, 2022
# title: The Nobel Prize in Physics 2022 - NobelPrize.org
# snippet: The Nobel Prize in Physics 2022 was awarded jointly to Alain Aspect, John F. Clauser and Anton Zeilinger "for experiments with entangled ...
# highlight: Nobel Prize in Physics | was awarded
#
# source: thehindu.com
# date: Oct 03, 2023
# title: Nobel Prize in Physics 2023: Three scientists win for ...
# snippet: The 2023 Nobel Prize for Physics has been awarded to to Pierre Agostini, Ferenc Krausz, Anne L'Huillier for research onelectrons in flashes ...
# highlight: Nobel Prize | Physics | been awarded
#
# source: apnews.com
# date: Oct 03, 2023
# title: Trio wins Nobel Prize in physics for split-second glimpse of ...
# snippet: Three scientists won the Nobel Prize in physics for their work on how electrons zip around the atom during the tiniest fractions of seconds.
# highlight: won | Nobel Prize in physics
#
# source: nytimes.com
# date: Oct 03, 2023
# title: Who won the last Nobel Prize Physics?
# snippet: Nobel Prize in Physics Awarded to 3 Scientists for Illuminating How Electrons Move. Techniques resulting from the work of Pierre Agostini, Ferenc Krausz and Anne L'Huillier let scientists capture the motions of subatomic particles moving at impossible speeds.
# highlight: None
#
# source: thehindu.com
# date: Oct 03, 2023
# title: Who won Nobel Prize 2023 in Physics?
# snippet: The 2023 Nobel Prize in Physics has been awarded to Pierre Agostini, Ferenc Krausz, and Anne L'Huillier “for experimental methods that generate attosecond pulses of light for the study of electro dynamics in matter”, The Royal Swedish Academy of Science announced on October 3, 2023.
# highlight: None
#
# source: nobelprize.org
# date: Oct 03, 2023
# title: The Nobel Prize in Physics 2023 - NobelPrize.org
# snippet: The Nobel Prize in Physics 2023
# 	Niklas Elmehed © Nobel Prize Outreach. Pierre Agostini. Prize share: 1/3.
# 	Niklas Elmehed © Nobel Prize Outreach. Ferenc Krausz. Prize share: 1/3.
# 	Niklas Elmehed © Nobel Prize Outreach. Anne L'Huillier. Prize share: 1/3.
# highlight: None
#
# source: pubs.acs.org
# date: Oct 09, 2023
# title: Who won the Nobel Prize in Physics 2023 attosecond?
# snippet: The 2023 Nobel Prize in Physics has been awarded to three researchers for their contributions to attosecond science. The prize honors Pierre Agostini of the Ohio State University, Ferenc Krausz of the Max Planck Institute of Quantum Optics, and Anne L'Huillier of Lund University.
# highlight: None
#
# question: Who won the latest Nobel Prize in Physics?
# Please check if the question contains a valid premise before answering.
# answer:

# %%
fresh_prompt = freshprompt_demo + format_fresh_prompt

# %%
print(fresh_prompt)
# Out:
# query: What year is considered Albert Einstein's annus mirabilis?
#
# source: philsci-archive.pitt.edu
# date: None
# title: The Turning Point for Einstein's Annus Mirabilis
# snippet: The year 1905 has been called Einstein's annus mirabilis in virtue of three ground-breaking works completed over the span of a few months — the light.
# highlight: 1905
#
# source: cantorsparadise.com
# date: None
# title: Einstein's Miraculous Year: A Summary of the 1905 Annus ...
# snippet: These are the four papers that Albert Einstein published in 1905, which are considered to be the foundation of modern physics.
# highlight: 1905
#
# source: quora.com
# date: None
# title: Why is 1905 Einstein's miracle year?
# snippet: Thus, 1905 is called Einstein's annus mirabilis, or miracle year, and these papers are called his annus mirabilis papers .
# highlight: 1905
#
# source: en.wikipedia.org
# date: None
# title: Annus mirabilis papers
# snippet: The annus mirabilis papers are the four papers that Albert Einstein published in Annalen der Physik (Annals of Physics), a scientific journal, in 1905.
# highlight: 1905
#
# source: americanscientist.org
# date: None
# title: Which year is known as annus mirabilis year?
# snippet: The Cambridge Dictionary defines annus mirabilis as “a year of extremely good events.” When otherwise unqualified, the term is usually understood to refer to “the miraculous year” of 1666, during which the Great Plague continued and the Great Fire of London raged for four days.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: When was the annus mirabilis of Albert Einstein?
# snippet: Because Einstein published these remarkable papers in a single year, 1905 is called his annus mirabilis (miracle year in English or Wunderjahr in German). , and was the only specific discovery mentioned in the citation awarding Einstein the Nobel Prize in Physics.
# highlight: None
#
# source: iopscience.iop.org
# date: None
# title: 1905
# snippet: Abstract. It is no exaggeration to say that almost every physicist knows about Albert Einstein's annus mirabilis 1905.
# highlight: 1905
#
# source: npr.org
# date: Mar 17, 2005
# title: Albert Einstein's Year of Miracles: Light Theory
# snippet: Scientists call 1905 Albert Einstein's annus mirabilis — his year of miracles. ... considered here [the March paper]" that represented a sharp ...
# highlight: 1905
#
# source: npr.org
# date: Mar 17, 2005
# title: What year is Einstein's biggest year?
# snippet: Web Resources. Scientists call 1905 Albert Einstein's annus mirabilis — his year of miracles. Within a few months, Einstein wrote a series of papers that would transform the way we see the universe.
# highlight: None
#
# source: scihi.org
# date: Jun 30, 2018
# title: The Annus Mirabilis in Physics – Albert Einstein and the Year ...
# snippet: 1905 was this Annus Mirabilis, this year of wonders or extraordinary year. History considers 1905 as the year with the most outstanding and ...
# highlight: 1905
#
# source: guides.loc.gov
# date: Nov 06, 2019
# title: Introduction - Annus Mirabilis of Albert Einstein
# snippet: He published hundreds of scientific papers during the course of his life, but in 1905, the year he turned 26, he published the four ...
# highlight: 1905
#
# source: guides.loc.gov
# date: Nov 04, 2023
# title: The 1905 Papers - Annus Mirabilis of Albert Einstein
# snippet: English translations of the four papers, from The Collected Papers of Albert Einstein, vol. 2: The Swiss Years: Writings 1900-1909, Princeton ...
# highlight: Albert
#
# question: What year is considered Albert Einstein's annus mirabilis?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. 1905 is considered Albert Einstein's annus mirabilis, his miraculous year.
#
#
# query: Which photographer took the most expensive photograph in the world?
#
# source: phototraces.com
# date: None
# title: Top 10 Most Expensive Photographs Ever Sold
# snippet: 10 Most Expensive Photographs Ever Sold · #1 Peter Lik, Phantom – (?) · #2 Andreas Gursky, Rhein II $4,338,500 · #3 Richard Prince, Spiritual America $3,973,000 · # ...
# highlight: Peter Lik, Phantom
#
# source: expertphotography.com
# date: None
# title: The 10 Most Expensive Photographs Ever Sold (by 2023)
# snippet: These are most expensive photographs ever sold, for millions at auction. You can decide for yourself if these famous photographers work is worth the price!
# highlight: most expensive photographs ever | photographers
#
# source: academic-accelerator.com
# date: None
# title: This is some fact about the cell membrane.
# snippet: cell membrane
# highlight: None
#
# source: reddit.com
# date: None
# title: Who is The Most Expensive Wedding Photographer in the world? and what is their portfolio like?
# snippet: surely Jose Villa would cost a bomb.
# highlight: None
#
# source: quora.com
# date: None
# title: What is the most expensive photograph ever shot?
# snippet: Probably the photo of the Earth taken from the Moon. Each moon landing of the Apollo program averages out to $18 billion dollars out of the $109 billion dollar program (based in 2011 dollars). http://www.thespacereview.com/article/1579/1 Hard to imaging that any other photo can come close.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: List
# snippet:
#
# Rank,Artist,Date
# 1,Man Ray,May 14, 2022
# 2,Edward Steichen,Nov 10, 2022
# 3,Andreas Gursky,November 8, 2011
# 4,Atsuko Satō,June 11, 2021
# highlight: None
#
# source: pentaxforums.com
# date: Oct 23, 2012
# title: WHo took the world's most expensive photograph?
# snippet: WHo took the world's most expensive photograph? ... Gursky sells high resolution photographs of huge dimensions often taken from very high angles.
# highlight: Gursky
#
# source: quora.com
# date: Mar 12, 2015
# title: What is the most expensive photograph ever shot?
# snippet: Shot by Kevin Abosch, in 2010 was auctioned for a whopping 1 Million Euros in 2015.
# highlight: Kevin Abosch
#
# source: digitalphotographycourses.co.za
# date: Nov 21, 2018
# title: What photograph sold for 4.3 million?
# snippet: Andreas Gursky's, Rhein II was sold at Christie's, New York for a whopping 4.3 Million USD on November 8, 2011.
# highlight: None
#
# source: all-about-photo.com
# date: Dec 22, 2019
# title: Most expensive photographs ever sold | Photo Article
# snippet: The most expensive photo in history as of December 2014 is $6.5 million! The work of Australian landscape photographer Peter Lik, Phantom is a ...
# highlight: Australian landscape photographer Peter Lik, Phantom
#
# source: pocket-lint.com
# date: Jul 22, 2021
# title: The 24 most expensive photos that sold for millions
# snippet: Australian photographer Peter Lik claims to hold the record for the most expensive photograph ever sold: a staggering $6.5 million for his photo ...
# highlight: Australian photographer Peter Lik
#
# source: cnn.com
# date: May 15, 2022
# title: What is the world's most expensive photograph?
# snippet: Man Ray's 'Le Violon d'Ingres' photograph sells for record $12.4 million. Editor's Note: This story was updated with the final sale price and other details following the auction.
# highlight: None
#
# source: news.artnet.com
# date: May 16, 2022
# title: What is the most expensive print ever sold?
# snippet: Man Ray, Le Violon d'Ingres (1924). Courtesy of Christie's. This weekend, an iconic Man Ray print sold for $12.4 million at Christie's, nearly tripling the record for the most expensive photograph ever sold at auction.
# highlight: None
#
# source: barnebys.com
# date: May 14, 2023
# title: The 11 Most Expensive Photographers
# snippet: It became the world's most expensive photograph when it sold at Christie's in 2022 for $12.4 million. Find more features on Barnebys Magazine.
# highlight: Christie's
#
# source: artincontext.org
# date: Aug 10, 2023
# title: Most Expensive Photographs - 15 Extravagant Photographs
# snippet: Le Violon D'Ingre (1924) by Man Ray takes first place at an astonishing $12.4 million! Some of the other most expensive photos ever sold include ...
# highlight: Le Violon D'Ingre (1924) by Man Ray
#
# question: Which photographer took the most expensive photograph in the world?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The most expensive photograph in the world is "Le Violon d'Ingres". The photograph was created by Man Ray.
#
#
# query: How many days are left until the 2023 Grammy Awards?
#
# source: en.wikipedia.org
# date: None
# title: 65th Annual Grammy Awards
# snippet: The 65th Annual Grammy Awards ceremony was held at the Crypto.com Arena in Los Angeles on February 5, 2023. It recognized the best recordings, compositions, ...
# highlight: Grammy Awards | in | 2023
#
# source: grammy.com
# date: None
# title: Everything You Need To Know About The 2023 GRAMMYs ...
# snippet: The eligibility period for the 65th GRAMMY Awards is Friday, Oct. 1, 2021 – Friday, Sept. 30, 2022. All eligible awards entries must be released within this ...
# highlight: for | GRAMMY Awards
#
# source: recordingacademy.com
# date: None
# title: 2023 GRAMMYs: Everything You Need To Know About ...
# snippet: There are only two days left to participate in first-round voting for the 2023 GRAMMYs; final-round voting will commence Dec. 14. If you're a Recording ...
# highlight: two days
#
# source: grammy.com
# date: None
# title: Air Date For 2023 GRAMMYs Announced
# snippet: This year's GRAMMY nominees will be announced on Tuesday, Nov. 15, with the 2023 GRAMMYs airing live Sunday, Feb. 5, from the Crypto.com Arena in Los Angeles.
# highlight: GRAMMY | 2023 GRAMMYs | in
#
# source: recordingacademy.com
# date: None
# title: How long until the next Grammy Awards?
# snippet: THE 66TH ANNUAL GRAMMY AWARDS® SET TO TAKE PLACE SUN, FEB. 4, 2024 | RECORDINGACADEMY.com.
# highlight: None
#
# source: grammy.com
# date: None
# title: What time is GRAMMYs 2023 over?
# snippet: The 2023 GRAMMYs will air live on Sunday, Feb. 5, at 8-11:30 p.m. ET/5-8:30 p.m. PT from the Crypto.com Arena in Los Angeles.
# highlight: None
#
# source: variety.com
# date: Jul 14, 2022
# title: Grammy Awards Announce Key Dates for 2023 Race
# snippet: Nominees will be announced this year on Nov. 15, with the first round of voting set from Oct. 13 to Oct. 23 and a final round on Dec. 14 to Jan.
# highlight: None
#
# source: billboard.com
# date: Jul 14, 2022
# title: Here's the Date & Location of the 2023 Grammy Awards
# snippet: Nominations will be announced on Tuesday, Nov. 15 -- eight days earlier than they were last year.
# highlight: eight days
#
# source: en.as.com
# date: Feb 01, 2023
# title: 2023 Grammy Awards: Who's attending, skipping, and ...
# snippet: With only a few days left until the 65th annual Grammy Awards, and the full performer lineup yet to be announced, here is how the show is ...
# highlight: only a few days
#
# source: howmanydaysuntil.center
# date: Feb 04, 2023
# title: When ar The Grammy Awards - How Many Days Until
# snippet: The Grammy Awards will be celebrated this year on is on February 4th. Find out more about The Grammy Awards.
# highlight: February 4th
#
# source: cnn.com
# date: Feb 05, 2023
# title: How to watch the Grammys: Time, channels and more
# snippet: How to watch the 2023 Grammy Awards: Time, channels and more · Day and time. The Grammy Awards air Sunday, February 5, at 8 p.m. ET/5 p.m. PT.
# highlight: 2023 Grammy Awards | Day | Grammy Awards
#
# source: nytimes.com
# date: Feb 06, 2023
# title: How to Watch the 2023 Grammys
# snippet: The ceremony will air live on Sunday, at 8 p.m. Eastern time (5 p.m. Pacific time) on CBS and stream live on Paramount+. Before the prime-time ...
# highlight: Before the
#
# source: billboard.com
# date: Nov 10, 2023
# title: What is the deadline for Grammy nominations 2023?
# snippet: This year's eligibility period ran from Oct. 1, 2022, through Sept. 15, 2023. The final round of Grammy voting, which will determine the winners, will take place Dec. 14 through Jan. 4, 2024.
# highlight: None
#
# question: How many days are left until the 2023 Grammy Awards?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The 2023 Grammy Awards ceremony was held on February 5, 2023. Thus, the ceremony has already taken place.
#
#
# query: How many years ago did the Boxing Day Tsunami happen?
#
# source: knowledge.aidr.org.au
# date: None
# title: The Boxing Day Tsunami in numbers Stats and facts
# snippet: The Tangshan Earthquake in China killed at least 255,000 in 1976. Flooding in Bangladesh in 2004 destroyed over 1 million homes, displaced over 4 million ...
# 	2 pages
# highlight: Earthquake | 2004
#
# source: knowledge.aidr.org.au
# date: None
# title: Indian Ocean tsunami, 2004 | Australian Disasters
# snippet: In December 2004, a massive earthquake struck off the west coast of Sumatra. The resulting Indian Ocean tsunami caused widespread destruction. Learn more.
# highlight: December 2004
#
# source: britannica.com
# date: None
# title: Indian Ocean tsunami of 2004 | Facts & Death Toll
# snippet: Indian Ocean tsunami of 2004, deadly tsunami that hit the coasts of several countries of South and Southeast Asia and caused immense destruction.
# highlight: 2004
#
# source: britannica.com
# date: None
# title: How long did the 2004 tsunami last?
# snippet: How long did the Indian Ocean tsunami of 2004 last? The Indian Ocean tsunami of 2004 lasted for seven hours and reached out across the Indian Ocean, devastating coastal areas of Indonesia, Sri Lanka, India, Maldives, and Thailand, and as far away as East Africa.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: 2004 Indian Ocean earthquake and tsunami - Wikipedia
# snippet: On 26 December 2004, at 07:58:53 local time (UTC+7), a major earthquake with a magnitude of 9.1–9.3 Mw struck with an epicentre off the west coast of northern Sumatra, Indonesia.
# highlight: None
#
# source: history.com
# date: Oct 02, 2018
# title: The 2004 Tsunami Wiped Away Towns With 'Mind- ...
# snippet: The Boxing Day tsunami would be the deadliest in recorded history, taking a staggering 230,000 lives in a matter of hours. The city of Banda ...
# highlight: 230,000
#
# source: reuters.com
# date: Dec 18, 2019
# title: 15 years on, a look back at the Boxing Day tsunami
# snippet: December 26 marks 15 years since a 9.1 magnitude quake off the coast of Indonesia's Aceh province triggered a tsunami that killed more than ...
# highlight: 15 years
#
# source: preventionweb.net
# date: Jun 26, 2021
# title: Indian Ocean tsunami: What was learned about recovery
# snippet: We've been following victims of the Boxing Day tsunami for 16 years – this is what we've learned about recovering from disaster. Source(s): ...
# highlight: 16 years
#
# source: materchristi.libguides.com
# date: May 11, 2023
# title: 2004 Indian Ocean Tsunami - Natural disasters of the Asia ...
# snippet: The Boxing Day tsunami in 2004 is believed to be the deadliest tsunami in history, killing more than 230,000 people across 14 countries.
# highlight: 2004
#
# source: noaa.gov
# date: Jun 12, 2023
# title: JetStream Max: 2004 Indian Ocean Tsunami
# snippet: On December 26, 2004, an extremely powerful earthquake off the coast of the Indonesian island of Sumatra in the Indian Ocean generated a ...
# highlight: December 26, 2004
#
# source: noaa.gov
# date: Jun 12, 2023
# title: When did the Boxing Day tsunami occur?
# snippet: On December 26, 2004, an extremely powerful earthquake off the coast of the Indonesian island of Sumatra in the Indian Ocean generated a devastating tsunami.
# highlight: None
#
# source: worldvision.org
# date: Sep 25, 2023
# title: 2004 Indian Ocean Earthquake and Tsunami
# snippet: Discover the 2004 Indian Ocean tsunami's historic impact and World Vision's multi-country humanitarian efforts that lasted over a decade.
# highlight: 2004
#
# source: worldvision.org
# date: Sep 25, 2023
# title: What was the worst tsunami in 2004?
# snippet: Approximately 230,000 people died in the 2004 Indian Ocean earthquake and tsunami, making it one of the deadliest disasters in modern history. The Sumatra-Andaman earthquake, which caused the tsunami, is estimated to have released energy equivalent to 23,000 Hiroshima-type atomic bombs.
# highlight: None
#
# question: How many years ago did the Boxing Day Tsunami happen?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The disaster occurred on December 26, 2004. Thus, it happened 18 years ago.
#
#
# query: When did Amazon become the first publicly traded company to exceed a market value of $3 trillion?
#
# source: en.wikipedia.org
# date: None
# title: List of public corporations by market capitalization
# snippet: The table below lists all companies which have, at any point, had a market capitalization in excess of $1 trillion, the date on which their market cap first ...
# highlight: companies | market capitalization | excess | trillion | market cap first
#
# source: cbsnews.com
# date: Sep 04, 2018
# title: Amazon becomes second trillion-dollar company in US
# snippet: Amazon hits $1 trillion and becomes the second U.S. company worth one trillion dollars after stock price surged Tuesday - CBS News.
# highlight: after stock price surged Tuesday
#
# source: cnbc.com
# date: Jan 03, 2022
# title: Apple becomes first U.S. company to reach $3 trillion ...
# snippet: Apple became the first publicly traded U.S. company to hit a $1 trillion market cap during intraday trading on Aug. 2, 2018. It hit a $2 ...
# highlight: Aug. 2, 2018
#
# source: fortune.com
# date: Nov 02, 2022
# title: As Amazon's value drops below $1 trillion, this chart shows ...
# snippet: On November 1, Amazon reached a bleak milestone when its value dropped below $1 trillion for the first time since first crossing that ...
# highlight: On November 1
#
# source: financialpost.com
# date: Nov 09, 2022
# title: Amazon becomes first public company to lose $1 trillion ...
# snippet: Amazon.com Inc. is the world's first public company to lose a trillion dollars in market value as a combination of rising inflation ...
# highlight: Amazon | is the | first public company | trillion | market value
#
# source: bloomberg.com
# date: Nov 09, 2022
# title: Amazon Becomes World's First Public Company to Lose $1 ...
# snippet: Amazon.com Inc. is the world's first public company to lose a trillion dollars in market value as a combination of rising inflation, ...
# highlight: Amazon | is the | first public company | trillion | market value
#
# source: fortune.com
# date: Jun 30, 2023
# title: Apple becomes first $3 trillion market value company
# snippet: Apple first became the world's most valuable stock in 2011, when its market cap was under $340 billion and it comprised about 3.3% of the S&P ...
# highlight: 2011
#
# source: qz.com
# date: Jun 30, 2023
# title: Apple is officially the world's first-ever $3 trillion company
# snippet: Apple became the first company in the world with a $3 trillion valuation on Friday (June 30). The company's stock closed at $193.97 per share— ...
# highlight: Friday (June 30
#
# source: zeebiz.com
# date: Jun 30, 2023
# title: What company has reached the market cap of 3 trillion?
# snippet: Apple is once again worth $3 trillion, the only company ever to reach the milestone, a media report said. Its shares rose 1 per cent on Friday to hit a record $191.34. With 15.7 billion shares outstanding, the stock price pushed Apple to its historic market value, CNN reported.
# highlight: None
#
# source: nbcnews.com
# date: Jun 30, 2023
# title: Is Apple the first US company to reach $3 trillion market cap?
# snippet: The news shows investors remain bullish on the stock and Apple's portfolio of products and services, despite the company's warning in May that its current quarter revenue is expected to fall about 3%.
# highlight: None
#
# source: fortune.com
# date: Jun 30, 2023
# title: What is the first $3 trillion dollar company?
# snippet: Apple just made history by becoming the first company with a $3 trillion market value—'and its lock on the consumer is only getting stronger' Apple CEO Tim Cook.
# highlight: None
#
# source: cityindex.com
# date: Aug 24, 2023
# title: A guide to trillion-dollar companies
# snippet: Apple did become the world's first $3 trillion company in June 2023 but hasn't retained that market capitalisation in the subsequent months.
# highlight: June 2023
#
# source: money.usnews.com
# date: Oct 24, 2023
# title: The 10 Most Valuable Companies in the World by Market ...
# snippet: (ticker: AAPL) was the first company to reach a market capitalization of $1 trillion in 2018. ... Overall, Amazon has become the largest online ...
# highlight: 2018
#
# question: When did Amazon become the first publicly traded company to exceed a market value of $3 trillion?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. Amazon's market capitalization has never exceeded $3 trillion.
#
#
# query: Who won the latest Nobel Prize in Physics?
#
# source: nobelprize.org
# date: None
# title: All Nobel Prizes
# snippet: Below, you can view the full list of Nobel Prizes and Nobel Prize laureates. Find all prizes in | physics | chemistry | physiology or medicine | literature | ...
# highlight: Nobel Prizes | Nobel Prize laureates | prizes | physics
#
# source: nobelprize.org
# date: None
# title: The official website of the Nobel Prize - NobelPrize.org
# snippet: The Nobel Prize in Physics 2023 was awarded to Pierre Agostini, Ferenc ... Last year's laureates. 14 laureates were awarded Nobel Prizes in 2022. See a short ...
# highlight: Nobel Prize in Physics | was awarded | Last | laureates | laureates | awarded
#
# source: nobelprize.org
# date: None
# title: All Nobel Prizes in Physics
# snippet: The Nobel Prize in Physics has been awarded 117 times to 225 Nobel Prize laureates between 1901 and 2023. John Bardeen is the only laureate who has been ...
# highlight: Nobel Prize in Physics | been awarded | laureates | laureate | been
#
# source: nobelprize.org
# date: None
# title: Nobel Prize in Physics Laureates
# snippet: The three Nobel Prize laureates in physics 2023 are being recognised for ... Read what caused the Royal Swedish Academy of Sciences to exclaim, “Here, at last!
# highlight: Nobel Prize laureates in physics | last
#
# source: quantamagazine.org
# date: Oct 04, 2022
# title: Pioneering Quantum Physicists Win Nobel Prize in Physics
# snippet: Alain Aspect, John Clauser and Anton Zeilinger have won the 2022 Nobel Prize in Physics for groundbreaking experiments with entangled ...
# highlight: won | Nobel Prize in Physics
#
# source: nobelprize.org
# date: Oct 04, 2022
# title: The Nobel Prize in Physics 2022 - NobelPrize.org
# snippet: The Nobel Prize in Physics 2022 was awarded jointly to Alain Aspect, John F. Clauser and Anton Zeilinger "for experiments with entangled ...
# highlight: Nobel Prize in Physics | was awarded
#
# source: thehindu.com
# date: Oct 03, 2023
# title: Nobel Prize in Physics 2023: Three scientists win for ...
# snippet: The 2023 Nobel Prize for Physics has been awarded to to Pierre Agostini, Ferenc Krausz, Anne L'Huillier for research onelectrons in flashes ...
# highlight: Nobel Prize | Physics | been awarded
#
# source: apnews.com
# date: Oct 03, 2023
# title: Trio wins Nobel Prize in physics for split-second glimpse of ...
# snippet: Three scientists won the Nobel Prize in physics for their work on how electrons zip around the atom during the tiniest fractions of seconds.
# highlight: won | Nobel Prize in physics
#
# source: nytimes.com
# date: Oct 03, 2023
# title: Who won the last Nobel Prize Physics?
# snippet: Nobel Prize in Physics Awarded to 3 Scientists for Illuminating How Electrons Move. Techniques resulting from the work of Pierre Agostini, Ferenc Krausz and Anne L'Huillier let scientists capture the motions of subatomic particles moving at impossible speeds.
# highlight: None
#
# source: thehindu.com
# date: Oct 03, 2023
# title: Who won Nobel Prize 2023 in Physics?
# snippet: The 2023 Nobel Prize in Physics has been awarded to Pierre Agostini, Ferenc Krausz, and Anne L'Huillier “for experimental methods that generate attosecond pulses of light for the study of electro dynamics in matter”, The Royal Swedish Academy of Science announced on October 3, 2023.
# highlight: None
#
# source: nobelprize.org
# date: Oct 03, 2023
# title: The Nobel Prize in Physics 2023 - NobelPrize.org
# snippet: The Nobel Prize in Physics 2023
# 	Niklas Elmehed © Nobel Prize Outreach. Pierre Agostini. Prize share: 1/3.
# 	Niklas Elmehed © Nobel Prize Outreach. Ferenc Krausz. Prize share: 1/3.
# 	Niklas Elmehed © Nobel Prize Outreach. Anne L'Huillier. Prize share: 1/3.
# highlight: None
#
# source: pubs.acs.org
# date: Oct 09, 2023
# title: Who won the Nobel Prize in Physics 2023 attosecond?
# snippet: The 2023 Nobel Prize in Physics has been awarded to three researchers for their contributions to attosecond science. The prize honors Pierre Agostini of the Ohio State University, Ferenc Krausz of the Max Planck Institute of Quantum Optics, and Anne L'Huillier of Lund University.
# highlight: None
#
# question: Who won the latest Nobel Prize in Physics?
# Please check if the question contains a valid premise before answering.
# answer:

# %%
answer = chat_completions(fresh_prompt)

# %%
print(answer)
# Out:
# The latest Nobel Prize in Physics, as of November 14, 2023, was awarded to Pierre Agostini, Ferenc Krausz, and Anne L'Huillier for their work on attosecond science.

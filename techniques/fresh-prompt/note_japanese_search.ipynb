# %% [markdown]
# # Fresh Prompt
# - [freshllms/freshqa](https://github.com/freshllms/freshqa)

# %% [markdown]
# ## セットアップ

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv(verbose=True)

openai_client = OpenAI(
  api_key=os.environ["OPENAI_API_KEY"],
)

# %%
import pytz
import datetime

current_date = datetime.datetime.now(
    pytz.timezone('Asia/Tokyo')
).strftime("%B %d, %Y")
print(current_date)
# Out:
# November 15, 2023

# %%
temperature = 0.0
max_tokens = 256

def chat_completions(prompt):
    response = openai_client.chat.completions.create(
        model="gpt-4-1106-preview",
        temperature=0.0,
        max_tokens=256,
        messages=[
            {
                "role": "system",
                "content": (
                    "You are a helpful assistant. Answer as concisely as"
                    f" possible. Knowledge cutoff: {current_date}."
                ),
            },
            {"role": "user", "content": "What's today's date?"},
            {
                "role": "assistant",
                "content": f"Today is {current_date} in Pacific Standard Time.",
            },
            {"role": "user", "content": prompt},
        ],
    )
    return response.choices[0].message.content

# %%
from serpapi import GoogleSearch

def call_search_engine(query):
  params = {
    "q": query,
    "hl": "ja",
    "gl": "jp",
    "google_domain": "google.com",
    "api_key": os.environ["SERPAPI_API_KEY"],
  }

  search = GoogleSearch(params)
  return search.get_dict()

# %%
import dateutil
import re

def is_date(string, fuzzy=False):
  # Parse a string into a date and check its validity
  try:
      dateutil.parser.parse(string, fuzzy=fuzzy)
      return True
  except ValueError:
      return False


def format_date(d):
  # Standardize the date format for each search result
  date = dateutil.parser.parse(current_date, fuzzy=True).strftime("%b %d, %Y")
  if d is None:
    return None

  for t in ["second", "minute", "hour"]:
    if f"{t} ago" in d or f"{t}s ago" in d:
      return date

  t = "day"
  if f"{t} ago" in d or f"{t}s ago" in d:
    n_days = int(re.search("(\d+) days? ago", d).group(1))
    return (
        datetime.datetime.strptime(date, "%b %d, %Y")
        - datetime.timedelta(days=n_days)
    ).strftime("%b %d, %Y")

  try:
    return dateutil.parser.parse(d, fuzzy=True).strftime("%b %d, %Y")
  except ValueError:
    for x in d.split():
      if is_date(x):
        return dateutil.parser.parse(x, fuzzy=True).strftime("%b %d, %Y")


def extract_source_webpage(link):
  # Extract source webpage
  return (
      link.strip()
      .replace("https://www.", "")
      .replace("http://www.", "")
      .replace("https://", "")
      .replace("http://", "")
      .split("/")[0]
  )


def simplify_displayed_link(displayed_link):
  # Simplify displayed link
  if displayed_link is None:
    return None
  return extract_source_webpage(displayed_link.split(' › ')[0])

# %%
def format_search_results(search_data, title_field=None, highlight_field=None):
  # Standardize search results as shown in Figure 3 (left) in the paper
  field = 'snippet_highlighted_words'
  if field in search_data and isinstance(search_data[field], list):
    search_data[field] = ' | '.join(search_data[field])

  field = 'displayed_link'
  if field in search_data:
    search_data[field] = simplify_displayed_link(search_data[field])

  # edge case 1
  if search_data.get('type') == 'local_time':
    source = search_data.get('displayed_link')
    date = format_date(search_data.get('date'))
    title = search_data.get('title')

    snippet = search_data.get('snippet')
    if snippet is None and 'result' in search_data:
      if 'extensions' in search_data and isinstance(
          search_data['extensions'], list
      ):
        snippet = '\n\t'.join(
            [search_data['result']] + search_data['extensions']
        )
      else:
        snippet = search_data['result']

    highlight = search_data.get('snippet_highlighted_words')
    if highlight is None and 'result' in search_data:
      highlight = search_data['result']

  # edge case 2
  elif 'type' in search_data and search_data['type'] == 'population_result':
    source = search_data.get('displayed_link')
    if source is None and 'sources' in search_data:
      if (
          isinstance(search_data['sources'], list)
          and 'link' in search_data['sources'][0]
      ):
        source = extract_source_webpage(search_data['sources'][0]['link'])

    date = format_date(search_data.get('date'))
    if date is None and 'year' in search_data:
      date = format_date(search_data['year'])

    title = search_data.get('title')

    snippet = search_data.get('snippet')
    if snippet is None and 'population' in search_data:
      if 'place' in search_data:
        snippet = '\n\t'.join(
            [
                f"{search_data['place']} / Population",
            ]
            + [
                search_data['population'],
            ]
        )
      else:
        snippet = search_data['population']

    highlight = search_data.get('snippet_highlighted_words')
    if highlight is None and 'population' in search_data:
      highlight = search_data['population']

  else:
    source = search_data.get('displayed_link')
    date = format_date(search_data.get('date'))
    title = (
        search_data.get('title')
        if title_field is None
        else search_data.get(title_field)
    )
    highlight = (
        search_data.get('snippet_highlighted_words')
        if highlight_field is None
        else search_data.get(highlight_field)
    )
    snippet = search_data.get('snippet', '')

    if 'rich_snippet' in search_data:
      for key in ['top', 'bottom']:
        if (
            key in search_data['rich_snippet']
            and 'extensions' in search_data['rich_snippet'][key]
        ):
          snippet = '\n\t'.join(
              [snippet] + search_data['rich_snippet'][key]['extensions']
          )

    if 'list' in search_data:
      assert isinstance(search_data['list'], list)
      snippet = '\n\t'.join([snippet] + search_data['list'])

    if 'contents' in search_data and 'table' in search_data['contents']:
      tbl = search_data['contents']['table']
      assert isinstance(tbl, list)
      snippet += '\n'
      for row in tbl:
        snippet += f'\n{",".join(row)}'

    if snippet is not None and snippet.strip() == '':
      snippet = None

  return {
      'source': source,
      'date': date,
      'title': title,
      'snippet': snippet,
      'highlight': highlight,
  }

# %%
def format_knowledge_graph(search_data):
  # Standardize knowledge graphs as shown in Figure 3 (left) in the paper
  source = None
  if "source" in search_data and "link" in search_data["source"]:
    source = extract_source_webpage(search_data["source"]["link"])

  date = None

  title = None
  if "title" in search_data:
    title = search_data["title"]
    if "type" in search_data:
      title += f"\n\t{search_data['type']}"

  snippet = ""
  for field in search_data:
    if (
        (field not in ["title", "type", "kgmid"])
        and ("_link" not in field)
        and ("_stick" not in field)
        and isinstance(search_data[field], str)
        and not search_data[field].startswith("http")
    ):
      snippet += f"\n\t{field}: {search_data[field]}"

  if snippet.strip() == "":
    snippet = None
  else:
    snippet = snippet.strip()

  highlight = None

  return {
      "source": source,
      "date": date,
      "title": title,
      "snippet": snippet,
      "highlight": highlight,
  }


def format_questions_and_answers(search_data):
  # Standardize questions and answers as shown in Figure 3 (left) in the paper
  source = None
  if "link" in search_data:
    source = extract_source_webpage(search_data["link"])

  date = None

  title = None
  if "question" in search_data:
    title = search_data["question"]

  snippet = None
  if "answer" in search_data:
    snippet = search_data["answer"]

  highlight = None

  return {
      "source": source,
      "date": date,
      "title": title,
      "snippet": snippet,
      "highlight": highlight,
  }

# %% [markdown]
# ## Demo Prompts

# %%
# read from file
with open("./data/freshprompt_demo.txt", "r") as f:
    freshprompt_demo = f.read()

print(freshprompt_demo)
# Out:
# query: What year is considered Albert Einstein's annus mirabilis?
#
# source: philsci-archive.pitt.edu
# date: None
# title: The Turning Point for Einstein's Annus Mirabilis
# snippet: The year 1905 has been called Einstein's annus mirabilis in virtue of three ground-breaking works completed over the span of a few months — the light.
# highlight: 1905
#
# source: cantorsparadise.com
# date: None
# title: Einstein's Miraculous Year: A Summary of the 1905 Annus ...
# snippet: These are the four papers that Albert Einstein published in 1905, which are considered to be the foundation of modern physics.
# highlight: 1905
#
# source: quora.com
# date: None
# title: Why is 1905 Einstein's miracle year?
# snippet: Thus, 1905 is called Einstein's annus mirabilis, or miracle year, and these papers are called his annus mirabilis papers .
# highlight: 1905
#
# source: en.wikipedia.org
# date: None
# title: Annus mirabilis papers
# snippet: The annus mirabilis papers are the four papers that Albert Einstein published in Annalen der Physik (Annals of Physics), a scientific journal, in 1905.
# highlight: 1905
#
# source: americanscientist.org
# date: None
# title: Which year is known as annus mirabilis year?
# snippet: The Cambridge Dictionary defines annus mirabilis as “a year of extremely good events.” When otherwise unqualified, the term is usually understood to refer to “the miraculous year” of 1666, during which the Great Plague continued and the Great Fire of London raged for four days.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: When was the annus mirabilis of Albert Einstein?
# snippet: Because Einstein published these remarkable papers in a single year, 1905 is called his annus mirabilis (miracle year in English or Wunderjahr in German). , and was the only specific discovery mentioned in the citation awarding Einstein the Nobel Prize in Physics.
# highlight: None
#
# source: iopscience.iop.org
# date: None
# title: 1905
# snippet: Abstract. It is no exaggeration to say that almost every physicist knows about Albert Einstein's annus mirabilis 1905.
# highlight: 1905
#
# source: npr.org
# date: Mar 17, 2005
# title: Albert Einstein's Year of Miracles: Light Theory
# snippet: Scientists call 1905 Albert Einstein's annus mirabilis — his year of miracles. ... considered here [the March paper]" that represented a sharp ...
# highlight: 1905
#
# source: npr.org
# date: Mar 17, 2005
# title: What year is Einstein's biggest year?
# snippet: Web Resources. Scientists call 1905 Albert Einstein's annus mirabilis — his year of miracles. Within a few months, Einstein wrote a series of papers that would transform the way we see the universe.
# highlight: None
#
# source: scihi.org
# date: Jun 30, 2018
# title: The Annus Mirabilis in Physics – Albert Einstein and the Year ...
# snippet: 1905 was this Annus Mirabilis, this year of wonders or extraordinary year. History considers 1905 as the year with the most outstanding and ...
# highlight: 1905
#
# source: guides.loc.gov
# date: Nov 06, 2019
# title: Introduction - Annus Mirabilis of Albert Einstein
# snippet: He published hundreds of scientific papers during the course of his life, but in 1905, the year he turned 26, he published the four ...
# highlight: 1905
#
# source: guides.loc.gov
# date: Nov 04, 2023
# title: The 1905 Papers - Annus Mirabilis of Albert Einstein
# snippet: English translations of the four papers, from The Collected Papers of Albert Einstein, vol. 2: The Swiss Years: Writings 1900-1909, Princeton ...
# highlight: Albert
#
# question: What year is considered Albert Einstein's annus mirabilis?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. 1905 is considered Albert Einstein's annus mirabilis, his miraculous year.
#
#
# query: Which photographer took the most expensive photograph in the world?
#
# source: phototraces.com
# date: None
# title: Top 10 Most Expensive Photographs Ever Sold
# snippet: 10 Most Expensive Photographs Ever Sold · #1 Peter Lik, Phantom – (?) · #2 Andreas Gursky, Rhein II $4,338,500 · #3 Richard Prince, Spiritual America $3,973,000 · # ...
# highlight: Peter Lik, Phantom
#
# source: expertphotography.com
# date: None
# title: The 10 Most Expensive Photographs Ever Sold (by 2023)
# snippet: These are most expensive photographs ever sold, for millions at auction. You can decide for yourself if these famous photographers work is worth the price!
# highlight: most expensive photographs ever | photographers
#
# source: academic-accelerator.com
# date: None
# title: This is some fact about the cell membrane.
# snippet: cell membrane
# highlight: None
#
# source: reddit.com
# date: None
# title: Who is The Most Expensive Wedding Photographer in the world? and what is their portfolio like?
# snippet: surely Jose Villa would cost a bomb.
# highlight: None
#
# source: quora.com
# date: None
# title: What is the most expensive photograph ever shot?
# snippet: Probably the photo of the Earth taken from the Moon. Each moon landing of the Apollo program averages out to $18 billion dollars out of the $109 billion dollar program (based in 2011 dollars). http://www.thespacereview.com/article/1579/1 Hard to imaging that any other photo can come close.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: List
# snippet:
#
# Rank,Artist,Date
# 1,Man Ray,May 14, 2022
# 2,Edward Steichen,Nov 10, 2022
# 3,Andreas Gursky,November 8, 2011
# 4,Atsuko Satō,June 11, 2021
# highlight: None
#
# source: pentaxforums.com
# date: Oct 23, 2012
# title: WHo took the world's most expensive photograph?
# snippet: WHo took the world's most expensive photograph? ... Gursky sells high resolution photographs of huge dimensions often taken from very high angles.
# highlight: Gursky
#
# source: quora.com
# date: Mar 12, 2015
# title: What is the most expensive photograph ever shot?
# snippet: Shot by Kevin Abosch, in 2010 was auctioned for a whopping 1 Million Euros in 2015.
# highlight: Kevin Abosch
#
# source: digitalphotographycourses.co.za
# date: Nov 21, 2018
# title: What photograph sold for 4.3 million?
# snippet: Andreas Gursky's, Rhein II was sold at Christie's, New York for a whopping 4.3 Million USD on November 8, 2011.
# highlight: None
#
# source: all-about-photo.com
# date: Dec 22, 2019
# title: Most expensive photographs ever sold | Photo Article
# snippet: The most expensive photo in history as of December 2014 is $6.5 million! The work of Australian landscape photographer Peter Lik, Phantom is a ...
# highlight: Australian landscape photographer Peter Lik, Phantom
#
# source: pocket-lint.com
# date: Jul 22, 2021
# title: The 24 most expensive photos that sold for millions
# snippet: Australian photographer Peter Lik claims to hold the record for the most expensive photograph ever sold: a staggering $6.5 million for his photo ...
# highlight: Australian photographer Peter Lik
#
# source: cnn.com
# date: May 15, 2022
# title: What is the world's most expensive photograph?
# snippet: Man Ray's 'Le Violon d'Ingres' photograph sells for record $12.4 million. Editor's Note: This story was updated with the final sale price and other details following the auction.
# highlight: None
#
# source: news.artnet.com
# date: May 16, 2022
# title: What is the most expensive print ever sold?
# snippet: Man Ray, Le Violon d'Ingres (1924). Courtesy of Christie's. This weekend, an iconic Man Ray print sold for $12.4 million at Christie's, nearly tripling the record for the most expensive photograph ever sold at auction.
# highlight: None
#
# source: barnebys.com
# date: May 14, 2023
# title: The 11 Most Expensive Photographers
# snippet: It became the world's most expensive photograph when it sold at Christie's in 2022 for $12.4 million. Find more features on Barnebys Magazine.
# highlight: Christie's
#
# source: artincontext.org
# date: Aug 10, 2023
# title: Most Expensive Photographs - 15 Extravagant Photographs
# snippet: Le Violon D'Ingre (1924) by Man Ray takes first place at an astonishing $12.4 million! Some of the other most expensive photos ever sold include ...
# highlight: Le Violon D'Ingre (1924) by Man Ray
#
# question: Which photographer took the most expensive photograph in the world?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The most expensive photograph in the world is "Le Violon d'Ingres". The photograph was created by Man Ray.
#
#
# query: How many days are left until the 2023 Grammy Awards?
#
# source: en.wikipedia.org
# date: None
# title: 65th Annual Grammy Awards
# snippet: The 65th Annual Grammy Awards ceremony was held at the Crypto.com Arena in Los Angeles on February 5, 2023. It recognized the best recordings, compositions, ...
# highlight: Grammy Awards | in | 2023
#
# source: grammy.com
# date: None
# title: Everything You Need To Know About The 2023 GRAMMYs ...
# snippet: The eligibility period for the 65th GRAMMY Awards is Friday, Oct. 1, 2021 – Friday, Sept. 30, 2022. All eligible awards entries must be released within this ...
# highlight: for | GRAMMY Awards
#
# source: recordingacademy.com
# date: None
# title: 2023 GRAMMYs: Everything You Need To Know About ...
# snippet: There are only two days left to participate in first-round voting for the 2023 GRAMMYs; final-round voting will commence Dec. 14. If you're a Recording ...
# highlight: two days
#
# source: grammy.com
# date: None
# title: Air Date For 2023 GRAMMYs Announced
# snippet: This year's GRAMMY nominees will be announced on Tuesday, Nov. 15, with the 2023 GRAMMYs airing live Sunday, Feb. 5, from the Crypto.com Arena in Los Angeles.
# highlight: GRAMMY | 2023 GRAMMYs | in
#
# source: recordingacademy.com
# date: None
# title: How long until the next Grammy Awards?
# snippet: THE 66TH ANNUAL GRAMMY AWARDS® SET TO TAKE PLACE SUN, FEB. 4, 2024 | RECORDINGACADEMY.com.
# highlight: None
#
# source: grammy.com
# date: None
# title: What time is GRAMMYs 2023 over?
# snippet: The 2023 GRAMMYs will air live on Sunday, Feb. 5, at 8-11:30 p.m. ET/5-8:30 p.m. PT from the Crypto.com Arena in Los Angeles.
# highlight: None
#
# source: variety.com
# date: Jul 14, 2022
# title: Grammy Awards Announce Key Dates for 2023 Race
# snippet: Nominees will be announced this year on Nov. 15, with the first round of voting set from Oct. 13 to Oct. 23 and a final round on Dec. 14 to Jan.
# highlight: None
#
# source: billboard.com
# date: Jul 14, 2022
# title: Here's the Date & Location of the 2023 Grammy Awards
# snippet: Nominations will be announced on Tuesday, Nov. 15 -- eight days earlier than they were last year.
# highlight: eight days
#
# source: en.as.com
# date: Feb 01, 2023
# title: 2023 Grammy Awards: Who's attending, skipping, and ...
# snippet: With only a few days left until the 65th annual Grammy Awards, and the full performer lineup yet to be announced, here is how the show is ...
# highlight: only a few days
#
# source: howmanydaysuntil.center
# date: Feb 04, 2023
# title: When ar The Grammy Awards - How Many Days Until
# snippet: The Grammy Awards will be celebrated this year on is on February 4th. Find out more about The Grammy Awards.
# highlight: February 4th
#
# source: cnn.com
# date: Feb 05, 2023
# title: How to watch the Grammys: Time, channels and more
# snippet: How to watch the 2023 Grammy Awards: Time, channels and more · Day and time. The Grammy Awards air Sunday, February 5, at 8 p.m. ET/5 p.m. PT.
# highlight: 2023 Grammy Awards | Day | Grammy Awards
#
# source: nytimes.com
# date: Feb 06, 2023
# title: How to Watch the 2023 Grammys
# snippet: The ceremony will air live on Sunday, at 8 p.m. Eastern time (5 p.m. Pacific time) on CBS and stream live on Paramount+. Before the prime-time ...
# highlight: Before the
#
# source: billboard.com
# date: Nov 10, 2023
# title: What is the deadline for Grammy nominations 2023?
# snippet: This year's eligibility period ran from Oct. 1, 2022, through Sept. 15, 2023. The final round of Grammy voting, which will determine the winners, will take place Dec. 14 through Jan. 4, 2024.
# highlight: None
#
# question: How many days are left until the 2023 Grammy Awards?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The 2023 Grammy Awards ceremony was held on February 5, 2023. Thus, the ceremony has already taken place.
#
#
# query: How many years ago did the Boxing Day Tsunami happen?
#
# source: knowledge.aidr.org.au
# date: None
# title: The Boxing Day Tsunami in numbers Stats and facts
# snippet: The Tangshan Earthquake in China killed at least 255,000 in 1976. Flooding in Bangladesh in 2004 destroyed over 1 million homes, displaced over 4 million ...
# 	2 pages
# highlight: Earthquake | 2004
#
# source: knowledge.aidr.org.au
# date: None
# title: Indian Ocean tsunami, 2004 | Australian Disasters
# snippet: In December 2004, a massive earthquake struck off the west coast of Sumatra. The resulting Indian Ocean tsunami caused widespread destruction. Learn more.
# highlight: December 2004
#
# source: britannica.com
# date: None
# title: Indian Ocean tsunami of 2004 | Facts & Death Toll
# snippet: Indian Ocean tsunami of 2004, deadly tsunami that hit the coasts of several countries of South and Southeast Asia and caused immense destruction.
# highlight: 2004
#
# source: britannica.com
# date: None
# title: How long did the 2004 tsunami last?
# snippet: How long did the Indian Ocean tsunami of 2004 last? The Indian Ocean tsunami of 2004 lasted for seven hours and reached out across the Indian Ocean, devastating coastal areas of Indonesia, Sri Lanka, India, Maldives, and Thailand, and as far away as East Africa.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: 2004 Indian Ocean earthquake and tsunami - Wikipedia
# snippet: On 26 December 2004, at 07:58:53 local time (UTC+7), a major earthquake with a magnitude of 9.1–9.3 Mw struck with an epicentre off the west coast of northern Sumatra, Indonesia.
# highlight: None
#
# source: history.com
# date: Oct 02, 2018
# title: The 2004 Tsunami Wiped Away Towns With 'Mind- ...
# snippet: The Boxing Day tsunami would be the deadliest in recorded history, taking a staggering 230,000 lives in a matter of hours. The city of Banda ...
# highlight: 230,000
#
# source: reuters.com
# date: Dec 18, 2019
# title: 15 years on, a look back at the Boxing Day tsunami
# snippet: December 26 marks 15 years since a 9.1 magnitude quake off the coast of Indonesia's Aceh province triggered a tsunami that killed more than ...
# highlight: 15 years
#
# source: preventionweb.net
# date: Jun 26, 2021
# title: Indian Ocean tsunami: What was learned about recovery
# snippet: We've been following victims of the Boxing Day tsunami for 16 years – this is what we've learned about recovering from disaster. Source(s): ...
# highlight: 16 years
#
# source: materchristi.libguides.com
# date: May 11, 2023
# title: 2004 Indian Ocean Tsunami - Natural disasters of the Asia ...
# snippet: The Boxing Day tsunami in 2004 is believed to be the deadliest tsunami in history, killing more than 230,000 people across 14 countries.
# highlight: 2004
#
# source: noaa.gov
# date: Jun 12, 2023
# title: JetStream Max: 2004 Indian Ocean Tsunami
# snippet: On December 26, 2004, an extremely powerful earthquake off the coast of the Indonesian island of Sumatra in the Indian Ocean generated a ...
# highlight: December 26, 2004
#
# source: noaa.gov
# date: Jun 12, 2023
# title: When did the Boxing Day tsunami occur?
# snippet: On December 26, 2004, an extremely powerful earthquake off the coast of the Indonesian island of Sumatra in the Indian Ocean generated a devastating tsunami.
# highlight: None
#
# source: worldvision.org
# date: Sep 25, 2023
# title: 2004 Indian Ocean Earthquake and Tsunami
# snippet: Discover the 2004 Indian Ocean tsunami's historic impact and World Vision's multi-country humanitarian efforts that lasted over a decade.
# highlight: 2004
#
# source: worldvision.org
# date: Sep 25, 2023
# title: What was the worst tsunami in 2004?
# snippet: Approximately 230,000 people died in the 2004 Indian Ocean earthquake and tsunami, making it one of the deadliest disasters in modern history. The Sumatra-Andaman earthquake, which caused the tsunami, is estimated to have released energy equivalent to 23,000 Hiroshima-type atomic bombs.
# highlight: None
#
# question: How many years ago did the Boxing Day Tsunami happen?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The disaster occurred on December 26, 2004. Thus, it happened 18 years ago.
#
#
# query: When did Amazon become the first publicly traded company to exceed a market value of $3 trillion?
#
# source: en.wikipedia.org
# date: None
# title: List of public corporations by market capitalization
# snippet: The table below lists all companies which have, at any point, had a market capitalization in excess of $1 trillion, the date on which their market cap first ...
# highlight: companies | market capitalization | excess | trillion | market cap first
#
# source: cbsnews.com
# date: Sep 04, 2018
# title: Amazon becomes second trillion-dollar company in US
# snippet: Amazon hits $1 trillion and becomes the second U.S. company worth one trillion dollars after stock price surged Tuesday - CBS News.
# highlight: after stock price surged Tuesday
#
# source: cnbc.com
# date: Jan 03, 2022
# title: Apple becomes first U.S. company to reach $3 trillion ...
# snippet: Apple became the first publicly traded U.S. company to hit a $1 trillion market cap during intraday trading on Aug. 2, 2018. It hit a $2 ...
# highlight: Aug. 2, 2018
#
# source: fortune.com
# date: Nov 02, 2022
# title: As Amazon's value drops below $1 trillion, this chart shows ...
# snippet: On November 1, Amazon reached a bleak milestone when its value dropped below $1 trillion for the first time since first crossing that ...
# highlight: On November 1
#
# source: financialpost.com
# date: Nov 09, 2022
# title: Amazon becomes first public company to lose $1 trillion ...
# snippet: Amazon.com Inc. is the world's first public company to lose a trillion dollars in market value as a combination of rising inflation ...
# highlight: Amazon | is the | first public company | trillion | market value
#
# source: bloomberg.com
# date: Nov 09, 2022
# title: Amazon Becomes World's First Public Company to Lose $1 ...
# snippet: Amazon.com Inc. is the world's first public company to lose a trillion dollars in market value as a combination of rising inflation, ...
# highlight: Amazon | is the | first public company | trillion | market value
#
# source: fortune.com
# date: Jun 30, 2023
# title: Apple becomes first $3 trillion market value company
# snippet: Apple first became the world's most valuable stock in 2011, when its market cap was under $340 billion and it comprised about 3.3% of the S&P ...
# highlight: 2011
#
# source: qz.com
# date: Jun 30, 2023
# title: Apple is officially the world's first-ever $3 trillion company
# snippet: Apple became the first company in the world with a $3 trillion valuation on Friday (June 30). The company's stock closed at $193.97 per share— ...
# highlight: Friday (June 30
#
# source: zeebiz.com
# date: Jun 30, 2023
# title: What company has reached the market cap of 3 trillion?
# snippet: Apple is once again worth $3 trillion, the only company ever to reach the milestone, a media report said. Its shares rose 1 per cent on Friday to hit a record $191.34. With 15.7 billion shares outstanding, the stock price pushed Apple to its historic market value, CNN reported.
# highlight: None
#
# source: nbcnews.com
# date: Jun 30, 2023
# title: Is Apple the first US company to reach $3 trillion market cap?
# snippet: The news shows investors remain bullish on the stock and Apple's portfolio of products and services, despite the company's warning in May that its current quarter revenue is expected to fall about 3%.
# highlight: None
#
# source: fortune.com
# date: Jun 30, 2023
# title: What is the first $3 trillion dollar company?
# snippet: Apple just made history by becoming the first company with a $3 trillion market value—'and its lock on the consumer is only getting stronger' Apple CEO Tim Cook.
# highlight: None
#
# source: cityindex.com
# date: Aug 24, 2023
# title: A guide to trillion-dollar companies
# snippet: Apple did become the world's first $3 trillion company in June 2023 but hasn't retained that market capitalisation in the subsequent months.
# highlight: June 2023
#
# source: money.usnews.com
# date: Oct 24, 2023
# title: The 10 Most Valuable Companies in the World by Market ...
# snippet: (ticker: AAPL) was the first company to reach a market capitalization of $1 trillion in 2018. ... Overall, Amazon has become the largest online ...
# highlight: 2018
#
# question: When did Amazon become the first publicly traded company to exceed a market value of $3 trillion?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. Amazon's market capitalization has never exceeded $3 trillion.

# %% [markdown]
# ## freshprompt_format method

# %%
question = "今年のルヴァンカップを優勝したサッカーチームはどこですか？"

# %%
# modelにgpt-4を利用する場合
num_organic_results = 15
num_related_questions = 3
num_questions_and_answers = 3
num_retrieved_evidences = 15

# %%
import pandas as pd

df = pd.DataFrame(columns=['source', 'date', 'title', 'snippet', 'highlight'])

# %%
search_data = call_search_engine(question)

# %%
search_data
# Out:
# {'search_metadata': {'id': '6553e5a3c56d93c332827067',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/b4ff1bef10e4c0d8/6553e5a3c56d93c332827067.json',
#   'created_at': '2023-11-14 21:24:51 UTC',
#   'processed_at': '2023-11-14 21:24:51 UTC',
#   'google_url': 'https://www.google.com/search?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&oq=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&hl=ja&gl=jp&sourceid=chrome&ie=UTF-8',
#   'raw_html_file': 'https://serpapi.com/searches/b4ff1bef10e4c0d8/6553e5a3c56d93c332827067.html',
#   'total_time_taken': 2.43},
#  'search_parameters': {'engine': 'google',
#   'q': '今年のルヴァンカップを優勝したサッカーチームはどこですか？',
#   'google_domain': 'google.com',
#   'hl': 'ja',
#   'gl': 'jp',
#   'device': 'desktop'},
#  'search_information': {'query_displayed': '今年のルヴァンカップを優勝したサッカーチームはどこですか？',
#   'total_results': 43100,
#   'time_taken_displayed': 0.43,
#   'menu_items': [{'position': 1, 'title': 'すべて'},
#    {'position': 2,
#     'title': 'ニュース',
#     'link': 'https://www.google.com/search?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&tbm=nws&source=lnms&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ_AUoAXoECAEQAw',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&tbm=nws'},
#    {'position': 3,
#     'title': '画像',
#     'link': 'https://www.google.com/search?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&tbm=isch&source=lnms&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ_AUoAnoECAEQBA',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_images&gl=jp&google_domain=google.com&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F'},
#    {'position': 4,
#     'title': '書籍',
#     'link': 'https://www.google.com/search?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&tbm=bks&source=lnms&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ_AUoA3oECAEQBQ'},
#    {'position': 5,
#     'title': '動画',
#     'link': 'https://www.google.com/search?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&tbm=vid&source=lnms&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ_AUoBHoECAEQBg',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_videos&gl=jp&google_domain=google.com&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F'},
#    {'position': 6,
#     'title': '地図',
#     'link': 'https://maps.google.com/maps?gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&um=1&ie=UTF-8&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ_AUoAHoECAEQCg'},
#    {'position': 7,
#     'title': 'ショッピング',
#     'link': 'https://www.google.com/search?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&tbm=shop&source=lnms&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ_AUoAXoECAEQCw',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=jp&google_domain=google.com&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F'},
#    {'position': 8,
#     'title': 'フライト',
#     'link': 'https://www.google.com/travel/flights?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&tbm=flm&source=lnms&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ_AUoAnoECAEQDA'},
#    {'position': 9,
#     'title': 'ファイナンス',
#     'link': 'https://www.google.com/finance?sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ_AUoA3oECAEQDQ'}],
#   'organic_results_state': 'Results for exact spelling'},
#  'inline_images': [{'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&tbm=isch&source=univ&fir=x8xbpThL1gNzIM%252CTor2QN-kDqBozM%252C_%253BXyzmYJpiaspI5M%252CtqhGZ2gPFmGPoM%252C_%253B8ufMF6opuTQs7M%252CdpGREUDlhFIiNM%252C_%253BdemdExAEvzZGyM%252CAidEn-UB9yJVmM%252C_%253B3TCEWjfrzSeipM%252CgJn3H7tgXwqS7M%252C_%253BCSWVS88ISK4ayM%252CN3G56R6ryDxZDM%252C_%253B9_lIa-Nk6122qM%252C-unnjDRfwD7oBM%252C_%253Bof1vL739a8AZ7M%252CEc2DpyHAPiqMgM%252C_%253B1UkXcQ5UtEt5JM%252Cwqs6aveIheyLpM%252C_%253BqyKZLCVIufuvvM%252CBNg1rahpm9ADzM%252C_&usg=AI4_-kTiHCn-F0Xo6H8nQLTxxpDSJ-zKrQ&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ9AF6BAgtEAA#imgrc=x8xbpThL1gNzIM',
#    'source': 'https://www.jleague.jp/j-tano/2966',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQAho-3wOr4bpy7z8kcC0dXDKIHE3Hn5bT3lbjT8cngeg&s',
#    'original': 'https://cdn.curation.jleague.jp/files/article/2966/211309226548e4ee015b5.jpg',
#    'title': '公式】【祝・初タイトル】アビスパ福岡のルヴァンカップ優勝を ...',
#    'source_name': 'Jリーグ'},
#   {'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&tbm=isch&source=univ&fir=x8xbpThL1gNzIM%252CTor2QN-kDqBozM%252C_%253BXyzmYJpiaspI5M%252CtqhGZ2gPFmGPoM%252C_%253B8ufMF6opuTQs7M%252CdpGREUDlhFIiNM%252C_%253BdemdExAEvzZGyM%252CAidEn-UB9yJVmM%252C_%253B3TCEWjfrzSeipM%252CgJn3H7tgXwqS7M%252C_%253BCSWVS88ISK4ayM%252CN3G56R6ryDxZDM%252C_%253B9_lIa-Nk6122qM%252C-unnjDRfwD7oBM%252C_%253Bof1vL739a8AZ7M%252CEc2DpyHAPiqMgM%252C_%253B1UkXcQ5UtEt5JM%252Cwqs6aveIheyLpM%252C_%253BqyKZLCVIufuvvM%252CBNg1rahpm9ADzM%252C_&usg=AI4_-kTiHCn-F0Xo6H8nQLTxxpDSJ-zKrQ&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ9AF6BAgrEAA#imgrc=XyzmYJpiaspI5M',
#    'source': 'https://www.goal.com/jp/%E3%83%8B%E3%83%A5%E3%83%BC%E3%82%B9/levain-final-fukuoka-urawa-20231104/bltae3040a37817e5b5',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRQ8hteHBcp_NEMktKkfI4kiwoI1YLmhO9GbMJ1OMoPqQ&s',
#    'original': 'https://assets.goal.com/v3/assets/bltcc7a7ffd2fbf71f5/bltcaafa5cddb2c4311/6545dec08dfd37040a684e90/1773815314_2.jpg?auto=webp&format=pjpg&width=3840&quality=60',
#    'title': '福岡がルヴァンカップ初優勝！浦和を下し、クラブ史上初の ...',
#    'source_name': 'Goal.com'},
#   {'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&tbm=isch&source=univ&fir=x8xbpThL1gNzIM%252CTor2QN-kDqBozM%252C_%253BXyzmYJpiaspI5M%252CtqhGZ2gPFmGPoM%252C_%253B8ufMF6opuTQs7M%252CdpGREUDlhFIiNM%252C_%253BdemdExAEvzZGyM%252CAidEn-UB9yJVmM%252C_%253B3TCEWjfrzSeipM%252CgJn3H7tgXwqS7M%252C_%253BCSWVS88ISK4ayM%252CN3G56R6ryDxZDM%252C_%253B9_lIa-Nk6122qM%252C-unnjDRfwD7oBM%252C_%253Bof1vL739a8AZ7M%252CEc2DpyHAPiqMgM%252C_%253B1UkXcQ5UtEt5JM%252Cwqs6aveIheyLpM%252C_%253BqyKZLCVIufuvvM%252CBNg1rahpm9ADzM%252C_&usg=AI4_-kTiHCn-F0Xo6H8nQLTxxpDSJ-zKrQ&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ9AF6BAgsEAA#imgrc=8ufMF6opuTQs7M',
#    'source': 'https://news.yahoo.co.jp/articles/dcbfb45dd4e272047d3146c1f3c80eeaa712524c',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTeUfSPJQ7-w_65SFTV3zMhTbkODRFigvWHq0lluZrdLw&s',
#    'original': 'https://newsatcl-pctr.c.yimg.jp/t/amd-img/20231105-00000007-dal-000-2-view.jpg?exp=10800&fmt=webp',
#    'title': '福岡 初優勝！ルヴァン杯制しチーム初タイトル 長谷部監督 ...',
#    'source_name': 'Yahoo!ニュース - Yahoo! JAPAN'},
#   {'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&tbm=isch&source=univ&fir=x8xbpThL1gNzIM%252CTor2QN-kDqBozM%252C_%253BXyzmYJpiaspI5M%252CtqhGZ2gPFmGPoM%252C_%253B8ufMF6opuTQs7M%252CdpGREUDlhFIiNM%252C_%253BdemdExAEvzZGyM%252CAidEn-UB9yJVmM%252C_%253B3TCEWjfrzSeipM%252CgJn3H7tgXwqS7M%252C_%253BCSWVS88ISK4ayM%252CN3G56R6ryDxZDM%252C_%253B9_lIa-Nk6122qM%252C-unnjDRfwD7oBM%252C_%253Bof1vL739a8AZ7M%252CEc2DpyHAPiqMgM%252C_%253B1UkXcQ5UtEt5JM%252Cwqs6aveIheyLpM%252C_%253BqyKZLCVIufuvvM%252CBNg1rahpm9ADzM%252C_&usg=AI4_-kTiHCn-F0Xo6H8nQLTxxpDSJ-zKrQ&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ9AF6BAg_EAA#imgrc=demdExAEvzZGyM',
#    'source': 'https://news.yahoo.co.jp/articles/593749f784194f31fe305632649e2efb297a6b59',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSie1PZr-uCnZzS9iD22pnEVyHLULqUwH1U3C2oKv7Jvg&s',
#    'original': 'https://newsatcl-pctr.c.yimg.jp/t/amd-img/20231104-00010016-goal-000-8-view.jpg?pri=l&w=640&h=640&exp=10800',
#    'title': '福岡がルヴァンカップ初優勝！浦和を下し、クラブ史上初の ...',
#    'source_name': 'Yahoo!ニュース - Yahoo! JAPAN'},
#   {'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&tbm=isch&source=univ&fir=x8xbpThL1gNzIM%252CTor2QN-kDqBozM%252C_%253BXyzmYJpiaspI5M%252CtqhGZ2gPFmGPoM%252C_%253B8ufMF6opuTQs7M%252CdpGREUDlhFIiNM%252C_%253BdemdExAEvzZGyM%252CAidEn-UB9yJVmM%252C_%253B3TCEWjfrzSeipM%252CgJn3H7tgXwqS7M%252C_%253BCSWVS88ISK4ayM%252CN3G56R6ryDxZDM%252C_%253B9_lIa-Nk6122qM%252C-unnjDRfwD7oBM%252C_%253Bof1vL739a8AZ7M%252CEc2DpyHAPiqMgM%252C_%253B1UkXcQ5UtEt5JM%252Cwqs6aveIheyLpM%252C_%253BqyKZLCVIufuvvM%252CBNg1rahpm9ADzM%252C_&usg=AI4_-kTiHCn-F0Xo6H8nQLTxxpDSJ-zKrQ&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ9AF6BAhFEAA#imgrc=3TCEWjfrzSeipM',
#    'source': 'https://news.yahoo.co.jp/articles/7dd515296a44f16d4124611af15ea873decfe186',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQkzSuzk57XU7E-W7tOH_MAoVM2avgae1rFPm5-afkzQQ&s',
#    'original': 'https://newsatcl-pctr.c.yimg.jp/t/amd-img/20231104-00010018-nishispo-000-6-view.jpg?pri=l&w=640&h=423&exp=10800',
#    'title': '福岡がルヴァン・カップ初優勝 浦和を撃破 経営危機など苦難 ...',
#    'source_name': 'Yahoo!ニュース - Yahoo! JAPAN'},
#   {'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&tbm=isch&source=univ&fir=x8xbpThL1gNzIM%252CTor2QN-kDqBozM%252C_%253BXyzmYJpiaspI5M%252CtqhGZ2gPFmGPoM%252C_%253B8ufMF6opuTQs7M%252CdpGREUDlhFIiNM%252C_%253BdemdExAEvzZGyM%252CAidEn-UB9yJVmM%252C_%253B3TCEWjfrzSeipM%252CgJn3H7tgXwqS7M%252C_%253BCSWVS88ISK4ayM%252CN3G56R6ryDxZDM%252C_%253B9_lIa-Nk6122qM%252C-unnjDRfwD7oBM%252C_%253Bof1vL739a8AZ7M%252CEc2DpyHAPiqMgM%252C_%253B1UkXcQ5UtEt5JM%252Cwqs6aveIheyLpM%252C_%253BqyKZLCVIufuvvM%252CBNg1rahpm9ADzM%252C_&usg=AI4_-kTiHCn-F0Xo6H8nQLTxxpDSJ-zKrQ&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ9AF6BAhEEAA#imgrc=CSWVS88ISK4ayM',
#    'source': 'https://olympics.com/ja/news/football-levain-cup-2022-final-result',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRIsrTilaPhABHzSSmebRd7qopfgcC46VgrwWBvBvbBPQ&s',
#    'original': 'https://img.olympics.com/images/image/private/t_s_pog_staticContent_hero_xl_2x/f_auto/primary/ts3jgqm2d2owikrgiebf',
#    'title': 'サッカー】ルヴァンカップ決勝：広島が悲願の初優勝…C大阪は逆転 ...',
#    'source_name': 'Olympics.com'},
#   {'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&tbm=isch&source=univ&fir=x8xbpThL1gNzIM%252CTor2QN-kDqBozM%252C_%253BXyzmYJpiaspI5M%252CtqhGZ2gPFmGPoM%252C_%253B8ufMF6opuTQs7M%252CdpGREUDlhFIiNM%252C_%253BdemdExAEvzZGyM%252CAidEn-UB9yJVmM%252C_%253B3TCEWjfrzSeipM%252CgJn3H7tgXwqS7M%252C_%253BCSWVS88ISK4ayM%252CN3G56R6ryDxZDM%252C_%253B9_lIa-Nk6122qM%252C-unnjDRfwD7oBM%252C_%253Bof1vL739a8AZ7M%252CEc2DpyHAPiqMgM%252C_%253B1UkXcQ5UtEt5JM%252Cwqs6aveIheyLpM%252C_%253BqyKZLCVIufuvvM%252CBNg1rahpm9ADzM%252C_&usg=AI4_-kTiHCn-F0Xo6H8nQLTxxpDSJ-zKrQ&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ9AF6BAhGEAA#imgrc=9_lIa-Nk6122qM',
#    'source': 'https://news.yahoo.co.jp/articles/ab07521efabbdc3deda1e8d9568728589981a197',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRMVbvG_RyhNVYKcwqJLV4Q2I1IlCEoUV4xZv2F_Z4e9w&s',
#    'original': 'https://newsatcl-pctr.c.yimg.jp/t/amd-img/20231104-01827180-soccerk-000-3-view.jpg?exp=10800',
#    'title': 'アビスパ福岡が浦和レッズを下し、ルヴァン杯優勝！ クラブ史上 ...',
#    'source_name': 'Yahoo!ニュース - Yahoo! JAPAN'},
#   {'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&tbm=isch&source=univ&fir=x8xbpThL1gNzIM%252CTor2QN-kDqBozM%252C_%253BXyzmYJpiaspI5M%252CtqhGZ2gPFmGPoM%252C_%253B8ufMF6opuTQs7M%252CdpGREUDlhFIiNM%252C_%253BdemdExAEvzZGyM%252CAidEn-UB9yJVmM%252C_%253B3TCEWjfrzSeipM%252CgJn3H7tgXwqS7M%252C_%253BCSWVS88ISK4ayM%252CN3G56R6ryDxZDM%252C_%253B9_lIa-Nk6122qM%252C-unnjDRfwD7oBM%252C_%253Bof1vL739a8AZ7M%252CEc2DpyHAPiqMgM%252C_%253B1UkXcQ5UtEt5JM%252Cwqs6aveIheyLpM%252C_%253BqyKZLCVIufuvvM%252CBNg1rahpm9ADzM%252C_&usg=AI4_-kTiHCn-F0Xo6H8nQLTxxpDSJ-zKrQ&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ9AF6BAhHEAA#imgrc=of1vL739a8AZ7M',
#    'source': 'https://www3.nhk.or.jp/news/html/20231104/k10014247121000.html',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR4_5yCqhA_gYEIYTMUzxihozNE-CPg6M6WW5D1vFJMOw&s',
#    'original': 'https://www3.nhk.or.jp/news/html/20231104/K10014247121_2311041558_1104155859_01_02.jpg',
#    'title': 'ルヴァンカップ アビスパ福岡 浦和レッズに勝ち初優勝 初 ...',
#    'source_name': 'NHKニュース'},
#   {'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&tbm=isch&source=univ&fir=x8xbpThL1gNzIM%252CTor2QN-kDqBozM%252C_%253BXyzmYJpiaspI5M%252CtqhGZ2gPFmGPoM%252C_%253B8ufMF6opuTQs7M%252CdpGREUDlhFIiNM%252C_%253BdemdExAEvzZGyM%252CAidEn-UB9yJVmM%252C_%253B3TCEWjfrzSeipM%252CgJn3H7tgXwqS7M%252C_%253BCSWVS88ISK4ayM%252CN3G56R6ryDxZDM%252C_%253B9_lIa-Nk6122qM%252C-unnjDRfwD7oBM%252C_%253Bof1vL739a8AZ7M%252CEc2DpyHAPiqMgM%252C_%253B1UkXcQ5UtEt5JM%252Cwqs6aveIheyLpM%252C_%253BqyKZLCVIufuvvM%252CBNg1rahpm9ADzM%252C_&usg=AI4_-kTiHCn-F0Xo6H8nQLTxxpDSJ-zKrQ&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ9AF6BAhIEAA#imgrc=1UkXcQ5UtEt5JM',
#    'source': 'https://www.jleague.jp/',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRn8EPt7ThjFpQvqCKnr7OMW5rSnDiUkJinOOtI6zFSdg&s',
#    'original': 'https://www.jleague.jp/img/top/4759pickup.jpg?_=1699853280',
#    'title': '公式】Jリーグ公式サイト（J.LEAGUE.jp）',
#    'source_name': 'www.jleague.jp'},
#   {'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&tbm=isch&source=univ&fir=x8xbpThL1gNzIM%252CTor2QN-kDqBozM%252C_%253BXyzmYJpiaspI5M%252CtqhGZ2gPFmGPoM%252C_%253B8ufMF6opuTQs7M%252CdpGREUDlhFIiNM%252C_%253BdemdExAEvzZGyM%252CAidEn-UB9yJVmM%252C_%253B3TCEWjfrzSeipM%252CgJn3H7tgXwqS7M%252C_%253BCSWVS88ISK4ayM%252CN3G56R6ryDxZDM%252C_%253B9_lIa-Nk6122qM%252C-unnjDRfwD7oBM%252C_%253Bof1vL739a8AZ7M%252CEc2DpyHAPiqMgM%252C_%253B1UkXcQ5UtEt5JM%252Cwqs6aveIheyLpM%252C_%253BqyKZLCVIufuvvM%252CBNg1rahpm9ADzM%252C_&usg=AI4_-kTiHCn-F0Xo6H8nQLTxxpDSJ-zKrQ&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ9AF6BAhDEAA#imgrc=qyKZLCVIufuvvM',
#    'source': 'https://www.jleague.jp/news/article/23590/?utm_source=twitter&utm_medium=social',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRZsjaiL3HiHypFqfEeFEOIz-vQeNrNv-XzDDjkrIwksQ&s',
#    'original': 'https://www.jleague.jp/img/news/2022/10/23590.jpg',
#    'title': '公式】広島が悲願の初優勝！後半ATのソティリウ劇的2発で大逆転 ...',
#    'source_name': 'Jリーグ'}],
#  'related_questions': [{'question': 'ルヴァンカップ決勝 どこで？',
#    'snippet': '決勝の開催日、開催スタジアム、TV放送決定のお知らせ【ルヴァンカップ】 「２０２３ＪリーグYBCルヴァンカップ 決勝」の開催日、開催スタジアムおよびTV放送が下記の通り決定しましたのでお知らせいたします。 決勝は11月4日（土）に国立競技場にて開催いたします。',
#    'title': '開催スタジアム、TV放送決定のお知らせ【ルヴァンカップ】',
#    'link': 'https://www.jleague.jp/news/article/24620/?utm_source=twitter&utm_medium=social#:~:text=%E6%B0%B4)%2013%3A00-,%E6%B1%BA%E5%8B%9D%E3%81%AE%E9%96%8B%E5%82%AC%E6%97%A5%E3%80%81%E9%96%8B%E5%82%AC%E3%82%B9%E3%82%BF%E3%82%B8%E3%82%A2%E3%83%A0%E3%80%81TV%E6%94%BE%E9%80%81,%E6%B1%BA%E5%AE%9A%E3%81%AE%E3%81%8A%E7%9F%A5%E3%82%89%E3%81%9B%E3%80%90%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%80%91&text=%E3%80%8C%EF%BC%92%EF%BC%90%EF%BC%92%EF%BC%93%EF%BC%AA%E3%83%AA%E3%83%BC%E3%82%B0YBC%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97,%E3%81%AB%E3%81%A6%E9%96%8B%E5%82%AC%E3%81%84%E3%81%9F%E3%81%97%E3%81%BE%E3%81%99%E3%80%82',
#    'displayed_link': 'https://www.jleague.jp › news › article',
#    'thumbnail': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/9bc2a035e5a3a99ff9c9b6e01d707a08c4cd33589b56f5faa0cfdf0d0d2d7c2c.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D'},
#   {'question': 'ルヴァンカップの優勝者は？',
#    'title': '歴代優勝',
#    'link': 'https://www.nikkansports.com/soccer/jleague/jcup/jcup-record.html',
#    'displayed_link': 'https://www.nikkansports.com › jcup › jcup-record',
#    'thumbnail': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/9bc2a035e5a3a99ff9c9b6e01d707a08011ee678aad7886a2a9fc6e55c9f4d2d.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%%3D'},
#   {'question': 'ルヴァンカップのグループBの順位は？',
#    'title': 'Bグループ',
#    'link': 'https://www.jleague.jp/leaguecup/2023/standings/',
#    'displayed_link': 'https://www.jleague.jp › leaguecup › standings',
#    'thumbnail': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/9bc2a035e5a3a99ff9c9b6e01d707a087cb3d609a5ab1b2b87e0117bbe013658.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D'},
#   {'question': 'サガン鳥栖とサンフレッチェ広島の順位は？',
#    'title': 'Ｊ１リーグ',
#    'link': 'https://www.sagan-tosu.net/match/standings/',
#    'displayed_link': 'https://www.sagan-tosu.net › match › standings',
#    'thumbnail': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/9bc2a035e5a3a99ff9c9b6e01d707a084a9ef9d05feee7709678b3d6d9d247c7.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%...'}],
#  'answer_box': {'type': 'organic_result',
#   'title': '【祝・初タイトル】アビスパ福岡のルヴァンカップ優勝を ...',
#   'link': 'https://www.jleague.jp/j-tano/2966#:~:text=11%E6%9C%884%E6%97%A5%E3%81%AB,%E5%84%AA%E5%8B%9D%E3%81%AB%E8%BC%9D%E3%81%8D%E3%81%BE%E3%81%97%E3%81%9F%EF%BC%81',
#   'displayed_link': 'https://www.jleague.jp › j-tano',
#   'date': '5 日前',
#   'snippet': '11月4日に国立競技場で２０２３ＪリーグＹＢＣルヴァンカップ決勝が行われ、アビスパ福岡が浦和レッズを下して初優勝に輝きました！',
#   'snippet_highlighted_words': ['アビスパ福岡'],
#   'favicon': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/a613f11f13c4385c5ee4372560c9482f2a0904b7c2d46a97.png',
#   'source': 'jleague.jp',
#   'about_this_result': {}},
#  'organic_results': [{'position': 1,
#    'title': 'ルヴァンカップMVPは福岡MF前寛之！ 恩師・長谷部監督 ...',
#    'link': 'https://www.soccer-king.jp/news/japan/jl/20231104/1827200.html',
#    'displayed_link': 'https://www.soccer-king.jp › ... › 前 寛之',
#    'favicon': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/327702b3da66ea42f02ad3dfda69fd553b7e8070d257325e928c0300c5843f5a.png',
#    'date': '2023/11/04',
#    'snippet': '『2023JリーグYBCルヴァンカップ』の決勝戦が4日に行われ、アビスパ福岡が2－1で浦和レッズを下して初優勝。この試合で貴重な先制点を記録し、MVPを ...',
#    'snippet_highlighted_words': ['ルヴァンカップ', '優勝'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://www.soccer-king.jp/news/japan/jl/20231104/1827200.html&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fwww.soccer-king.jp%2Fnews%2Fjapan%2Fjl%2F20231104%2F1827200.html',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:mROUTne8s_IJ:https://www.soccer-king.jp/news/japan/jl/20231104/1827200.html&hl=ja&gl=jp',
#    'source': 'サッカーキング'},
#   {'position': 2,
#    'title': '【公式】YBCルヴァンカップの順位表 - Jリーグ',
#    'link': 'https://www.jleague.jp/sp/standings/leaguecup/',
#    'displayed_link': 'https://www.jleague.jp › standings › leaguecup',
#    'favicon': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/327702b3da66ea42f02ad3dfda69fd556cf89bcfbb9406ab06ec2dc06cbab518.png',
#    'date': '2023/06/18',
#    'snippet': '（1）グループステージが終了した時点で、勝点合計の多いチームを上位とし、順位を決定する。ただし、勝点が同じ場合は、以下の順によって順位を決定する ...',
#    'snippet_highlighted_words': ['した', 'チーム'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://www.jleague.jp/sp/standings/leaguecup/&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fwww.jleague.jp%2Fsp%2Fstandings%2Fleaguecup%2F',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:9kwtChmzTIAJ:https://www.jleague.jp/sp/standings/leaguecup/&hl=ja&gl=jp',
#    'missing': ['優勝'],
#    'must_include': {'word': '優勝',
#     'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92+%22%E5%84%AA%E5%8B%9D%22+%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ5t4CegQIIBAB'},
#    'source': 'jleague.jp'},
#   {'position': 3,
#    'title': 'ルヴァンカップの決勝でアビスパ福岡が優勝しましたが',
#    'link': 'https://detail.chiebukuro.yahoo.co.jp/qa/question_detail/q14288596484',
#    'displayed_link': 'https://detail.chiebukuro.yahoo.co.jp › ... › スポーツ',
#    'date': '8 日前',
#    'snippet': 'ルヴァンカップの決勝でアビスパ福岡が優勝しましたが、福岡でもソフトバンクホークスの影に隠れていることが多く厳しい状況が続いていたため感動も ...',
#    'snippet_highlighted_words': ['ルヴァンカップ', '優勝', 'した'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://detail.chiebukuro.yahoo.co.jp/qa/question_detail/q14288596484&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fdetail.chiebukuro.yahoo.co.jp%2Fqa%2Fquestion_detail%2Fq14288596484',
#    'source': 'Yahoo! JAPAN'},
#   {'position': 4,
#    'title': '【ルヴァンカップ】賞金と歴代優勝チーム一覧 - スポスル',
#    'link': 'https://sposuru.com/contents/money-situation/soccer-levain-cup/',
#    'displayed_link': 'https://sposuru.com › contents › soccer-levain-cup',
#    'favicon': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/327702b3da66ea42f02ad3dfda69fd55dba6a71dc9dc0541d4fdd0246970c763.png',
#    'date': '2023/08/09',
#    'snippet': '昔からのサッカーファンには「ヤマザキナビスコカップ」として知られているルヴァンカップ。 Jリーグの始まりと共にスタートしたこの大会ではさまざまな ...',
#    'snippet_highlighted_words': ['サッカー', 'ルヴァンカップ', 'した'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://sposuru.com/contents/money-situation/soccer-levain-cup/&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fsposuru.com%2Fcontents%2Fmoney-situation%2Fsoccer-levain-cup%2F',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:0f6HnUmOtmIJ:https://sposuru.com/contents/money-situation/soccer-levain-cup/&hl=ja&gl=jp',
#    'source': 'sposuru.com'},
#   {'position': 5,
#    'title': '歴代優勝クラブ：2022JリーグYBCルヴァンカップ',
#    'link': 'https://www.jleague.jp/leaguecup/2022/special/report.html',
#    'displayed_link': 'https://www.jleague.jp › leaguecup › special › report',
#    'favicon': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/327702b3da66ea42f02ad3dfda69fd55b5484a8bd703f90291726b14c03fd05d.png',
#    'snippet': '2022JリーグYBCルヴァンカップの30周年特設サイト、過去30年の歴代優勝クラブを紹介。Jリーグ（日本プロサッカーリーグ）試合速報、日程、結果、順位表、写真、 ...',
#    'snippet_highlighted_words': ['ルヴァンカップ', '優勝', 'サッカー'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://www.jleague.jp/leaguecup/2022/special/report.html&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fwww.jleague.jp%2Fleaguecup%2F2022%2Fspecial%2Freport.html',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:_cW2OhAWQhwJ:https://www.jleague.jp/leaguecup/2022/special/report.html&hl=ja&gl=jp',
#    'missing': ['した', 'どこで', 'すか？'],
#    'source': 'jleague.jp'},
#   {'position': 6,
#    'title': '15歳のニュース NEWS・FILE weekly topics 11月3日～11 ...',
#    'link': 'https://mainichi.jp/maisho15/articles/20231111/dbg/048/040/006000c',
#    'displayed_link': 'https://mainichi.jp › maisho15 › articles › dbg',
#    'favicon': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/327702b3da66ea42f02ad3dfda69fd550edf0a7f856ebc9dbb797272671849cc.png',
#    'date': '4 日前',
#    'snippet': 'サッカー ルヴァン・カップ 福岡が初優勝. 国内サッカーの「3大タイトル」の一つ、JリーグのYBCルヴァン・カップの決勝が東京・国立競技場であり、福岡 ...',
#    'snippet_highlighted_words': ['サッカー ルヴァン',
#     'カップ',
#     '優勝',
#     'サッカー',
#     'ルヴァン',
#     'カップ'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://mainichi.jp/maisho15/articles/20231111/dbg/048/040/006000c&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fmainichi.jp%2Fmaisho15%2Farticles%2F20231111%2Fdbg%2F048%2F040%2F006000c',
#    'source': '毎日新聞'},
#   {'position': 7,
#    'title': 'Jリーグ YBCルヴァンカップ」の優勝トロフィーを今年も制作 - ...',
#    'link': 'https://yab.yomiuri.co.jp/adv/feature/release/detail/000000492000010426.html',
#    'displayed_link': 'https://yab.yomiuri.co.jp › feature › release › detail',
#    'favicon': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/327702b3da66ea42f02ad3dfda69fd55d811d6e1e9d07e25b5c8d17d5fb3fb0f.png',
#    'date': '2023/11/03',
#    'snippet': 'ティファニー・アンド・カンパニー・ジャパン・インクティファニーは、「Jリーグ YBCルヴァンカップ」(C)J.LEAGUEの優勝トロフィーを今年も制作 ...',
#    'snippet_highlighted_words': ['ルヴァンカップ', '優勝', '今年'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://yab.yomiuri.co.jp/adv/feature/release/detail/000000492000010426.html&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fyab.yomiuri.co.jp%2Fadv%2Ffeature%2Frelease%2Fdetail%2F000000492000010426.html',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:FQeZx674hpMJ:https://yab.yomiuri.co.jp/adv/feature/release/detail/000000492000010426.html&hl=ja&gl=jp',
#    'source': '読売新聞オンライン'},
#   {'position': 8,
#    'title': 'Jリーグカップ アビスパ福岡 初優勝 クラブ史上初タイトル',
#    'link': 'https://www3.nhk.or.jp/news/html/20231104/k10014247121000.html',
#    'displayed_link': 'https://www3.nhk.or.jp › ... › スポーツニュース一覧',
#    'favicon': 'https://serpapi.com/searches/6553e5a3c56d93c332827067/images/327702b3da66ea42f02ad3dfda69fd558819abe06a9caf872ee2c04e4ce6ba24.png',
#    'date': '2023/11/04',
#    'snippet': 'サッカーの国内3大タイトルの1つ、Jリーグカップの決勝が国立競技場で行われ、アビスパ福岡が浦和レッズに2対1で勝って初めての優勝を果たしました。',
#    'snippet_highlighted_words': ['サッカー', 'カップ', '優勝'],
#    'about_page_link': 'https://www.google.com/search?q=About+https://www3.nhk.or.jp/news/html/20231104/k10014247121000.html&tbm=ilp',
#    'about_page_serpapi_link': 'https://serpapi.com/search.json?engine=google_about_this_result&google_domain=google.com&q=About+https%3A%2F%2Fwww3.nhk.or.jp%2Fnews%2Fhtml%2F20231104%2Fk10014247121000.html',
#    'missing': ['どこで', 'すか？'],
#    'source': 'NHK'}],
#  'related_searches': [{'block_position': 1,
#    'query': 'ルヴァンカップ 優勝すると',
#    'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+%E5%84%AA%E5%8B%9D%E3%81%99%E3%82%8B%E3%81%A8&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ1QJ6BAhCEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+%E5%84%AA%E5%8B%9D%E3%81%99%E3%82%8B%E3%81%A8'},
#   {'block_position': 1,
#    'query': 'ルヴァンカップ 2023',
#    'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+2023&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ1QJ6BAhBEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+2023'},
#   {'block_position': 1,
#    'query': 'ルヴァンカップ歴代優勝チーム',
#    'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E6%AD%B4%E4%BB%A3%E5%84%AA%E5%8B%9D%E3%83%81%E3%83%BC%E3%83%A0&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ1QJ6BAhAEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E6%AD%B4%E4%BB%A3%E5%84%AA%E5%8B%9D%E3%83%81%E3%83%BC%E3%83%A0'},
#   {'block_position': 1,
#    'query': 'ルヴァンカップ 決勝トーナメント',
#    'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+%E6%B1%BA%E5%8B%9D%E3%83%88%E3%83%BC%E3%83%8A%E3%83%A1%E3%83%B3%E3%83%88&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ1QJ6BAg-EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+%E6%B1%BA%E5%8B%9D%E3%83%88%E3%83%BC%E3%83%8A%E3%83%A1%E3%83%B3%E3%83%88'},
#   {'block_position': 1,
#    'query': 'ルヴァンカップ トーナメント表',
#    'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+%E3%83%88%E3%83%BC%E3%83%8A%E3%83%A1%E3%83%B3%E3%83%88%E8%A1%A8&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ1QJ6BAg9EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+%E3%83%88%E3%83%BC%E3%83%8A%E3%83%A1%E3%83%B3%E3%83%88%E8%A1%A8'},
#   {'block_position': 1,
#    'query': 'ルヴァンカップ優勝チーム',
#    'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E5%84%AA%E5%8B%9D%E3%83%81%E3%83%BC%E3%83%A0&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ1QJ6BAg8EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E5%84%AA%E5%8B%9D%E3%83%81%E3%83%BC%E3%83%A0'},
#   {'block_position': 1,
#    'query': 'ルヴァンカップ レギュレーション',
#    'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+%E3%83%AC%E3%82%AE%E3%83%A5%E3%83%AC%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ1QJ6BAg7EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+%E3%83%AC%E3%82%AE%E3%83%A5%E3%83%AC%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3'},
#   {'block_position': 1,
#    'query': 'ルヴァンカップ 優勝回数',
#    'link': 'https://www.google.com/search?sca_esv=72b2733ec0ce7f63&gl=jp&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+%E5%84%AA%E5%8B%9D%E5%9B%9E%E6%95%B0&sa=X&ved=2ahUKEwja5PPWtsSCAxVmSDABHevCBwcQ1QJ6BAgyEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97+%E5%84%AA%E5%8B%9D%E5%9B%9E%E6%95%B0'}],
#  'pagination': {'current': 1,
#   'next': 'https://www.google.com/search?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&oq=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&hl=ja&gl=jp&start=10&sourceid=chrome&ie=UTF-8',
#   'other_pages': {'2': 'https://www.google.com/search?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&oq=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&hl=ja&gl=jp&start=10&sourceid=chrome&ie=UTF-8',
#    '3': 'https://www.google.com/search?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&oq=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&hl=ja&gl=jp&start=20&sourceid=chrome&ie=UTF-8',
#    '4': 'https://www.google.com/search?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&oq=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&hl=ja&gl=jp&start=30&sourceid=chrome&ie=UTF-8',
#    '5': 'https://www.google.com/search?q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&oq=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&hl=ja&gl=jp&start=40&sourceid=chrome&ie=UTF-8'}},
#  'serpapi_pagination': {'current': 1,
#   'next_link': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&start=10',
#   'next': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&start=10',
#   'other_pages': {'2': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&start=10',
#    '3': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&start=20',
#    '4': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&start=30',
#    '5': 'https://serpapi.com/search.json?device=desktop&engine=google&gl=jp&google_domain=google.com&hl=ja&q=%E4%BB%8A%E5%B9%B4%E3%81%AE%E3%83%AB%E3%83%B4%E3%82%A1%E3%83%B3%E3%82%AB%E3%83%83%E3%83%97%E3%82%92%E5%84%AA%E5%8B%9D%E3%81%97%E3%81%9F%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E3%83%81%E3%83%BC%E3%83%A0%E3%81%AF%E3%81%A9%E3%81%93%E3%81%A7%E3%81%99%E3%81%8B%EF%BC%9F&start=40'}}}

# %%
# Organic results
organic_results = [None] * num_organic_results
for k in range(num_organic_results):
    if (
        'organic_results' in search_data
        and len(search_data['organic_results']) > k
    ):
      organic_results[k] = format_search_results(
          search_data['organic_results'][k]
      )
    else:
      organic_results[k] = format_search_results({})

for d in organic_results[::-1]:
   df = pd.concat([df, pd.DataFrame([d])], ignore_index=True)

# %%
print(len(organic_results))
organic_results
# Out:
# 15
# [{'source': 'soccer-king.jp',
#   'date': 'Nov 04, 2023',
#   'title': 'ルヴァンカップMVPは福岡MF前寛之！ 恩師・長谷部監督 ...',
#   'snippet': '『2023JリーグYBCルヴァンカップ』の決勝戦が4日に行われ、アビスパ福岡が2－1で浦和レッズを下して初優勝。この試合で貴重な先制点を記録し、MVPを ...',
#   'highlight': 'ルヴァンカップ | 優勝'},
#  {'source': 'jleague.jp',
#   'date': 'Jun 18, 2023',
#   'title': '【公式】YBCルヴァンカップの順位表 - Jリーグ',
#   'snippet': '（1）グループステージが終了した時点で、勝点合計の多いチームを上位とし、順位を決定する。ただし、勝点が同じ場合は、以下の順によって順位を決定する ...',
#   'highlight': 'した | チーム'},
#  {'source': 'detail.chiebukuro.yahoo.co.jp',
#   'date': 'Nov 08, 2023',
#   'title': 'ルヴァンカップの決勝でアビスパ福岡が優勝しましたが',
#   'snippet': 'ルヴァンカップの決勝でアビスパ福岡が優勝しましたが、福岡でもソフトバンクホークスの影に隠れていることが多く厳しい状況が続いていたため感動も ...',
#   'highlight': 'ルヴァンカップ | 優勝 | した'},
#  {'source': 'sposuru.com',
#   'date': 'Aug 09, 2023',
#   'title': '【ルヴァンカップ】賞金と歴代優勝チーム一覧 - スポスル',
#   'snippet': '昔からのサッカーファンには「ヤマザキナビスコカップ」として知られているルヴァンカップ。 Jリーグの始まりと共にスタートしたこの大会ではさまざまな ...',
#   'highlight': 'サッカー | ルヴァンカップ | した'},
#  {'source': 'jleague.jp',
#   'date': None,
#   'title': '歴代優勝クラブ：2022JリーグYBCルヴァンカップ',
#   'snippet': '2022JリーグYBCルヴァンカップの30周年特設サイト、過去30年の歴代優勝クラブを紹介。Jリーグ（日本プロサッカーリーグ）試合速報、日程、結果、順位表、写真、 ...',
#   'highlight': 'ルヴァンカップ | 優勝 | サッカー'},
#  {'source': 'mainichi.jp',
#   'date': 'Nov 04, 2023',
#   'title': '15歳のニュース NEWS・FILE weekly topics 11月3日～11 ...',
#   'snippet': 'サッカー ルヴァン・カップ 福岡が初優勝. 国内サッカーの「3大タイトル」の一つ、JリーグのYBCルヴァン・カップの決勝が東京・国立競技場であり、福岡 ...',
#   'highlight': 'サッカー ルヴァン | カップ | 優勝 | サッカー | ルヴァン | カップ'},
#  {'source': 'yab.yomiuri.co.jp',
#   'date': 'Nov 03, 2023',
#   'title': 'Jリーグ YBCルヴァンカップ」の優勝トロフィーを今年も制作 - ...',
#   'snippet': 'ティファニー・アンド・カンパニー・ジャパン・インクティファニーは、「Jリーグ YBCルヴァンカップ」(C)J.LEAGUEの優勝トロフィーを今年も制作 ...',
#   'highlight': 'ルヴァンカップ | 優勝 | 今年'},
#  {'source': 'www3.nhk.or.jp',
#   'date': 'Nov 04, 2023',
#   'title': 'Jリーグカップ アビスパ福岡 初優勝 クラブ史上初タイトル',
#   'snippet': 'サッカーの国内3大タイトルの1つ、Jリーグカップの決勝が国立競技場で行われ、アビスパ福岡が浦和レッズに2対1で勝って初めての優勝を果たしました。',
#   'highlight': 'サッカー | カップ | 優勝'},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None},
#  {'source': None,
#   'date': None,
#   'title': None,
#   'snippet': None,
#   'highlight': None}]

# %%
 # Related questions
related_questions = [None] * num_related_questions
for k in range(num_related_questions):
  if (
      'related_questions' in search_data
      and len(search_data['related_questions']) > k
  ):
    related_questions[k] = format_search_results(
        search_data['related_questions'][k], title_field='question'
    )
  else:
    related_questions[k] = format_search_results({})

for d in related_questions[::-1]:
  df = pd.concat([df, pd.DataFrame([d])], ignore_index=True)

# %%
print(len(related_questions))
related_questions
# Out:
# 3
# [{'source': 'jleague.jp',
#   'date': None,
#   'title': 'ルヴァンカップ決勝 どこで？',
#   'snippet': '決勝の開催日、開催スタジアム、TV放送決定のお知らせ【ルヴァンカップ】 「２０２３ＪリーグYBCルヴァンカップ 決勝」の開催日、開催スタジアムおよびTV放送が下記の通り決定しましたのでお知らせいたします。 決勝は11月4日（土）に国立競技場にて開催いたします。',
#   'highlight': None},
#  {'source': 'nikkansports.com',
#   'date': None,
#   'title': 'ルヴァンカップの優勝者は？',
#   'snippet': None,
#   'highlight': None},
#  {'source': 'jleague.jp',
#   'date': None,
#   'title': 'ルヴァンカップのグループBの順位は？',
#   'snippet': None,
#   'highlight': None}]

# %%
# Knowledge graph
knowledge_graph = None
if 'knowledge_graph' in search_data:
  knowledge_graph = format_knowledge_graph(search_data['knowledge_graph'])
else:
  knowledge_graph = format_knowledge_graph({})
df = pd.concat([df, pd.DataFrame([knowledge_graph])], ignore_index=True)

# %%
knowledge_graph
# Out:
# {'source': None,
#  'date': None,
#  'title': None,
#  'snippet': None,
#  'highlight': None}

# %%
# Answer box
answer_box = None
if 'answer_box' in search_data:
  answer_box = format_search_results(
      search_data['answer_box'], highlight_field='answer'
  )
else:
  answer_box = format_search_results({})
df = pd.concat([df, pd.DataFrame([answer_box])], ignore_index=True)

# %%
answer_box
# Out:
# {'source': 'jleague.jp',
#  'date': 'Nov 05, 2023',
#  'title': '【祝・初タイトル】アビスパ福岡のルヴァンカップ優勝を ...',
#  'snippet': '11月4日に国立競技場で２０２３ＪリーグＹＢＣルヴァンカップ決勝が行われ、アビスパ福岡が浦和レッズを下して初優勝に輝きました！',
#  'highlight': None}

# %%
# Sort by date
df['date'] = df['date'].apply(lambda x: format_date(x))
df['datetime'] = pd.to_datetime(df['date'], errors='coerce')
df = df.sort_values(by='datetime', na_position='first')
df.replace({pd.NaT: None}, inplace=True)
df = df.dropna(how='all')

# %%
df.head()
# Out:
#               source          date                       title  \
# 10        jleague.jp          None  歴代優勝クラブ：2022JリーグYBCルヴァンカップ
# 15        jleague.jp          None          ルヴァンカップのグループBの順位は？
# 16  nikkansports.com          None               ルヴァンカップの優勝者は？
# 17        jleague.jp          None              ルヴァンカップ決勝 どこで？
# 13        jleague.jp  Jun 18, 2023   【公式】YBCルヴァンカップの順位表 - Jリーグ
#
#                                               snippet            highlight  \
# 10  2022JリーグYBCルヴァンカップの30周年特設サイト、過去30年の歴代優勝クラブを紹介。...  ルヴァンカップ | 優勝 | サッカー
# 15                                               None                 None
# 16                                               None                 None
# 17  決勝の開催日、開催スタジアム、TV放送決定のお知らせ【ルヴァンカップ】 「２０２３ＪリーグY...                 None
# 13  （1）グループステージが終了した時点で、勝点合計の多いチームを上位とし、順位を決定する。ただ...             した | チーム
#
#                datetime
# 10                 None
# 15                 None
# 16                 None
# 17                 None
# 13  2023-06-18 00:00:00

# %%
reasoning_and_answer = (
    "\nPlease check if the question contains a valid premise before"
    " answering.\nanswer: "
)

# Select top_k supporting evidences overall
evidences = []

for _, row in df.tail(num_retrieved_evidences).iterrows():
  evidences.append(
      f"""\n\nsource: {row['source']}\ndate: {row['date']}\ntitle: {row['title']}\nsnippet: {row['snippet']}\nhighlight: {row['highlight']}"""
  )

format_fresh_prompt = ''.join(
        [
            f'\n\n\nquery: {question}',
        ]
        + evidences
    ) + f'\n\nquestion: {question}{reasoning_and_answer}'

# %%
print(format_fresh_prompt)
# Out:
# query: 今年のルヴァンカップを優勝したサッカーチームはどこですか？
#
# source: jleague.jp
# date: None
# title: 歴代優勝クラブ：2022JリーグYBCルヴァンカップ
# snippet: 2022JリーグYBCルヴァンカップの30周年特設サイト、過去30年の歴代優勝クラブを紹介。Jリーグ（日本プロサッカーリーグ）試合速報、日程、結果、順位表、写真、 ...
# highlight: ルヴァンカップ | 優勝 | サッカー
#
# source: jleague.jp
# date: None
# title: ルヴァンカップのグループBの順位は？
# snippet: None
# highlight: None
#
# source: nikkansports.com
# date: None
# title: ルヴァンカップの優勝者は？
# snippet: None
# highlight: None
#
# source: jleague.jp
# date: None
# title: ルヴァンカップ決勝 どこで？
# snippet: 決勝の開催日、開催スタジアム、TV放送決定のお知らせ【ルヴァンカップ】 「２０２３ＪリーグYBCルヴァンカップ 決勝」の開催日、開催スタジアムおよびTV放送が下記の通り決定しましたのでお知らせいたします。 決勝は11月4日（土）に国立競技場にて開催いたします。
# highlight: None
#
# source: jleague.jp
# date: Jun 18, 2023
# title: 【公式】YBCルヴァンカップの順位表 - Jリーグ
# snippet: （1）グループステージが終了した時点で、勝点合計の多いチームを上位とし、順位を決定する。ただし、勝点が同じ場合は、以下の順によって順位を決定する ...
# highlight: した | チーム
#
# source: sposuru.com
# date: Aug 09, 2023
# title: 【ルヴァンカップ】賞金と歴代優勝チーム一覧 - スポスル
# snippet: 昔からのサッカーファンには「ヤマザキナビスコカップ」として知られているルヴァンカップ。 Jリーグの始まりと共にスタートしたこの大会ではさまざまな ...
# highlight: サッカー | ルヴァンカップ | した
#
# source: yab.yomiuri.co.jp
# date: Nov 03, 2023
# title: Jリーグ YBCルヴァンカップ」の優勝トロフィーを今年も制作 - ...
# snippet: ティファニー・アンド・カンパニー・ジャパン・インクティファニーは、「Jリーグ YBCルヴァンカップ」(C)J.LEAGUEの優勝トロフィーを今年も制作 ...
# highlight: ルヴァンカップ | 優勝 | 今年
#
# source: www3.nhk.or.jp
# date: Nov 04, 2023
# title: Jリーグカップ アビスパ福岡 初優勝 クラブ史上初タイトル
# snippet: サッカーの国内3大タイトルの1つ、Jリーグカップの決勝が国立競技場で行われ、アビスパ福岡が浦和レッズに2対1で勝って初めての優勝を果たしました。
# highlight: サッカー | カップ | 優勝
#
# source: mainichi.jp
# date: Nov 04, 2023
# title: 15歳のニュース NEWS・FILE weekly topics 11月3日～11 ...
# snippet: サッカー ルヴァン・カップ 福岡が初優勝. 国内サッカーの「3大タイトル」の一つ、JリーグのYBCルヴァン・カップの決勝が東京・国立競技場であり、福岡 ...
# highlight: サッカー ルヴァン | カップ | 優勝 | サッカー | ルヴァン | カップ
#
# source: soccer-king.jp
# date: Nov 04, 2023
# title: ルヴァンカップMVPは福岡MF前寛之！ 恩師・長谷部監督 ...
# snippet: 『2023JリーグYBCルヴァンカップ』の決勝戦が4日に行われ、アビスパ福岡が2－1で浦和レッズを下して初優勝。この試合で貴重な先制点を記録し、MVPを ...
# highlight: ルヴァンカップ | 優勝
#
# source: jleague.jp
# date: Nov 05, 2023
# title: 【祝・初タイトル】アビスパ福岡のルヴァンカップ優勝を ...
# snippet: 11月4日に国立競技場で２０２３ＪリーグＹＢＣルヴァンカップ決勝が行われ、アビスパ福岡が浦和レッズを下して初優勝に輝きました！
# highlight: None
#
# source: detail.chiebukuro.yahoo.co.jp
# date: Nov 08, 2023
# title: ルヴァンカップの決勝でアビスパ福岡が優勝しましたが
# snippet: ルヴァンカップの決勝でアビスパ福岡が優勝しましたが、福岡でもソフトバンクホークスの影に隠れていることが多く厳しい状況が続いていたため感動も ...
# highlight: ルヴァンカップ | 優勝 | した
#
# question: 今年のルヴァンカップを優勝したサッカーチームはどこですか？
# Please check if the question contains a valid premise before answering.
# answer:

# %%
fresh_prompt = freshprompt_demo + format_fresh_prompt

# %%
print(fresh_prompt)
# Out:
# query: What year is considered Albert Einstein's annus mirabilis?
#
# source: philsci-archive.pitt.edu
# date: None
# title: The Turning Point for Einstein's Annus Mirabilis
# snippet: The year 1905 has been called Einstein's annus mirabilis in virtue of three ground-breaking works completed over the span of a few months — the light.
# highlight: 1905
#
# source: cantorsparadise.com
# date: None
# title: Einstein's Miraculous Year: A Summary of the 1905 Annus ...
# snippet: These are the four papers that Albert Einstein published in 1905, which are considered to be the foundation of modern physics.
# highlight: 1905
#
# source: quora.com
# date: None
# title: Why is 1905 Einstein's miracle year?
# snippet: Thus, 1905 is called Einstein's annus mirabilis, or miracle year, and these papers are called his annus mirabilis papers .
# highlight: 1905
#
# source: en.wikipedia.org
# date: None
# title: Annus mirabilis papers
# snippet: The annus mirabilis papers are the four papers that Albert Einstein published in Annalen der Physik (Annals of Physics), a scientific journal, in 1905.
# highlight: 1905
#
# source: americanscientist.org
# date: None
# title: Which year is known as annus mirabilis year?
# snippet: The Cambridge Dictionary defines annus mirabilis as “a year of extremely good events.” When otherwise unqualified, the term is usually understood to refer to “the miraculous year” of 1666, during which the Great Plague continued and the Great Fire of London raged for four days.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: When was the annus mirabilis of Albert Einstein?
# snippet: Because Einstein published these remarkable papers in a single year, 1905 is called his annus mirabilis (miracle year in English or Wunderjahr in German). , and was the only specific discovery mentioned in the citation awarding Einstein the Nobel Prize in Physics.
# highlight: None
#
# source: iopscience.iop.org
# date: None
# title: 1905
# snippet: Abstract. It is no exaggeration to say that almost every physicist knows about Albert Einstein's annus mirabilis 1905.
# highlight: 1905
#
# source: npr.org
# date: Mar 17, 2005
# title: Albert Einstein's Year of Miracles: Light Theory
# snippet: Scientists call 1905 Albert Einstein's annus mirabilis — his year of miracles. ... considered here [the March paper]" that represented a sharp ...
# highlight: 1905
#
# source: npr.org
# date: Mar 17, 2005
# title: What year is Einstein's biggest year?
# snippet: Web Resources. Scientists call 1905 Albert Einstein's annus mirabilis — his year of miracles. Within a few months, Einstein wrote a series of papers that would transform the way we see the universe.
# highlight: None
#
# source: scihi.org
# date: Jun 30, 2018
# title: The Annus Mirabilis in Physics – Albert Einstein and the Year ...
# snippet: 1905 was this Annus Mirabilis, this year of wonders or extraordinary year. History considers 1905 as the year with the most outstanding and ...
# highlight: 1905
#
# source: guides.loc.gov
# date: Nov 06, 2019
# title: Introduction - Annus Mirabilis of Albert Einstein
# snippet: He published hundreds of scientific papers during the course of his life, but in 1905, the year he turned 26, he published the four ...
# highlight: 1905
#
# source: guides.loc.gov
# date: Nov 04, 2023
# title: The 1905 Papers - Annus Mirabilis of Albert Einstein
# snippet: English translations of the four papers, from The Collected Papers of Albert Einstein, vol. 2: The Swiss Years: Writings 1900-1909, Princeton ...
# highlight: Albert
#
# question: What year is considered Albert Einstein's annus mirabilis?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. 1905 is considered Albert Einstein's annus mirabilis, his miraculous year.
#
#
# query: Which photographer took the most expensive photograph in the world?
#
# source: phototraces.com
# date: None
# title: Top 10 Most Expensive Photographs Ever Sold
# snippet: 10 Most Expensive Photographs Ever Sold · #1 Peter Lik, Phantom – (?) · #2 Andreas Gursky, Rhein II $4,338,500 · #3 Richard Prince, Spiritual America $3,973,000 · # ...
# highlight: Peter Lik, Phantom
#
# source: expertphotography.com
# date: None
# title: The 10 Most Expensive Photographs Ever Sold (by 2023)
# snippet: These are most expensive photographs ever sold, for millions at auction. You can decide for yourself if these famous photographers work is worth the price!
# highlight: most expensive photographs ever | photographers
#
# source: academic-accelerator.com
# date: None
# title: This is some fact about the cell membrane.
# snippet: cell membrane
# highlight: None
#
# source: reddit.com
# date: None
# title: Who is The Most Expensive Wedding Photographer in the world? and what is their portfolio like?
# snippet: surely Jose Villa would cost a bomb.
# highlight: None
#
# source: quora.com
# date: None
# title: What is the most expensive photograph ever shot?
# snippet: Probably the photo of the Earth taken from the Moon. Each moon landing of the Apollo program averages out to $18 billion dollars out of the $109 billion dollar program (based in 2011 dollars). http://www.thespacereview.com/article/1579/1 Hard to imaging that any other photo can come close.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: List
# snippet:
#
# Rank,Artist,Date
# 1,Man Ray,May 14, 2022
# 2,Edward Steichen,Nov 10, 2022
# 3,Andreas Gursky,November 8, 2011
# 4,Atsuko Satō,June 11, 2021
# highlight: None
#
# source: pentaxforums.com
# date: Oct 23, 2012
# title: WHo took the world's most expensive photograph?
# snippet: WHo took the world's most expensive photograph? ... Gursky sells high resolution photographs of huge dimensions often taken from very high angles.
# highlight: Gursky
#
# source: quora.com
# date: Mar 12, 2015
# title: What is the most expensive photograph ever shot?
# snippet: Shot by Kevin Abosch, in 2010 was auctioned for a whopping 1 Million Euros in 2015.
# highlight: Kevin Abosch
#
# source: digitalphotographycourses.co.za
# date: Nov 21, 2018
# title: What photograph sold for 4.3 million?
# snippet: Andreas Gursky's, Rhein II was sold at Christie's, New York for a whopping 4.3 Million USD on November 8, 2011.
# highlight: None
#
# source: all-about-photo.com
# date: Dec 22, 2019
# title: Most expensive photographs ever sold | Photo Article
# snippet: The most expensive photo in history as of December 2014 is $6.5 million! The work of Australian landscape photographer Peter Lik, Phantom is a ...
# highlight: Australian landscape photographer Peter Lik, Phantom
#
# source: pocket-lint.com
# date: Jul 22, 2021
# title: The 24 most expensive photos that sold for millions
# snippet: Australian photographer Peter Lik claims to hold the record for the most expensive photograph ever sold: a staggering $6.5 million for his photo ...
# highlight: Australian photographer Peter Lik
#
# source: cnn.com
# date: May 15, 2022
# title: What is the world's most expensive photograph?
# snippet: Man Ray's 'Le Violon d'Ingres' photograph sells for record $12.4 million. Editor's Note: This story was updated with the final sale price and other details following the auction.
# highlight: None
#
# source: news.artnet.com
# date: May 16, 2022
# title: What is the most expensive print ever sold?
# snippet: Man Ray, Le Violon d'Ingres (1924). Courtesy of Christie's. This weekend, an iconic Man Ray print sold for $12.4 million at Christie's, nearly tripling the record for the most expensive photograph ever sold at auction.
# highlight: None
#
# source: barnebys.com
# date: May 14, 2023
# title: The 11 Most Expensive Photographers
# snippet: It became the world's most expensive photograph when it sold at Christie's in 2022 for $12.4 million. Find more features on Barnebys Magazine.
# highlight: Christie's
#
# source: artincontext.org
# date: Aug 10, 2023
# title: Most Expensive Photographs - 15 Extravagant Photographs
# snippet: Le Violon D'Ingre (1924) by Man Ray takes first place at an astonishing $12.4 million! Some of the other most expensive photos ever sold include ...
# highlight: Le Violon D'Ingre (1924) by Man Ray
#
# question: Which photographer took the most expensive photograph in the world?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The most expensive photograph in the world is "Le Violon d'Ingres". The photograph was created by Man Ray.
#
#
# query: How many days are left until the 2023 Grammy Awards?
#
# source: en.wikipedia.org
# date: None
# title: 65th Annual Grammy Awards
# snippet: The 65th Annual Grammy Awards ceremony was held at the Crypto.com Arena in Los Angeles on February 5, 2023. It recognized the best recordings, compositions, ...
# highlight: Grammy Awards | in | 2023
#
# source: grammy.com
# date: None
# title: Everything You Need To Know About The 2023 GRAMMYs ...
# snippet: The eligibility period for the 65th GRAMMY Awards is Friday, Oct. 1, 2021 – Friday, Sept. 30, 2022. All eligible awards entries must be released within this ...
# highlight: for | GRAMMY Awards
#
# source: recordingacademy.com
# date: None
# title: 2023 GRAMMYs: Everything You Need To Know About ...
# snippet: There are only two days left to participate in first-round voting for the 2023 GRAMMYs; final-round voting will commence Dec. 14. If you're a Recording ...
# highlight: two days
#
# source: grammy.com
# date: None
# title: Air Date For 2023 GRAMMYs Announced
# snippet: This year's GRAMMY nominees will be announced on Tuesday, Nov. 15, with the 2023 GRAMMYs airing live Sunday, Feb. 5, from the Crypto.com Arena in Los Angeles.
# highlight: GRAMMY | 2023 GRAMMYs | in
#
# source: recordingacademy.com
# date: None
# title: How long until the next Grammy Awards?
# snippet: THE 66TH ANNUAL GRAMMY AWARDS® SET TO TAKE PLACE SUN, FEB. 4, 2024 | RECORDINGACADEMY.com.
# highlight: None
#
# source: grammy.com
# date: None
# title: What time is GRAMMYs 2023 over?
# snippet: The 2023 GRAMMYs will air live on Sunday, Feb. 5, at 8-11:30 p.m. ET/5-8:30 p.m. PT from the Crypto.com Arena in Los Angeles.
# highlight: None
#
# source: variety.com
# date: Jul 14, 2022
# title: Grammy Awards Announce Key Dates for 2023 Race
# snippet: Nominees will be announced this year on Nov. 15, with the first round of voting set from Oct. 13 to Oct. 23 and a final round on Dec. 14 to Jan.
# highlight: None
#
# source: billboard.com
# date: Jul 14, 2022
# title: Here's the Date & Location of the 2023 Grammy Awards
# snippet: Nominations will be announced on Tuesday, Nov. 15 -- eight days earlier than they were last year.
# highlight: eight days
#
# source: en.as.com
# date: Feb 01, 2023
# title: 2023 Grammy Awards: Who's attending, skipping, and ...
# snippet: With only a few days left until the 65th annual Grammy Awards, and the full performer lineup yet to be announced, here is how the show is ...
# highlight: only a few days
#
# source: howmanydaysuntil.center
# date: Feb 04, 2023
# title: When ar The Grammy Awards - How Many Days Until
# snippet: The Grammy Awards will be celebrated this year on is on February 4th. Find out more about The Grammy Awards.
# highlight: February 4th
#
# source: cnn.com
# date: Feb 05, 2023
# title: How to watch the Grammys: Time, channels and more
# snippet: How to watch the 2023 Grammy Awards: Time, channels and more · Day and time. The Grammy Awards air Sunday, February 5, at 8 p.m. ET/5 p.m. PT.
# highlight: 2023 Grammy Awards | Day | Grammy Awards
#
# source: nytimes.com
# date: Feb 06, 2023
# title: How to Watch the 2023 Grammys
# snippet: The ceremony will air live on Sunday, at 8 p.m. Eastern time (5 p.m. Pacific time) on CBS and stream live on Paramount+. Before the prime-time ...
# highlight: Before the
#
# source: billboard.com
# date: Nov 10, 2023
# title: What is the deadline for Grammy nominations 2023?
# snippet: This year's eligibility period ran from Oct. 1, 2022, through Sept. 15, 2023. The final round of Grammy voting, which will determine the winners, will take place Dec. 14 through Jan. 4, 2024.
# highlight: None
#
# question: How many days are left until the 2023 Grammy Awards?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The 2023 Grammy Awards ceremony was held on February 5, 2023. Thus, the ceremony has already taken place.
#
#
# query: How many years ago did the Boxing Day Tsunami happen?
#
# source: knowledge.aidr.org.au
# date: None
# title: The Boxing Day Tsunami in numbers Stats and facts
# snippet: The Tangshan Earthquake in China killed at least 255,000 in 1976. Flooding in Bangladesh in 2004 destroyed over 1 million homes, displaced over 4 million ...
# 	2 pages
# highlight: Earthquake | 2004
#
# source: knowledge.aidr.org.au
# date: None
# title: Indian Ocean tsunami, 2004 | Australian Disasters
# snippet: In December 2004, a massive earthquake struck off the west coast of Sumatra. The resulting Indian Ocean tsunami caused widespread destruction. Learn more.
# highlight: December 2004
#
# source: britannica.com
# date: None
# title: Indian Ocean tsunami of 2004 | Facts & Death Toll
# snippet: Indian Ocean tsunami of 2004, deadly tsunami that hit the coasts of several countries of South and Southeast Asia and caused immense destruction.
# highlight: 2004
#
# source: britannica.com
# date: None
# title: How long did the 2004 tsunami last?
# snippet: How long did the Indian Ocean tsunami of 2004 last? The Indian Ocean tsunami of 2004 lasted for seven hours and reached out across the Indian Ocean, devastating coastal areas of Indonesia, Sri Lanka, India, Maldives, and Thailand, and as far away as East Africa.
# highlight: None
#
# source: en.wikipedia.org
# date: None
# title: 2004 Indian Ocean earthquake and tsunami - Wikipedia
# snippet: On 26 December 2004, at 07:58:53 local time (UTC+7), a major earthquake with a magnitude of 9.1–9.3 Mw struck with an epicentre off the west coast of northern Sumatra, Indonesia.
# highlight: None
#
# source: history.com
# date: Oct 02, 2018
# title: The 2004 Tsunami Wiped Away Towns With 'Mind- ...
# snippet: The Boxing Day tsunami would be the deadliest in recorded history, taking a staggering 230,000 lives in a matter of hours. The city of Banda ...
# highlight: 230,000
#
# source: reuters.com
# date: Dec 18, 2019
# title: 15 years on, a look back at the Boxing Day tsunami
# snippet: December 26 marks 15 years since a 9.1 magnitude quake off the coast of Indonesia's Aceh province triggered a tsunami that killed more than ...
# highlight: 15 years
#
# source: preventionweb.net
# date: Jun 26, 2021
# title: Indian Ocean tsunami: What was learned about recovery
# snippet: We've been following victims of the Boxing Day tsunami for 16 years – this is what we've learned about recovering from disaster. Source(s): ...
# highlight: 16 years
#
# source: materchristi.libguides.com
# date: May 11, 2023
# title: 2004 Indian Ocean Tsunami - Natural disasters of the Asia ...
# snippet: The Boxing Day tsunami in 2004 is believed to be the deadliest tsunami in history, killing more than 230,000 people across 14 countries.
# highlight: 2004
#
# source: noaa.gov
# date: Jun 12, 2023
# title: JetStream Max: 2004 Indian Ocean Tsunami
# snippet: On December 26, 2004, an extremely powerful earthquake off the coast of the Indonesian island of Sumatra in the Indian Ocean generated a ...
# highlight: December 26, 2004
#
# source: noaa.gov
# date: Jun 12, 2023
# title: When did the Boxing Day tsunami occur?
# snippet: On December 26, 2004, an extremely powerful earthquake off the coast of the Indonesian island of Sumatra in the Indian Ocean generated a devastating tsunami.
# highlight: None
#
# source: worldvision.org
# date: Sep 25, 2023
# title: 2004 Indian Ocean Earthquake and Tsunami
# snippet: Discover the 2004 Indian Ocean tsunami's historic impact and World Vision's multi-country humanitarian efforts that lasted over a decade.
# highlight: 2004
#
# source: worldvision.org
# date: Sep 25, 2023
# title: What was the worst tsunami in 2004?
# snippet: Approximately 230,000 people died in the 2004 Indian Ocean earthquake and tsunami, making it one of the deadliest disasters in modern history. The Sumatra-Andaman earthquake, which caused the tsunami, is estimated to have released energy equivalent to 23,000 Hiroshima-type atomic bombs.
# highlight: None
#
# question: How many years ago did the Boxing Day Tsunami happen?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. The disaster occurred on December 26, 2004. Thus, it happened 18 years ago.
#
#
# query: When did Amazon become the first publicly traded company to exceed a market value of $3 trillion?
#
# source: en.wikipedia.org
# date: None
# title: List of public corporations by market capitalization
# snippet: The table below lists all companies which have, at any point, had a market capitalization in excess of $1 trillion, the date on which their market cap first ...
# highlight: companies | market capitalization | excess | trillion | market cap first
#
# source: cbsnews.com
# date: Sep 04, 2018
# title: Amazon becomes second trillion-dollar company in US
# snippet: Amazon hits $1 trillion and becomes the second U.S. company worth one trillion dollars after stock price surged Tuesday - CBS News.
# highlight: after stock price surged Tuesday
#
# source: cnbc.com
# date: Jan 03, 2022
# title: Apple becomes first U.S. company to reach $3 trillion ...
# snippet: Apple became the first publicly traded U.S. company to hit a $1 trillion market cap during intraday trading on Aug. 2, 2018. It hit a $2 ...
# highlight: Aug. 2, 2018
#
# source: fortune.com
# date: Nov 02, 2022
# title: As Amazon's value drops below $1 trillion, this chart shows ...
# snippet: On November 1, Amazon reached a bleak milestone when its value dropped below $1 trillion for the first time since first crossing that ...
# highlight: On November 1
#
# source: financialpost.com
# date: Nov 09, 2022
# title: Amazon becomes first public company to lose $1 trillion ...
# snippet: Amazon.com Inc. is the world's first public company to lose a trillion dollars in market value as a combination of rising inflation ...
# highlight: Amazon | is the | first public company | trillion | market value
#
# source: bloomberg.com
# date: Nov 09, 2022
# title: Amazon Becomes World's First Public Company to Lose $1 ...
# snippet: Amazon.com Inc. is the world's first public company to lose a trillion dollars in market value as a combination of rising inflation, ...
# highlight: Amazon | is the | first public company | trillion | market value
#
# source: fortune.com
# date: Jun 30, 2023
# title: Apple becomes first $3 trillion market value company
# snippet: Apple first became the world's most valuable stock in 2011, when its market cap was under $340 billion and it comprised about 3.3% of the S&P ...
# highlight: 2011
#
# source: qz.com
# date: Jun 30, 2023
# title: Apple is officially the world's first-ever $3 trillion company
# snippet: Apple became the first company in the world with a $3 trillion valuation on Friday (June 30). The company's stock closed at $193.97 per share— ...
# highlight: Friday (June 30
#
# source: zeebiz.com
# date: Jun 30, 2023
# title: What company has reached the market cap of 3 trillion?
# snippet: Apple is once again worth $3 trillion, the only company ever to reach the milestone, a media report said. Its shares rose 1 per cent on Friday to hit a record $191.34. With 15.7 billion shares outstanding, the stock price pushed Apple to its historic market value, CNN reported.
# highlight: None
#
# source: nbcnews.com
# date: Jun 30, 2023
# title: Is Apple the first US company to reach $3 trillion market cap?
# snippet: The news shows investors remain bullish on the stock and Apple's portfolio of products and services, despite the company's warning in May that its current quarter revenue is expected to fall about 3%.
# highlight: None
#
# source: fortune.com
# date: Jun 30, 2023
# title: What is the first $3 trillion dollar company?
# snippet: Apple just made history by becoming the first company with a $3 trillion market value—'and its lock on the consumer is only getting stronger' Apple CEO Tim Cook.
# highlight: None
#
# source: cityindex.com
# date: Aug 24, 2023
# title: A guide to trillion-dollar companies
# snippet: Apple did become the world's first $3 trillion company in June 2023 but hasn't retained that market capitalisation in the subsequent months.
# highlight: June 2023
#
# source: money.usnews.com
# date: Oct 24, 2023
# title: The 10 Most Valuable Companies in the World by Market ...
# snippet: (ticker: AAPL) was the first company to reach a market capitalization of $1 trillion in 2018. ... Overall, Amazon has become the largest online ...
# highlight: 2018
#
# question: When did Amazon become the first publicly traded company to exceed a market value of $3 trillion?
# answer: As of today November 14, 2023, the most up-to-date and relevant information regarding this query is as follows. Amazon's market capitalization has never exceeded $3 trillion.
#
#
# query: 今年のルヴァンカップを優勝したサッカーチームはどこですか？
#
# source: jleague.jp
# date: None
# title: 歴代優勝クラブ：2022JリーグYBCルヴァンカップ
# snippet: 2022JリーグYBCルヴァンカップの30周年特設サイト、過去30年の歴代優勝クラブを紹介。Jリーグ（日本プロサッカーリーグ）試合速報、日程、結果、順位表、写真、 ...
# highlight: ルヴァンカップ | 優勝 | サッカー
#
# source: jleague.jp
# date: None
# title: ルヴァンカップのグループBの順位は？
# snippet: None
# highlight: None
#
# source: nikkansports.com
# date: None
# title: ルヴァンカップの優勝者は？
# snippet: None
# highlight: None
#
# source: jleague.jp
# date: None
# title: ルヴァンカップ決勝 どこで？
# snippet: 決勝の開催日、開催スタジアム、TV放送決定のお知らせ【ルヴァンカップ】 「２０２３ＪリーグYBCルヴァンカップ 決勝」の開催日、開催スタジアムおよびTV放送が下記の通り決定しましたのでお知らせいたします。 決勝は11月4日（土）に国立競技場にて開催いたします。
# highlight: None
#
# source: jleague.jp
# date: Jun 18, 2023
# title: 【公式】YBCルヴァンカップの順位表 - Jリーグ
# snippet: （1）グループステージが終了した時点で、勝点合計の多いチームを上位とし、順位を決定する。ただし、勝点が同じ場合は、以下の順によって順位を決定する ...
# highlight: した | チーム
#
# source: sposuru.com
# date: Aug 09, 2023
# title: 【ルヴァンカップ】賞金と歴代優勝チーム一覧 - スポスル
# snippet: 昔からのサッカーファンには「ヤマザキナビスコカップ」として知られているルヴァンカップ。 Jリーグの始まりと共にスタートしたこの大会ではさまざまな ...
# highlight: サッカー | ルヴァンカップ | した
#
# source: yab.yomiuri.co.jp
# date: Nov 03, 2023
# title: Jリーグ YBCルヴァンカップ」の優勝トロフィーを今年も制作 - ...
# snippet: ティファニー・アンド・カンパニー・ジャパン・インクティファニーは、「Jリーグ YBCルヴァンカップ」(C)J.LEAGUEの優勝トロフィーを今年も制作 ...
# highlight: ルヴァンカップ | 優勝 | 今年
#
# source: www3.nhk.or.jp
# date: Nov 04, 2023
# title: Jリーグカップ アビスパ福岡 初優勝 クラブ史上初タイトル
# snippet: サッカーの国内3大タイトルの1つ、Jリーグカップの決勝が国立競技場で行われ、アビスパ福岡が浦和レッズに2対1で勝って初めての優勝を果たしました。
# highlight: サッカー | カップ | 優勝
#
# source: mainichi.jp
# date: Nov 04, 2023
# title: 15歳のニュース NEWS・FILE weekly topics 11月3日～11 ...
# snippet: サッカー ルヴァン・カップ 福岡が初優勝. 国内サッカーの「3大タイトル」の一つ、JリーグのYBCルヴァン・カップの決勝が東京・国立競技場であり、福岡 ...
# highlight: サッカー ルヴァン | カップ | 優勝 | サッカー | ルヴァン | カップ
#
# source: soccer-king.jp
# date: Nov 04, 2023
# title: ルヴァンカップMVPは福岡MF前寛之！ 恩師・長谷部監督 ...
# snippet: 『2023JリーグYBCルヴァンカップ』の決勝戦が4日に行われ、アビスパ福岡が2－1で浦和レッズを下して初優勝。この試合で貴重な先制点を記録し、MVPを ...
# highlight: ルヴァンカップ | 優勝
#
# source: jleague.jp
# date: Nov 05, 2023
# title: 【祝・初タイトル】アビスパ福岡のルヴァンカップ優勝を ...
# snippet: 11月4日に国立競技場で２０２３ＪリーグＹＢＣルヴァンカップ決勝が行われ、アビスパ福岡が浦和レッズを下して初優勝に輝きました！
# highlight: None
#
# source: detail.chiebukuro.yahoo.co.jp
# date: Nov 08, 2023
# title: ルヴァンカップの決勝でアビスパ福岡が優勝しましたが
# snippet: ルヴァンカップの決勝でアビスパ福岡が優勝しましたが、福岡でもソフトバンクホークスの影に隠れていることが多く厳しい状況が続いていたため感動も ...
# highlight: ルヴァンカップ | 優勝 | した
#
# question: 今年のルヴァンカップを優勝したサッカーチームはどこですか？
# Please check if the question contains a valid premise before answering.
# answer:

# %%
answer = chat_completions(fresh_prompt)

# %%
print(answer)
# Out:
# 2023年のルヴァンカップはアビスパ福岡が優勝しました。
